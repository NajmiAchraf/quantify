# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD4_TC5_CX6 for Query

# %%
import sys
from make import *
from main_experiments import main

t_count = 5

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 2
# End range of qubits: 2
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 1s 1ms
# 	• RSS (Memory Usage): 221.69 MB
# 	• VMS (Memory Usage): 1.68 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 639ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD4_TC5_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  282ms
#
# Display decomposition ToffoliDecompType.AN0_TD4_TC5_CX6 circuit:
# Time elapsed on displaying the circuit:  330ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 32                   | 12               | 32               | 10                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 672ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
make_slurm("experiments", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 211ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD4_TC5_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 25.00% • Output vector: 75.00% )
#
# Time elapsed on simulation and comparison: 219ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |      2048        |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 52.34% • Output vector: 47.66% )
#
# Time elapsed on simulation and comparison: 1s 201ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# Rank: 27
# Loading stress experiment #1 of 1 with T gate indices: 28
#
#
# Rank: 19
# Loading stress experiment #1 of 1 with T gate indices: 20
#
#
# Rank: 21
# Loading stress experiment #1 of 1 with T gate indices: 22
#
#
# Rank: 10
# Loading stress experiment #1 of 1 with T gate indices: 11
#
#
# Rank: 2
# Loading stress experiment #1 of 1 with T gate indices: 3
#
#
# Rank: 28
# Loading stress experiment #1 of 1 with T gate indices: 29
#
#
# Rank: 11
# Loading stress experiment #1 of 1 with T gate indices: 12
#
#
# Rank: 15
# Loading stress experiment #1 of 1 with T gate indices: 16
#
#
# Rank: 4
# Loading stress experiment #1 of 1 with T gate indices: 5
#
#
# Rank: 13
# Loading stress experiment #1 of 1 with T gate indices: 14
#
#
# Rank: 23
# Loading stress experiment #1 of 1 with T gate indices: 24
#
#
# Rank: 14
# Loading stress experiment #1 of 1 with T gate indices: 15
#
#
# Rank: 31
# Loading stress experiment #1 of 1 with T gate indices: 32
#
#
# Rank: 8
# Loading stress experiment #1 of 1 with T gate indices: 9
#
#
# Rank: 6
# Loading stress experiment #1 of 1 with T gate indices: 7
#
#
# Rank: 25
# Loading stress experiment #1 of 1 with T gate indices: 26
#
#
# Rank: 24
# Loading stress experiment #1 of 1 with T gate indices: 25
#
#
# Rank: 5
# Loading stress experiment #1 of 1 with T gate indices: 6
#
#
# Rank: 22
# Loading stress experiment #1 of 1 with T gate indices: 23
#
#
# Rank: 20
# Loading stress experiment #1 of 1 with T gate indices: 21
#
#
# Rank: 26
# Loading stress experiment #1 of 1 with T gate indices: 27
#
#
# Rank: 17
# Loading stress experiment #1 of 1 with T gate indices: 18
#
#
# Rank: 3
# Loading stress experiment #1 of 1 with T gate indices: 4
#
#
# Rank: 1
# Loading stress experiment #1 of 1 with T gate indices: 2
#
#
# Rank: 0
# Loading stress experiment #1 of 1 with T gate indices: 1
#
#
# Rank: 16
# Loading stress experiment #1 of 1 with T gate indices: 17
#
#
# Rank: 30
# Loading stress experiment #1 of 1 with T gate indices: 31
#
#
# Rank: 9
# Loading stress experiment #1 of 1 with T gate indices: 10
#
#
# Rank: 18
# Loading stress experiment #1 of 1 with T gate indices: 19
#
#
# Rank: 7
# Loading stress experiment #1 of 1 with T gate indices: 8
#
#
# Rank: 12
# Loading stress experiment #1 of 1 with T gate indices: 13
#
#
# Rank: 29
# Loading stress experiment #1 of 1 with T gate indices: 30
#
#
# Rank: 21
# Completed stress experiment #1 of 1 with T gate indices: 22
# Time elapsed: 2s 472ms
#
#
# Rank: 10
# Completed stress experiment #1 of 1 with T gate indices: 11
# Time elapsed: 2s 554ms
#
#
# Rank: 19
# Completed stress experiment #1 of 1 with T gate indices: 20
# Time elapsed: 2s 556ms
#
#
# Rank: 27
# Completed stress experiment #1 of 1 with T gate indices: 28
# Time elapsed: 2s 555ms
#
#
# Rank: 2
# Completed stress experiment #1 of 1 with T gate indices: 3
# Time elapsed: 2s 592ms
#
#
# Rank: 15
# Completed stress experiment #1 of 1 with T gate indices: 16
# Time elapsed: 2s 628ms
#
#
# Rank: 28
# Completed stress experiment #1 of 1 with T gate indices: 29
# Time elapsed: 2s 632ms
#
#
# Rank: 11
# Completed stress experiment #1 of 1 with T gate indices: 12
# Time elapsed: 2s 664ms
#
#
# Rank: 4
# Completed stress experiment #1 of 1 with T gate indices: 5
# Time elapsed: 2s 706ms
#
#
# Rank: 13
# Completed stress experiment #1 of 1 with T gate indices: 14
# Time elapsed: 2s 759ms
#
#
# Rank: 23
# Completed stress experiment #1 of 1 with T gate indices: 24
# Time elapsed: 2s 770ms
#
#
# Rank: 14
# Completed stress experiment #1 of 1 with T gate indices: 15
# Time elapsed: 2s 927ms
#
#
# Rank: 8
# Completed stress experiment #1 of 1 with T gate indices: 9
# Time elapsed: 3s 11ms
#
#
# Rank: 31
# Completed stress experiment #1 of 1 with T gate indices: 32
# Time elapsed: 3s 24ms
#
#
# Rank: 6
# Completed stress experiment #1 of 1 with T gate indices: 7
# Time elapsed: 3s 79ms
#
#
# Rank: 25
# Completed stress experiment #1 of 1 with T gate indices: 26
# Time elapsed: 3s 119ms
#
#
# Rank: 24
# Completed stress experiment #1 of 1 with T gate indices: 25
# Time elapsed: 3s 142ms
#
#
# Rank: 5
# Completed stress experiment #1 of 1 with T gate indices: 6
# Time elapsed: 3s 221ms
#
#
# Rank: 22
# Completed stress experiment #1 of 1 with T gate indices: 23
# Time elapsed: 3s 314ms
#
#
# Rank: 20
# Completed stress experiment #1 of 1 with T gate indices: 21
# Time elapsed: 3s 458ms
#
#
# Rank: 26
# Completed stress experiment #1 of 1 with T gate indices: 27
# Time elapsed: 3s 554ms
#
#
# Rank: 17
# Completed stress experiment #1 of 1 with T gate indices: 18
# Time elapsed: 3s 719ms
#
#
# Rank: 3
# Completed stress experiment #1 of 1 with T gate indices: 4
# Time elapsed: 3s 722ms
#
#
# Rank: 1
# Completed stress experiment #1 of 1 with T gate indices: 2
# Time elapsed: 3s 838ms
#
#
# Rank: 0
# Completed stress experiment #1 of 1 with T gate indices: 1
# Time elapsed: 3s 959ms
#
#
# Rank: 16
# Completed stress experiment #1 of 1 with T gate indices: 17
# Time elapsed: 4s 80ms
#
#
# Rank: 30
# Completed stress experiment #1 of 1 with T gate indices: 31
# Time elapsed: 4s 136ms
#
#
# Rank: 9
# Completed stress experiment #1 of 1 with T gate indices: 10
# Time elapsed: 4s 270ms
#
#
# Rank: 18
# Completed stress experiment #1 of 1 with T gate indices: 19
# Time elapsed: 4s 358ms
#
#
# Rank: 7
# Completed stress experiment #1 of 1 with T gate indices: 8
# Time elapsed: 4s 436ms
#
#
# Rank: 12
# Completed stress experiment #1 of 1 with T gate indices: 13
# Time elapsed: 4s 643ms
#
#
# Rank: 29
# Completed stress experiment #1 of 1 with T gate indices: 30
# Time elapsed: 4s 703ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 9.62              | 90.38             | 42.92             | 47.46             |
# | 2                | 7.76              | 92.24             | 44.78             | 47.46             |
# | 3                | 8.45              | 91.55             | 41.21             | 50.34             |
# | 4                | 9.38              | 90.62             | 40.38             | 50.24             |
# | 5                | 6.93              | 93.07             | 45.51             | 47.56             |
# | 6                | 8.69              | 91.31             | 43.95             | 47.36             |
# | 7                | 9.67              | 90.33             | 40.19             | 50.15             |
# | 8                | 9.08              | 90.92             | 41.06             | 49.85             |
# | 9                | 0.00              | 100.00            | 51.56             | 48.44             |
# | 10               | 0.00              | 100.00            | 51.56             | 48.44             |
# | 11               | 0.00              | 100.00            | 51.56             | 48.44             |
# | 12               | 0.00              | 100.00            | 51.56             | 48.44             |
# | 13               | 12.35             | 87.65             | 44.92             | 42.72             |
# | 14               | 19.09             | 80.91             | 44.34             | 36.57             |
# | 15               | 17.04             | 82.96             | 48.88             | 34.08             |
# | 16               | 15.97             | 84.03             | 43.80             | 40.23             |
# | 17               | 14.79             | 85.21             | 43.02             | 42.19             |
# | 18               | 18.51             | 81.49             | 42.43             | 39.06             |
# | 19               | 19.58             | 80.42             | 38.57             | 41.85             |
# | 20               | 12.35             | 87.65             | 46.24             | 41.41             |
# | 21               | 11.62             | 88.38             | 43.99             | 44.38             |
# | 22               | 9.18              | 90.82             | 46.14             | 44.68             |
# | 23               | 13.33             | 86.67             | 42.24             | 44.43             |
# | 24               | 12.84             | 87.16             | 44.78             | 42.38             |
# | 25               | 11.13             | 88.87             | 41.41             | 47.46             |
# | 26               | 5.96              | 94.04             | 46.53             | 47.51             |
# | 27               | 7.47              | 92.53             | 42.09             | 50.44             |
# | 28               | 8.59              | 91.41             | 41.55             | 49.85             |
# | 29               | 8.64              | 91.36             | 43.80             | 47.56             |
# | 30               | 6.59              | 93.41             | 45.75             | 47.66             |
# | 31               | 10.74             | 89.26             | 39.16             | 50.10             |
# | 32               | 6.88              | 93.12             | 42.87             | 50.24             |
#
#
# Time elapsed for stress testing 32 unique combinations: 5s 524ms

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 3
# End range of qubits: 3
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 3 Qbits
# 	• Time elapsed on creation: 655ms
# 	• RSS (Memory Usage): 223.69 MB
# 	• VMS (Memory Usage): 1.74 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 28                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  3s 332ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD4_TC5_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  236ms
#
# Display decomposition ToffoliDecompType.AN0_TD4_TC5_CX6 circuit:
# Time elapsed on displaying the circuit:  334ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 44                   | 16               | 80               | 26                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  3s 418ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 213ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD4_TC5_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 62.50% • Output vector: 37.50% )
#
# Time elapsed on simulation and comparison: 224ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 39.44% • Output vector: 60.56% )
#
# Time elapsed on simulation and comparison: 14h 0min 4s 341ms
#
# ======================================================================================================================================================

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ======================================================================================================================================================
#
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
#
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 39.44% • Output vector: 60.56% )
#
# Time elapsed on simulation and comparison: 22min 27s 462ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")
# Out:
# Rank: 18
# Loading stress experiment #1 of 2 with T gate indices: 53
#
#
# Rank: 31
# Loading stress experiment #1 of 2 with T gate indices: 79
#
#
# Rank: 14
# Loading stress experiment #1 of 3 with T gate indices: 43
#
#
# Rank: 23
# Loading stress experiment #1 of 2 with T gate indices: 63
#
#
# Rank: 8
# Loading stress experiment #1 of 3 with T gate indices: 25
#
#
# Rank: 1
# Loading stress experiment #1 of 3 with T gate indices: 4
#
#
# Rank: 22
# Loading stress experiment #1 of 2 with T gate indices: 61
#
#
# Rank: 26
# Loading stress experiment #1 of 2 with T gate indices: 69
#
#
# Rank: 17
# Loading stress experiment #1 of 2 with T gate indices: 51
#
#
# Rank: 0
# Loading stress experiment #1 of 3 with T gate indices: 1
#
#
# Rank: 30
# Loading stress experiment #1 of 2 with T gate indices: 77
#
#
# Rank: 7
# Loading stress experiment #1 of 3 with T gate indices: 22
#
#
# Rank: 4
# Loading stress experiment #1 of 3 with T gate indices: 13
#
#
# Rank: 15
# Loading stress experiment #1 of 3 with T gate indices: 46
#
#
# Rank: 21
# Loading stress experiment #1 of 2 with T gate indices: 59
#
#
# Rank: 5
# Loading stress experiment #1 of 3 with T gate indices: 16
#
#
# Rank: 19
# Loading stress experiment #1 of 2 with T gate indices: 55
#
#
# Rank: 13
# Loading stress experiment #1 of 3 with T gate indices: 40
#
#
# Rank: 29
# Loading stress experiment #1 of 2 with T gate indices: 75
#
#
# Rank: 27
# Loading stress experiment #1 of 2 with T gate indices: 71
#
#
# Rank: 16
# Loading stress experiment #1 of 2 with T gate indices: 49
#
#
# Rank: 12
# Loading stress experiment #1 of 3 with T gate indices: 37
#
#
# Rank: 11
# Loading stress experiment #1 of 3 with T gate indices: 34
#
#
# Rank: 10
# Loading stress experiment #1 of 3 with T gate indices: 31
#
#
# Rank: 2
# Loading stress experiment #1 of 3 with T gate indices: 7
#
#
# Rank: 24
# Loading stress experiment #1 of 2 with T gate indices: 65
#
#
# Rank: 25
# Loading stress experiment #1 of 2 with T gate indices: 67
#
#
# Rank: 28
# Loading stress experiment #1 of 2 with T gate indices: 73
#
#
# Rank: 9
# Loading stress experiment #1 of 3 with T gate indices: 28
#
#
# Rank: 3
# Loading stress experiment #1 of 3 with T gate indices: 10
#
#
# Rank: 6
# Loading stress experiment #1 of 3 with T gate indices: 19
#
#
# Rank: 20
# Loading stress experiment #1 of 2 with T gate indices: 57
#
#
# Rank: 21
# Completed stress experiment #1 of 2 with T gate indices: 59
# Time elapsed: 23h 4min 58s 309ms
#
#
# Rank: 21
# Loading stress experiment #2 of 2 with T gate indices: 60
#
#
# Rank: 29
# Completed stress experiment #1 of 2 with T gate indices: 75
# Time elapsed: 23h 11min 24s 677ms
#
#
# Rank: 29
# Loading stress experiment #2 of 2 with T gate indices: 76
#
#
# Rank: 26
# Completed stress experiment #1 of 2 with T gate indices: 69
# Time elapsed: 23h 12min 31s 867ms
#
#
# Rank: 26
# Loading stress experiment #2 of 2 with T gate indices: 70
#
#
# Rank: 16
# Completed stress experiment #1 of 2 with T gate indices: 49
# Time elapsed: 23h 12min 38s 408ms
#
#
# Rank: 16
# Loading stress experiment #2 of 2 with T gate indices: 50
#
#
# Rank: 7
# Completed stress experiment #1 of 3 with T gate indices: 22
# Time elapsed: 23h 13min 4s 97ms
#
#
# Rank: 7
# Loading stress experiment #2 of 3 with T gate indices: 23
#
#
# Rank: 28
# Completed stress experiment #1 of 2 with T gate indices: 73
# Time elapsed: 23h 13min 22s 490ms
#
#
# Rank: 28
# Loading stress experiment #2 of 2 with T gate indices: 74
#
#
# Rank: 10
# Completed stress experiment #1 of 3 with T gate indices: 31
# Time elapsed: 23h 14min 13s 994ms
#
#
# Rank: 10
# Loading stress experiment #2 of 3 with T gate indices: 32
#
#
# Rank: 30
# Completed stress experiment #1 of 2 with T gate indices: 77
# Time elapsed: 23h 14min 21s 804ms
#
#
# Rank: 30
# Loading stress experiment #2 of 2 with T gate indices: 78
#
#
# Rank: 1
# Completed stress experiment #1 of 3 with T gate indices: 4
# Time elapsed: 23h 14min 52s 735ms
#
#
# Rank: 1
# Loading stress experiment #2 of 3 with T gate indices: 5
#
#
# Rank: 12
# Completed stress experiment #1 of 3 with T gate indices: 37
# Time elapsed: 23h 15min 24s 857ms
#
#
# Rank: 12
# Loading stress experiment #2 of 3 with T gate indices: 38
#
#
# Rank: 2
# Completed stress experiment #1 of 3 with T gate indices: 7
# Time elapsed: 23h 15min 39s 582ms
#
#
# Rank: 2
# Loading stress experiment #2 of 3 with T gate indices: 8
#
#
# Rank: 31
# Completed stress experiment #1 of 2 with T gate indices: 79
# Time elapsed: 23h 15min 53s 970ms
#
#
# Rank: 31
# Loading stress experiment #2 of 2 with T gate indices: 80
#
#
# Rank: 9
# Completed stress experiment #1 of 3 with T gate indices: 28
# Time elapsed: 23h 16min 28s 545ms
#
#
# Rank: 9
# Loading stress experiment #2 of 3 with T gate indices: 29
#
#
# Rank: 25
# Completed stress experiment #1 of 2 with T gate indices: 67
# Time elapsed: 23h 16min 33s 82ms
#
#
# Rank: 25
# Loading stress experiment #2 of 2 with T gate indices: 68
#
#
# Rank: 3
# Completed stress experiment #1 of 3 with T gate indices: 10
# Time elapsed: 23h 17min 4s 444ms
#
#
# Rank: 3
# Loading stress experiment #2 of 3 with T gate indices: 11
#
#
# Rank: 27
# Completed stress experiment #1 of 2 with T gate indices: 71
# Time elapsed: 23h 17min 36s 908ms
#
#
# Rank: 27
# Loading stress experiment #2 of 2 with T gate indices: 72
#
#
# Rank: 8
# Completed stress experiment #1 of 3 with T gate indices: 25
# Time elapsed: 23h 17min 44s 509ms
#
#
# Rank: 8
# Loading stress experiment #2 of 3 with T gate indices: 26
#
#
# Rank: 18
# Completed stress experiment #1 of 2 with T gate indices: 53
# Time elapsed: 23h 17min 46s 194ms
#
#
# Rank: 18
# Loading stress experiment #2 of 2 with T gate indices: 54
#
#
# Rank: 19
# Completed stress experiment #1 of 2 with T gate indices: 55
# Time elapsed: 23h 17min 47s 566ms
#
#
# Rank: 19
# Loading stress experiment #2 of 2 with T gate indices: 56
#
#
# Rank: 15
# Completed stress experiment #1 of 3 with T gate indices: 46
# Time elapsed: 23h 18min 8s 963ms
#
#
# Rank: 15
# Loading stress experiment #2 of 3 with T gate indices: 47
#
#
# Rank: 17
# Completed stress experiment #1 of 2 with T gate indices: 51
# Time elapsed: 23h 18min 11s 425ms
#
#
# Rank: 17
# Loading stress experiment #2 of 2 with T gate indices: 52
#
#
# Rank: 14
# Completed stress experiment #1 of 3 with T gate indices: 43
# Time elapsed: 23h 18min 27s 35ms
#
#
# Rank: 14
# Loading stress experiment #2 of 3 with T gate indices: 44
#
#
# Rank: 20
# Completed stress experiment #1 of 2 with T gate indices: 57
# Time elapsed: 23h 18min 59s 845ms
#
#
# Rank: 20
# Loading stress experiment #2 of 2 with T gate indices: 58
#
#
# Rank: 6
# Completed stress experiment #1 of 3 with T gate indices: 19
# Time elapsed: 23h 19min 8s 666ms
#
#
# Rank: 6
# Loading stress experiment #2 of 3 with T gate indices: 20
#
#
# Rank: 0
# Completed stress experiment #1 of 3 with T gate indices: 1
# Time elapsed: 23h 19min 19s 424ms
#
#
# Rank: 0
# Loading stress experiment #2 of 3 with T gate indices: 2
#
#
# Rank: 13
# Completed stress experiment #1 of 3 with T gate indices: 40
# Time elapsed: 23h 20min 40s 407ms
#
#
# Rank: 13
# Loading stress experiment #2 of 3 with T gate indices: 41
#
#
# Rank: 23
# Completed stress experiment #1 of 2 with T gate indices: 63
# Time elapsed: 23h 20min 51s 114ms
#
#
# Rank: 23
# Loading stress experiment #2 of 2 with T gate indices: 64
#
#
# Rank: 5
# Completed stress experiment #1 of 3 with T gate indices: 16
# Time elapsed: 23h 23min 39s 324ms
#
#
# Rank: 5
# Loading stress experiment #2 of 3 with T gate indices: 17
#
#
# Rank: 24
# Completed stress experiment #1 of 2 with T gate indices: 65
# Time elapsed: 23h 23min 45s 556ms
#
#
# Rank: 24
# Loading stress experiment #2 of 2 with T gate indices: 66
#
#
# Rank: 11
# Completed stress experiment #1 of 3 with T gate indices: 34
# Time elapsed: 23h 25min 33s 200ms
#
#
# Rank: 11
# Loading stress experiment #2 of 3 with T gate indices: 35
#
#
# Rank: 4
# Completed stress experiment #1 of 3 with T gate indices: 13
# Time elapsed: 23h 28min 47s 218ms
#
#
# Rank: 4
# Loading stress experiment #2 of 3 with T gate indices: 14
#
#
# Rank: 22
# Completed stress experiment #1 of 2 with T gate indices: 61
# Time elapsed: 23h 31min 56s 128ms
#
#
# Rank: 22
# Loading stress experiment #2 of 2 with T gate indices: 62
#
#
# Rank: 21
# Completed stress experiment #2 of 2 with T gate indices: 60
# Time elapsed: 23h 5min 33s 780ms
#
#
# Rank: 29
# Completed stress experiment #2 of 2 with T gate indices: 76
# Time elapsed: 23h 12min 0s 913ms
#
#
# Rank: 26
# Completed stress experiment #2 of 2 with T gate indices: 70
# Time elapsed: 23h 13min 13s 349ms
#
#
# Rank: 16
# Completed stress experiment #2 of 2 with T gate indices: 50
# Time elapsed: 23h 14min 1s 846ms
#
#
# Rank: 7
# Completed stress experiment #2 of 3 with T gate indices: 23
# Time elapsed: 23h 13min 39s 759ms
#
#
# Rank: 7
# Loading stress experiment #3 of 3 with T gate indices: 24
#
#
# Rank: 28
# Completed stress experiment #2 of 2 with T gate indices: 74
# Time elapsed: 23h 13min 45s 962ms
#
#
# Rank: 10
# Completed stress experiment #2 of 3 with T gate indices: 32
# Time elapsed: 23h 13min 57s 332ms
#
#
# Rank: 10
# Loading stress experiment #3 of 3 with T gate indices: 33
#
#
# Rank: 30
# Completed stress experiment #2 of 2 with T gate indices: 78
# Time elapsed: 23h 14min 35s 631ms
#
#
# Rank: 1
# Completed stress experiment #2 of 3 with T gate indices: 5
# Time elapsed: 23h 15min 14s 56ms
#
#
# Rank: 1
# Loading stress experiment #3 of 3 with T gate indices: 6
#
#
# Rank: 12
# Completed stress experiment #2 of 3 with T gate indices: 38
# Time elapsed: 23h 16min 11s 518ms
#
#
# Rank: 12
# Loading stress experiment #3 of 3 with T gate indices: 39
#
#
# Rank: 9
# Completed stress experiment #2 of 3 with T gate indices: 29
# Time elapsed: 23h 15min 28s 43ms
#
#
# Rank: 9
# Loading stress experiment #3 of 3 with T gate indices: 30
#
#
# Rank: 2
# Completed stress experiment #2 of 3 with T gate indices: 8
# Time elapsed: 23h 16min 34s 483ms
#
#
# Rank: 2
# Loading stress experiment #3 of 3 with T gate indices: 9
#
#
# Rank: 31
# Completed stress experiment #2 of 2 with T gate indices: 80
# Time elapsed: 23h 17min 0s 577ms
#
#
# Rank: 25
# Completed stress experiment #2 of 2 with T gate indices: 68
# Time elapsed: 23h 17min 42s 252ms
#
#
# Rank: 3
# Completed stress experiment #2 of 3 with T gate indices: 11
# Time elapsed: 23h 17min 13s 181ms
#
#
# Rank: 3
# Loading stress experiment #3 of 3 with T gate indices: 12
#
#
# Rank: 18
# Completed stress experiment #2 of 2 with T gate indices: 54
# Time elapsed: 23h 16min 40s 994ms
#
#
# Rank: 27
# Completed stress experiment #2 of 2 with T gate indices: 72
# Time elapsed: 23h 17min 15s 162ms
#
#
# Rank: 8
# Completed stress experiment #2 of 3 with T gate indices: 26
# Time elapsed: 23h 18min 0s 608ms
#
#
# Rank: 8
# Loading stress experiment #3 of 3 with T gate indices: 27
#
#
# Rank: 19
# Completed stress experiment #2 of 2 with T gate indices: 56
# Time elapsed: 23h 18min 16s 36ms
#
#
# Rank: 17
# Completed stress experiment #2 of 2 with T gate indices: 52
# Time elapsed: 23h 18min 54s 502ms
#
#
# Rank: 6
# Completed stress experiment #2 of 3 with T gate indices: 20
# Time elapsed: 23h 18min 5s 937ms
#
#
# Rank: 6
# Loading stress experiment #3 of 3 with T gate indices: 21
#
#
# Rank: 14
# Completed stress experiment #2 of 3 with T gate indices: 44
# Time elapsed: 23h 18min 47s 581ms
#
#
# Rank: 14
# Loading stress experiment #3 of 3 with T gate indices: 45
#
#
# Rank: 15
# Completed stress experiment #2 of 3 with T gate indices: 47
# Time elapsed: 23h 19min 15s 713ms
#
#
# Rank: 15
# Loading stress experiment #3 of 3 with T gate indices: 48
#
#
# Rank: 20
# Completed stress experiment #2 of 2 with T gate indices: 58
# Time elapsed: 23h 18min 29s 179ms
#
#
# Rank: 0
# Completed stress experiment #2 of 3 with T gate indices: 2
# Time elapsed: 23h 19min 41s 789ms
#
#
# Rank: 0
# Loading stress experiment #3 of 3 with T gate indices: 3
#
#
# Rank: 13
# Completed stress experiment #2 of 3 with T gate indices: 41
# Time elapsed: 23h 19min 54s 880ms
#
#
# Rank: 13
# Loading stress experiment #3 of 3 with T gate indices: 42
#
#
# Rank: 23
# Completed stress experiment #2 of 2 with T gate indices: 64
# Time elapsed: 23h 21min 27s 57ms
#
#
# Rank: 5
# Completed stress experiment #2 of 3 with T gate indices: 17
# Time elapsed: 23h 23min 40s 805ms
#
#
# Rank: 5
# Loading stress experiment #3 of 3 with T gate indices: 18
#
#
# Rank: 24
# Completed stress experiment #2 of 2 with T gate indices: 66
# Time elapsed: 23h 25min 57s 519ms
#
#
# Rank: 11
# Completed stress experiment #2 of 3 with T gate indices: 35
# Time elapsed: 23h 24min 38s 200ms
#
#
# Rank: 11
# Loading stress experiment #3 of 3 with T gate indices: 36
#
#
# Rank: 4
# Completed stress experiment #2 of 3 with T gate indices: 14
# Time elapsed: 23h 29min 11s 693ms
#
#
# Rank: 4
# Loading stress experiment #3 of 3 with T gate indices: 15
#
#
# Rank: 22
# Completed stress experiment #2 of 2 with T gate indices: 62
# Time elapsed: 23h 32min 27s 445ms
#
#
# Rank: 7
# Completed stress experiment #3 of 3 with T gate indices: 24
# Time elapsed: 23h 13min 42s 693ms
#
#
# Rank: 10
# Completed stress experiment #3 of 3 with T gate indices: 33
# Time elapsed: 23h 13min 36s 900ms
#
#
# Rank: 1
# Completed stress experiment #3 of 3 with T gate indices: 6
# Time elapsed: 23h 15min 36s 514ms
#
#
# Rank: 9
# Completed stress experiment #3 of 3 with T gate indices: 30
# Time elapsed: 23h 15min 38s 629ms
#
#
# Rank: 12
# Completed stress experiment #3 of 3 with T gate indices: 39
# Time elapsed: 23h 16min 3s 194ms
#
#
# Rank: 2
# Completed stress experiment #3 of 3 with T gate indices: 9
# Time elapsed: 23h 17min 15s 36ms
#
#
# Rank: 3
# Completed stress experiment #3 of 3 with T gate indices: 12
# Time elapsed: 23h 17min 9s 680ms
#
#
# Rank: 8
# Completed stress experiment #3 of 3 with T gate indices: 27
# Time elapsed: 23h 17min 14s 275ms
#
#
# Rank: 6
# Completed stress experiment #3 of 3 with T gate indices: 21
# Time elapsed: 23h 17min 57s 272ms
#
#
# Rank: 15
# Completed stress experiment #3 of 3 with T gate indices: 48
# Time elapsed: 23h 19min 7s 192ms
#
#
# Rank: 14
# Completed stress experiment #3 of 3 with T gate indices: 45
# Time elapsed: 23h 20min 6s 966ms
#
#
# Rank: 0
# Completed stress experiment #3 of 3 with T gate indices: 3
# Time elapsed: 23h 19min 31s 732ms
#
#
# Rank: 13
# Completed stress experiment #3 of 3 with T gate indices: 42
# Time elapsed: 23h 20min 17s 323ms
#
#
# Rank: 5
# Completed stress experiment #3 of 3 with T gate indices: 18
# Time elapsed: 23h 24min 13s 344ms
#
#
# Rank: 11
# Completed stress experiment #3 of 3 with T gate indices: 36
# Time elapsed: 23h 25min 44s 185ms
#
#
# Rank: 4
# Completed stress experiment #3 of 3 with T gate indices: 15
# Time elapsed: 23h 29min 8s 540ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 7.35              | 92.65             | 26.49             | 66.15             |
# | 2                | 7.24              | 92.76             | 26.57             | 66.19             |
# | 3                | 7.47              | 92.53             | 26.42             | 66.11             |
# | 4                | 7.25              | 92.75             | 26.56             | 66.19             |
# | 5                | 7.28              | 92.72             | 26.55             | 66.17             |
# | 6                | 7.34              | 92.66             | 26.50             | 66.15             |
# | 7                | 7.26              | 92.74             | 25.97             | 66.77             |
# | 8                | 7.24              | 92.76             | 26.00             | 66.77             |
# | 9                | 7.31              | 92.69             | 25.92             | 66.77             |
# | 10               | 7.34              | 92.66             | 25.93             | 66.72             |
# | 11               | 7.35              | 92.65             | 25.93             | 66.72             |
# | 12               | 7.25              | 92.75             | 25.98             | 66.76             |
# | 13               | 7.46              | 92.54             | 26.42             | 66.13             |
# | 14               | 7.40              | 92.60             | 26.48             | 66.12             |
# | 15               | 7.46              | 92.54             | 25.85             | 66.70             |
# | 16               | 7.33              | 92.67             | 25.94             | 66.73             |
# | 17               | 7.34              | 92.66             | 26.52             | 66.14             |
# | 18               | 7.26              | 92.74             | 26.55             | 66.18             |
# | 19               | 7.40              | 92.60             | 26.44             | 66.15             |
# | 20               | 7.41              | 92.59             | 26.48             | 66.11             |
# | 21               | 7.40              | 92.60             | 25.91             | 66.69             |
# | 22               | 7.46              | 92.54             | 25.83             | 66.71             |
# | 23               | 7.48              | 92.52             | 25.83             | 66.69             |
# | 24               | 7.39              | 92.61             | 25.85             | 66.76             |
# | 25               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 26               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 27               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 28               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 29               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 30               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 31               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 32               | 0.00              | 100.00            | 39.72             | 60.28             |
# | 33               | 14.70             | 85.30             | 26.51             | 58.80             |
# | 34               | 14.56             | 85.44             | 26.47             | 58.97             |
# | 35               | 14.56             | 85.44             | 26.47             | 58.97             |
# | 36               | 14.56             | 85.44             | 26.47             | 58.97             |
# | 37               | 14.90             | 85.10             | 26.37             | 58.73             |
# | 38               | 14.90             | 85.10             | 26.37             | 58.73             |
# | 39               | 14.90             | 85.10             | 26.37             | 58.73             |
# | 40               | 14.57             | 85.43             | 26.59             | 58.84             |
# | 41               | 14.57             | 85.43             | 26.03             | 59.40             |
# | 42               | 14.57             | 85.43             | 26.03             | 59.40             |
# | 43               | 14.43             | 85.57             | 25.97             | 59.60             |
# | 44               | 14.43             | 85.57             | 25.97             | 59.60             |
# | 45               | 14.43             | 85.57             | 25.97             | 59.60             |
# | 46               | 14.55             | 85.45             | 25.92             | 59.53             |
# | 47               | 14.55             | 85.45             | 25.92             | 59.53             |
# | 48               | 14.55             | 85.45             | 25.92             | 59.53             |
# | 49               | 14.68             | 85.32             | 25.94             | 59.38             |
# | 50               | 14.68             | 85.32             | 25.94             | 59.38             |
# | 51               | 14.52             | 85.48             | 25.94             | 59.54             |
# | 52               | 14.52             | 85.48             | 25.94             | 59.54             |
# | 53               | 14.63             | 85.37             | 25.94             | 59.42             |
# | 54               | 14.63             | 85.37             | 25.94             | 59.42             |
# | 55               | 14.51             | 85.49             | 26.03             | 59.47             |
# | 56               | 14.51             | 85.49             | 26.03             | 59.47             |
# | 57               | 7.19              | 92.81             | 26.61             | 66.20             |
# | 58               | 7.36              | 92.64             | 26.49             | 66.15             |
# | 59               | 7.31              | 92.69             | 26.53             | 66.16             |
# | 60               | 7.31              | 92.69             | 26.52             | 66.17             |
# | 61               | 7.27              | 92.73             | 25.94             | 66.79             |
# | 62               | 7.41              | 92.59             | 25.86             | 66.73             |
# | 63               | 7.52              | 92.48             | 25.83             | 66.65             |
# | 64               | 7.37              | 92.63             | 25.91             | 66.72             |
# | 65               | 7.49              | 92.51             | 26.42             | 66.09             |
# | 66               | 7.33              | 92.67             | 26.50             | 66.17             |
# | 67               | 7.39              | 92.61             | 25.88             | 66.72             |
# | 68               | 7.27              | 92.73             | 25.98             | 66.76             |
# | 69               | 7.27              | 92.73             | 26.55             | 66.18             |
# | 70               | 7.36              | 92.64             | 26.52             | 66.12             |
# | 71               | 7.32              | 92.68             | 26.53             | 66.15             |
# | 72               | 7.34              | 92.66             | 26.50             | 66.16             |
# | 73               | 7.33              | 92.67             | 26.50             | 66.17             |
# | 74               | 7.35              | 92.65             | 26.49             | 66.16             |
# | 75               | 7.28              | 92.72             | 25.96             | 66.77             |
# | 76               | 7.28              | 92.72             | 25.96             | 66.76             |
# | 77               | 7.50              | 92.50             | 25.80             | 66.70             |
# | 78               | 7.14              | 92.86             | 26.04             | 66.82             |
# | 79               | 7.31              | 92.69             | 25.94             | 66.74             |
# | 80               | 7.31              | 92.69             | 25.92             | 66.77             |
#
#
# Time elapsed for stress testing 80 unique combinations: 2d 22h 27min 9s 65ms

# %% [markdown]
# ## Bilan comparing the QRAM circuit Query AN0_TD4_TC5_CX6 WITH the QRAM circuit Query AN0_TD4_TC7_CX6

# %%
make_slurm("bilan", "2-10", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 10
#
# ================================================
#
#
# Loading bilan done
#
#
# Bilan of the experiment:
#
# Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 201ms                      | 207.33 MB              | 1.13 GB                |
# | 3                | 437ms                      | 207.87 MB              | 1.13 GB                |
# | 4                | 1s 177ms                   | 208.61 MB              | 1.13 GB                |
# | 5                | 3s 582ms                   | 209.80 MB              | 1.13 GB                |
# | 6                | 13s 77ms                   | 212.01 MB              | 1.13 GB                |
# | 7                | 53s 401ms                  | 216.29 MB              | 1.13 GB                |
# | 8                | 4min 8s 754ms              | 224.25 MB              | 1.14 GB                |
# | 9                | 24min 42s 142ms            | 240.29 MB              | 1.15 GB                |
# | 10               | 2h 53min 37s 932ms         | 273.32 MB              | 1.16 GB                |
#
#
# Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
# | 7                | 264              | 93                   | 33               | 1776             | 506               |
# | 8                | 521              | 105                  | 37               | 3568             | 1018              |
# | 9                | 1034             | 117                  | 41               | 7152             | 2042              |
# | 10               | 2059             | 129                  | 45               | 14320            | 4090              |
#
#
# Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 32                   | 12               | 32               | 10                |
# | 3                | 20               | 44                   | 16               | 80               | 26                |
# | 4                | 37               | 56                   | 20               | 176              | 58                |
# | 5                | 70               | 68                   | 24               | 368              | 122               |
# | 6                | 135              | 80                   | 28               | 752              | 250               |
# | 7                | 264              | 92                   | 32               | 1520             | 506               |
# | 8                | 521              | 104                  | 36               | 3056             | 1018              |
# | 9                | 1034             | 116                  | 40               | 6128             | 2042              |
# | 10               | 2059             | 128                  | 44               | 12272            | 4090              |
#
#
# Comparing bilans
#
# T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded (%) | T Count Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 32  ( 80.00 )      | 8  ( 20.00 )           |
# | 3                | 96                 | 80  ( 83.33 )      | 16  ( 16.67 )          |
# | 4                | 208                | 176  ( 84.62 )     | 32  ( 15.38 )          |
# | 5                | 432                | 368  ( 85.19 )     | 64  ( 14.81 )          |
# | 6                | 880                | 752  ( 85.45 )     | 128  ( 14.55 )         |
# | 7                | 1776               | 1520  ( 85.59 )    | 256  ( 14.41 )         |
# | 8                | 3568               | 3056  ( 85.65 )    | 512  ( 14.35 )         |
# | 9                | 7152               | 6128  ( 85.68 )    | 1024  ( 14.32 )        |
# | 10               | 14320              | 12272  ( 85.70 )   | 2048  ( 14.30 )        |
#
#
# T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded (%) | T Depth Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 12  ( 92.31 )      | 1  ( 7.69 )            |
# | 3                | 17                 | 16  ( 94.12 )      | 1  ( 5.88 )            |
# | 4                | 21                 | 20  ( 95.24 )      | 1  ( 4.76 )            |
# | 5                | 25                 | 24  ( 96.00 )      | 1  ( 4.00 )            |
# | 6                | 29                 | 28  ( 96.55 )      | 1  ( 3.45 )            |
# | 7                | 33                 | 32  ( 96.97 )      | 1  ( 3.03 )            |
# | 8                | 37                 | 36  ( 97.30 )      | 1  ( 2.70 )            |
# | 9                | 41                 | 40  ( 97.56 )      | 1  ( 2.44 )            |
# | 10               | 45                 | 44  ( 97.78 )      | 1  ( 2.22 )            |
#
#
# Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded (%)   | Depth Cancelled (%)    |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 32  ( 96.97 )      | 1  ( 3.03 )            |
# | 3                | 45                 | 44  ( 97.78 )      | 1  ( 2.22 )            |
# | 4                | 57                 | 56  ( 98.25 )      | 1  ( 1.75 )            |
# | 5                | 69                 | 68  ( 98.55 )      | 1  ( 1.45 )            |
# | 6                | 81                 | 80  ( 98.77 )      | 1  ( 1.23 )            |
# | 7                | 93                 | 92  ( 98.92 )      | 1  ( 1.08 )            |
# | 8                | 105                | 104  ( 99.05 )     | 1  ( 0.95 )            |
# | 9                | 117                | 116  ( 99.15 )     | 1  ( 0.85 )            |
# | 10               | 129                | 128  ( 99.22 )     | 1  ( 0.78 )            |
