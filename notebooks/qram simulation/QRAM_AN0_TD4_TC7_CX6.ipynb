# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD4_TC7_CX6 for Query

# %%
import sys

sys.path.append('../..')

from main_experiments import main
from make import *

t_count = 7

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--simulate', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d', '--print-simulation=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Display
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate specific measurement: qram qubits
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time elapsed on displaying the circuit:  69ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)
#
# Time elapsed on simulation and comparison: 292ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  42ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)	( Measurements: 1 (12.50 %) • Output vector: 7 (87.50 %) )
#
# Time elapsed on simulation and comparison: 301ms
#
#
# Simulating the circuit ... Checking the QRAM logic and measure only the target qubit ...
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  216ms
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  262ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |       1584       |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 16 (100.00 %)
#
# Time elapsed on simulation and comparison: 699ms
#
# ======================================================================================================================================================
# 0

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# Rank: 0
# Loading stress experiment #1 of 1 with T gate indices: 1
#
#
# Rank: 7
# Loading stress experiment #1 of 1 with T gate indices: 8
#
#
# Rank: 36
# Loading stress experiment #1 of 1 with T gate indices: 37
#
#
# Rank: 29
# Loading stress experiment #1 of 1 with T gate indices: 30
#
#
# Rank: 24
# Loading stress experiment #1 of 1 with T gate indices: 25
#
#
# Rank: 3
# Loading stress experiment #1 of 1 with T gate indices: 4
#
#
# Rank: 17
# Loading stress experiment #1 of 1 with T gate indices: 18
#
#
# Rank: 11
# Loading stress experiment #1 of 1 with T gate indices: 12
#
#
# Rank: 20
# Loading stress experiment #1 of 1 with T gate indices: 21
#
#
# Rank: 21
# Loading stress experiment #1 of 1 with T gate indices: 22
#
#
# Rank: 12
# Loading stress experiment #1 of 1 with T gate indices: 13
#
#
# Rank: 19
# Loading stress experiment #1 of 1 with T gate indices: 20
#
#
# Rank: 25
# Loading stress experiment #1 of 1 with T gate indices: 26
#
#
# Rank: 23
# Loading stress experiment #1 of 1 with T gate indices: 24
#
#
# Rank: 4
# Loading stress experiment #1 of 1 with T gate indices: 5
#
#
# Rank: 8
# Loading stress experiment #1 of 1 with T gate indices: 9
#
#
# Rank: 10
# Loading stress experiment #1 of 1 with T gate indices: 11
#
#
# Rank: 13
# Loading stress experiment #1 of 1 with T gate indices: 14
#
#
# Rank: 35
# Loading stress experiment #1 of 1 with T gate indices: 36
#
#
# Rank: 0
# Completed stress experiment #1 of 1 with T gate indices: 1
# Time elapsed: 326ms
#
#
# Rank: 36
# Completed stress experiment #1 of 1 with T gate indices: 37
# Time elapsed: 326ms
#
#
# Rank: 7
# Completed stress experiment #1 of 1 with T gate indices: 8
# Time elapsed: 328ms
#
#
# Rank: 24
# Completed stress experiment #1 of 1 with T gate indices: 25
# Time elapsed: 337ms
#
#
# Rank: 3
# Completed stress experiment #1 of 1 with T gate indices: 4
# Time elapsed: 343ms
#
#
# Rank: 17
# Completed stress experiment #1 of 1 with T gate indices: 18
# Time elapsed: 361ms
#
#
# Rank: 11
# Completed stress experiment #1 of 1 with T gate indices: 12
# Time elapsed: 364ms
#
#
# Rank: 32
# Loading stress experiment #1 of 1 with T gate indices: 33
#
#
# Rank: 37
# Loading stress experiment #1 of 1 with T gate indices: 38
#
#
# Rank: 20
# Completed stress experiment #1 of 1 with T gate indices: 21
# Time elapsed: 385ms
#
#
# Rank: 21
# Completed stress experiment #1 of 1 with T gate indices: 22
# Time elapsed: 389ms
#
#
# Rank: 12
# Completed stress experiment #1 of 1 with T gate indices: 13
# Time elapsed: 431ms
#
#
# Rank: 25
# Completed stress experiment #1 of 1 with T gate indices: 26
# Time elapsed: 438ms
#
#
# Rank: 19
# Completed stress experiment #1 of 1 with T gate indices: 20
# Time elapsed: 440ms
#
#
# Rank: 33
# Loading stress experiment #1 of 1 with T gate indices: 34
#
#
# Rank: 14
# Loading stress experiment #1 of 1 with T gate indices: 15
#
#
# Rank: 29
# Completed stress experiment #1 of 1 with T gate indices: 30
# Time elapsed: 470ms
#
#
# Rank: 4
# Completed stress experiment #1 of 1 with T gate indices: 5
# Time elapsed: 478ms
#
#
# Rank: 23
# Completed stress experiment #1 of 1 with T gate indices: 24
# Time elapsed: 483ms
#
#
# Rank: 8
# Completed stress experiment #1 of 1 with T gate indices: 9
# Time elapsed: 542ms
#
#
# Rank: 10
# Completed stress experiment #1 of 1 with T gate indices: 11
# Time elapsed: 549ms
#
#
# Rank: 34
# Loading stress experiment #1 of 1 with T gate indices: 35
#
#
# Rank: 28
# Loading stress experiment #1 of 1 with T gate indices: 29
#
#
# Rank: 35
# Completed stress experiment #1 of 1 with T gate indices: 36
# Time elapsed: 612ms
#
#
# Rank: 13
# Completed stress experiment #1 of 1 with T gate indices: 14
# Time elapsed: 613ms
#
#
# Rank: 9
# Loading stress experiment #1 of 1 with T gate indices: 10
#
#
# Rank: 5
# Loading stress experiment #1 of 1 with T gate indices: 6
#
#
# Rank: 37
# Completed stress experiment #1 of 1 with T gate indices: 38
# Time elapsed: 695ms
#
#
# Rank: 32
# Completed stress experiment #1 of 1 with T gate indices: 33
# Time elapsed: 699ms
#
#
# Rank: 6
# Loading stress experiment #1 of 1 with T gate indices: 7
#
#
# Rank: 30
# Loading stress experiment #1 of 1 with T gate indices: 31
#
#
# Rank: 33
# Completed stress experiment #1 of 1 with T gate indices: 34
# Time elapsed: 784ms
#
#
# Rank: 14
# Completed stress experiment #1 of 1 with T gate indices: 15
# Time elapsed: 784ms
#
#
# Rank: 2
# Loading stress experiment #1 of 1 with T gate indices: 3
#
#
# Rank: 38
# Loading stress experiment #1 of 1 with T gate indices: 39
#
#
# Rank: 28
# Completed stress experiment #1 of 1 with T gate indices: 29
# Time elapsed: 877ms
#
#
# Rank: 34
# Completed stress experiment #1 of 1 with T gate indices: 35
# Time elapsed: 892ms
#
#
# Rank: 16
# Loading stress experiment #1 of 1 with T gate indices: 17
#
#
# Rank: 5
# Completed stress experiment #1 of 1 with T gate indices: 6
# Time elapsed: 986ms
#
#
# Rank: 9
# Completed stress experiment #1 of 1 with T gate indices: 10
# Time elapsed: 996ms
#
#
# Rank: 26
# Loading stress experiment #1 of 1 with T gate indices: 27
#
#
# Rank: 30
# Completed stress experiment #1 of 1 with T gate indices: 31
# Time elapsed: 1s 82ms
#
#
# Rank: 6
# Completed stress experiment #1 of 1 with T gate indices: 7
# Time elapsed: 1s 85ms
#
#
# Rank: 27
# Loading stress experiment #1 of 1 with T gate indices: 28
#
#
# Rank: 38
# Completed stress experiment #1 of 1 with T gate indices: 39
# Time elapsed: 1s 186ms
#
#
# Rank: 2
# Completed stress experiment #1 of 1 with T gate indices: 3
# Time elapsed: 1s 188ms
#
#
# Rank: 39
# Loading stress experiment #1 of 1 with T gate indices: 40
#
#
# Rank: 16
# Completed stress experiment #1 of 1 with T gate indices: 17
# Time elapsed: 1s 292ms
#
#
# Rank: 22
# Loading stress experiment #1 of 1 with T gate indices: 23
#
#
# Rank: 26
# Completed stress experiment #1 of 1 with T gate indices: 27
# Time elapsed: 1s 392ms
#
#
# Rank: 18
# Loading stress experiment #1 of 1 with T gate indices: 19
#
#
# Rank: 27
# Completed stress experiment #1 of 1 with T gate indices: 28
# Time elapsed: 1s 489ms
#
#
# Rank: 1
# Loading stress experiment #1 of 1 with T gate indices: 2
#
#
# Rank: 39
# Completed stress experiment #1 of 1 with T gate indices: 40
# Time elapsed: 1s 596ms
#
#
# Rank: 31
# Loading stress experiment #1 of 1 with T gate indices: 32
#
#
# Rank: 22
# Completed stress experiment #1 of 1 with T gate indices: 23
# Time elapsed: 1s 694ms
#
#
# Rank: 15
# Loading stress experiment #1 of 1 with T gate indices: 16
#
#
# Rank: 18
# Completed stress experiment #1 of 1 with T gate indices: 19
# Time elapsed: 1s 796ms
#
#
# Rank: 1
# Completed stress experiment #1 of 1 with T gate indices: 2
# Time elapsed: 1s 897ms
#
#
# Rank: 31
# Completed stress experiment #1 of 1 with T gate indices: 32
# Time elapsed: 1s 990ms
#
#
# Rank: 15
# Completed stress experiment #1 of 1 with T gate indices: 16
# Time elapsed: 2s 92ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 2                | 12.50             | 87.50             | 0.00              | 87.50             |
# | 3                | 0.00              | 100.00            | 6.25              | 93.75             |
# | 4                | 0.00              | 100.00            | 6.25              | 93.75             |
# | 5                | 0.00              | 100.00            | 6.25              | 93.75             |
# | 6                | 0.00              | 100.00            | 6.25              | 93.75             |
# | 7                | 12.50             | 87.50             | 0.00              | 87.50             |
# | 8                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 9                | 12.50             | 87.50             | 0.00              | 87.50             |
# | 10               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 11               | 12.50             | 87.50             | 0.00              | 87.50             |
# | 12               | 12.50             | 87.50             | 0.00              | 87.50             |
# | 13               | 0.00              | 100.00            | 31.25             | 68.75             |
# | 14               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 15               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 16               | 0.00              | 100.00            | 6.25              | 93.75             |
# | 17               | 0.00              | 100.00            | 37.50             | 62.50             |
# | 18               | 0.00              | 100.00            | 31.25             | 68.75             |
# | 19               | 0.00              | 100.00            | 31.25             | 68.75             |
# | 20               | 0.00              | 100.00            | 12.50             | 87.50             |
# | 21               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 22               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 23               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 24               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 25               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 26               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 27               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 28               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 29               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 30               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 31               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 32               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 33               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 34               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 35               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 36               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 37               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 38               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 39               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 40               | 0.00              | 100.00            | 0.00              | 100.00            |
#
#
# Time elapsed for stress testing 40 unique combinations: 4s 550ms

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--simulate', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d', '--print-simulation=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Display
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate specific measurement: qram qubits
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time elapsed on displaying the circuit:  61ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)
#
# Time elapsed on simulation and comparison: 309ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  41ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)	( Measurements: 1 (12.50 %) • Output vector: 7 (87.50 %) )
#
# Time elapsed on simulation and comparison: 259ms
#
#
# Simulating the circuit ... Checking the QRAM logic and measure only the target qubit ...
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  467ms
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  544ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |      918272      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 32 (100.00 %)
#
# Time elapsed on simulation and comparison: 12s 489ms
#
# ======================================================================================================================================================
# 0

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")
# Out:
# Rank: 0
# Loading stress experiment #1 of 2 with T gate indices: 1
#
#
# Rank: 11
# Loading stress experiment #1 of 2 with T gate indices: 23
#
#
# Rank: 40
# Loading stress experiment #1 of 1 with T gate indices: 73
#
#
# Rank: 20
# Loading stress experiment #1 of 2 with T gate indices: 41
#
#
# Rank: 62
# Loading stress experiment #1 of 1 with T gate indices: 95
#
#
# Rank: 19
# Loading stress experiment #1 of 2 with T gate indices: 39
#
#
# Rank: 52
# Loading stress experiment #1 of 1 with T gate indices: 85
#
#
# Rank: 49
# Loading stress experiment #1 of 1 with T gate indices: 82
#
#
# Rank: 6
# Loading stress experiment #1 of 2 with T gate indices: 13
#
#
# Rank: 46
# Loading stress experiment #1 of 1 with T gate indices: 79
#
#
# Rank: 37
# Loading stress experiment #1 of 1 with T gate indices: 70
#
#
# Rank: 16
# Loading stress experiment #1 of 2 with T gate indices: 33
#
#
# Rank: 47
# Loading stress experiment #1 of 1 with T gate indices: 80
#
#
# Rank: 24
# Loading stress experiment #1 of 2 with T gate indices: 49
#
#
# Rank: 59
# Loading stress experiment #1 of 1 with T gate indices: 92
#
#
# Rank: 17
# Loading stress experiment #1 of 2 with T gate indices: 35
#
#
# Rank: 42
# Loading stress experiment #1 of 1 with T gate indices: 75
#
#
# Rank: 45
# Loading stress experiment #1 of 1 with T gate indices: 78
#
#
# Rank: 22
# Loading stress experiment #1 of 2 with T gate indices: 45
#
#
# Rank: 4
# Loading stress experiment #1 of 2 with T gate indices: 9
#
#
# Rank: 61
# Loading stress experiment #1 of 1 with T gate indices: 94
#
#
# Rank: 33
# Loading stress experiment #1 of 1 with T gate indices: 66
#
#
# Rank: 15
# Loading stress experiment #1 of 2 with T gate indices: 31
#
#
# Rank: 58
# Loading stress experiment #1 of 1 with T gate indices: 91
#
#
# Rank: 55
# Loading stress experiment #1 of 1 with T gate indices: 88
#
#
# Rank: 2
# Loading stress experiment #1 of 2 with T gate indices: 5
#
#
# Rank: 30
# Loading stress experiment #1 of 2 with T gate indices: 61
#
#
# Rank: 13
# Loading stress experiment #1 of 2 with T gate indices: 27
#
#
# Rank: 21
# Loading stress experiment #1 of 2 with T gate indices: 43
#
#
# Rank: 31
# Loading stress experiment #1 of 2 with T gate indices: 63
#
#
# Rank: 29
# Loading stress experiment #1 of 2 with T gate indices: 59
#
#
# Rank: 35
# Loading stress experiment #1 of 1 with T gate indices: 68
#
#
# Rank: 7
# Loading stress experiment #1 of 2 with T gate indices: 15
#
#
# Rank: 53
# Loading stress experiment #1 of 1 with T gate indices: 86
#
#
# Rank: 44
# Loading stress experiment #1 of 1 with T gate indices: 77
#
#
# Rank: 56
# Loading stress experiment #1 of 1 with T gate indices: 89
#
#
# Rank: 41
# Loading stress experiment #1 of 1 with T gate indices: 74
#
#
# Rank: 57
# Loading stress experiment #1 of 1 with T gate indices: 90
#
#
# Rank: 34
# Loading stress experiment #1 of 1 with T gate indices: 67
#
#
# Rank: 25
# Loading stress experiment #1 of 2 with T gate indices: 51
#
#
# Rank: 36
# Loading stress experiment #1 of 1 with T gate indices: 69
#
#
# Rank: 3
# Loading stress experiment #1 of 2 with T gate indices: 7
#
#
# Rank: 28
# Loading stress experiment #1 of 2 with T gate indices: 57
#
#
# Rank: 39
# Loading stress experiment #1 of 1 with T gate indices: 72
#
#
# Rank: 51
# Loading stress experiment #1 of 1 with T gate indices: 84
#
#
# Rank: 43
# Loading stress experiment #1 of 1 with T gate indices: 76
#
#
# Rank: 1
# Loading stress experiment #1 of 2 with T gate indices: 3
#
#
# Rank: 50
# Loading stress experiment #1 of 1 with T gate indices: 83
#
#
# Rank: 18
# Loading stress experiment #1 of 2 with T gate indices: 37
#
#
# Rank: 38
# Loading stress experiment #1 of 1 with T gate indices: 71
#
#
# Rank: 9
# Loading stress experiment #1 of 2 with T gate indices: 19
#
#
# Rank: 54
# Loading stress experiment #1 of 1 with T gate indices: 87
#
#
# Rank: 10
# Loading stress experiment #1 of 2 with T gate indices: 21
#
#
# Rank: 14
# Loading stress experiment #1 of 2 with T gate indices: 29
#
#
# Rank: 48
# Loading stress experiment #1 of 1 with T gate indices: 81
#
#
# Rank: 26
# Loading stress experiment #1 of 2 with T gate indices: 53
#
#
# Rank: 32
# Loading stress experiment #1 of 1 with T gate indices: 65
#
#
# Rank: 12
# Loading stress experiment #1 of 2 with T gate indices: 25
#
#
# Rank: 23
# Loading stress experiment #1 of 2 with T gate indices: 47
#
#
# Rank: 63
# Loading stress experiment #1 of 1 with T gate indices: 96
#
#
# Rank: 60
# Loading stress experiment #1 of 1 with T gate indices: 93
#
#
# Rank: 8
# Loading stress experiment #1 of 2 with T gate indices: 17
#
#
# Rank: 5
# Loading stress experiment #1 of 2 with T gate indices: 11
#
#
# Rank: 27
# Loading stress experiment #1 of 2 with T gate indices: 55
#
#
# Rank: 20
# Completed stress experiment #1 of 2 with T gate indices: 41
# Time elapsed: 2s 43ms
#
#
# Rank: 20
# Loading stress experiment #2 of 2 with T gate indices: 42
#
#
# Rank: 0
# Completed stress experiment #1 of 2 with T gate indices: 1
# Time elapsed: 2s 48ms
#
#
# Rank: 0
# Loading stress experiment #2 of 2 with T gate indices: 2
#
#
# Rank: 11
# Completed stress experiment #1 of 2 with T gate indices: 23
# Time elapsed: 2s 48ms
#
#
# Rank: 62
# Completed stress experiment #1 of 1 with T gate indices: 95
# Time elapsed: 2s 49ms
#
#
# Rank: 19
# Completed stress experiment #1 of 2 with T gate indices: 39
# Time elapsed: 2s 64ms
#
#
# Rank: 19
# Loading stress experiment #2 of 2 with T gate indices: 40
#
#
# Rank: 11
# Loading stress experiment #2 of 2 with T gate indices: 24
#
#
# Rank: 52
# Completed stress experiment #1 of 1 with T gate indices: 85
# Time elapsed: 2s 79ms
#
#
# Rank: 16
# Completed stress experiment #1 of 2 with T gate indices: 33
# Time elapsed: 2s 82ms
#
#
# Rank: 6
# Completed stress experiment #1 of 2 with T gate indices: 13
# Time elapsed: 2s 83ms
#
#
# Rank: 16
# Loading stress experiment #2 of 2 with T gate indices: 34
#
#
# Rank: 6
# Loading stress experiment #2 of 2 with T gate indices: 14
#
#
# Rank: 49
# Completed stress experiment #1 of 1 with T gate indices: 82
# Time elapsed: 2s 85ms
#
#
# Rank: 47
# Completed stress experiment #1 of 1 with T gate indices: 80
# Time elapsed: 2s 87ms
#
#
# Rank: 24
# Completed stress experiment #1 of 2 with T gate indices: 49
# Time elapsed: 2s 88ms
#
#
# Rank: 24
# Loading stress experiment #2 of 2 with T gate indices: 50
#
#
# Rank: 46
# Completed stress experiment #1 of 1 with T gate indices: 79
# Time elapsed: 2s 80ms
#
#
# Rank: 61
# Completed stress experiment #1 of 1 with T gate indices: 94
# Time elapsed: 2s 91ms
#
#
# Rank: 4
# Completed stress experiment #1 of 2 with T gate indices: 9
# Time elapsed: 2s 93ms
#
#
# Rank: 55
# Completed stress experiment #1 of 1 with T gate indices: 88
# Time elapsed: 2s 95ms
#
#
# Rank: 33
# Completed stress experiment #1 of 1 with T gate indices: 66
# Time elapsed: 2s 95ms
#
#
# Rank: 30
# Completed stress experiment #1 of 2 with T gate indices: 61
# Time elapsed: 2s 96ms
#
#
# Rank: 17
# Completed stress experiment #1 of 2 with T gate indices: 35
# Time elapsed: 2s 98ms
#
#
# Rank: 22
# Completed stress experiment #1 of 2 with T gate indices: 45
# Time elapsed: 2s 88ms
#
#
# Rank: 17
# Loading stress experiment #2 of 2 with T gate indices: 36
#
#
# Rank: 22
# Loading stress experiment #2 of 2 with T gate indices: 46
#
#
# Rank: 15
# Completed stress experiment #1 of 2 with T gate indices: 31
# Time elapsed: 2s 101ms
#
#
# Rank: 31
# Completed stress experiment #1 of 2 with T gate indices: 63
# Time elapsed: 2s 103ms
#
#
# Rank: 31
# Loading stress experiment #2 of 2 with T gate indices: 64
#
#
# Rank: 4
# Loading stress experiment #2 of 2 with T gate indices: 10
#
#
# Rank: 30
# Loading stress experiment #2 of 2 with T gate indices: 62
#
#
# Rank: 35
# Completed stress experiment #1 of 1 with T gate indices: 68
# Time elapsed: 2s 110ms
#
#
# Rank: 59
# Completed stress experiment #1 of 1 with T gate indices: 92
# Time elapsed: 2s 101ms
#
#
# Rank: 2
# Completed stress experiment #1 of 2 with T gate indices: 5
# Time elapsed: 2s 101ms
#
#
# Rank: 15
# Loading stress experiment #2 of 2 with T gate indices: 32
#
#
# Rank: 45
# Completed stress experiment #1 of 1 with T gate indices: 78
# Time elapsed: 2s 88ms
#
#
# Rank: 58
# Completed stress experiment #1 of 1 with T gate indices: 91
# Time elapsed: 2s 92ms
#
#
# Rank: 2
# Loading stress experiment #2 of 2 with T gate indices: 6
#
#
# Rank: 21
# Completed stress experiment #1 of 2 with T gate indices: 43
# Time elapsed: 2s 98ms
#
#
# Rank: 21
# Loading stress experiment #2 of 2 with T gate indices: 44
#
#
# Rank: 7
# Completed stress experiment #1 of 2 with T gate indices: 15
# Time elapsed: 2s 134ms
#
#
# Rank: 7
# Loading stress experiment #2 of 2 with T gate indices: 16
#
#
# Rank: 53
# Completed stress experiment #1 of 1 with T gate indices: 86
# Time elapsed: 2s 138ms
#
#
# Rank: 44
# Completed stress experiment #1 of 1 with T gate indices: 77
# Time elapsed: 2s 147ms
#
#
# Rank: 40
# Completed stress experiment #1 of 1 with T gate indices: 73
# Time elapsed: 2s 149ms
#
#
# Rank: 56
# Completed stress experiment #1 of 1 with T gate indices: 89
# Time elapsed: 2s 151ms
#
#
# Rank: 25
# Completed stress experiment #1 of 2 with T gate indices: 51
# Time elapsed: 2s 178ms
#
#
# Rank: 25
# Loading stress experiment #2 of 2 with T gate indices: 52
#
#
# Rank: 42
# Completed stress experiment #1 of 1 with T gate indices: 75
# Time elapsed: 2s 184ms
#
#
# Rank: 34
# Completed stress experiment #1 of 1 with T gate indices: 67
# Time elapsed: 2s 186ms
#
#
# Rank: 13
# Completed stress experiment #1 of 2 with T gate indices: 27
# Time elapsed: 2s 207ms
#
#
# Rank: 13
# Loading stress experiment #2 of 2 with T gate indices: 28
#
#
# Rank: 3
# Completed stress experiment #1 of 2 with T gate indices: 7
# Time elapsed: 2s 217ms
#
#
# Rank: 3
# Loading stress experiment #2 of 2 with T gate indices: 8
#
#
# Rank: 39
# Completed stress experiment #1 of 1 with T gate indices: 72
# Time elapsed: 2s 220ms
#
#
# Rank: 36
# Completed stress experiment #1 of 1 with T gate indices: 69
# Time elapsed: 2s 224ms
#
#
# Rank: 43
# Completed stress experiment #1 of 1 with T gate indices: 76
# Time elapsed: 2s 225ms
#
#
# Rank: 1
# Completed stress experiment #1 of 2 with T gate indices: 3
# Time elapsed: 2s 227ms
#
#
# Rank: 1
# Loading stress experiment #2 of 2 with T gate indices: 4
#
#
# Rank: 50
# Completed stress experiment #1 of 1 with T gate indices: 83
# Time elapsed: 2s 231ms
#
#
# Rank: 51
# Completed stress experiment #1 of 1 with T gate indices: 84
# Time elapsed: 2s 225ms
#
#
# Rank: 18
# Completed stress experiment #1 of 2 with T gate indices: 37
# Time elapsed: 2s 237ms
#
#
# Rank: 18
# Loading stress experiment #2 of 2 with T gate indices: 38
#
#
# Rank: 57
# Completed stress experiment #1 of 1 with T gate indices: 90
# Time elapsed: 2s 267ms
#
#
# Rank: 41
# Completed stress experiment #1 of 1 with T gate indices: 74
# Time elapsed: 2s 270ms
#
#
# Rank: 9
# Completed stress experiment #1 of 2 with T gate indices: 19
# Time elapsed: 2s 282ms
#
#
# Rank: 9
# Loading stress experiment #2 of 2 with T gate indices: 20
#
#
# Rank: 54
# Completed stress experiment #1 of 1 with T gate indices: 87
# Time elapsed: 2s 285ms
#
#
# Rank: 10
# Completed stress experiment #1 of 2 with T gate indices: 21
# Time elapsed: 2s 288ms
#
#
# Rank: 10
# Loading stress experiment #2 of 2 with T gate indices: 22
#
#
# Rank: 37
# Completed stress experiment #1 of 1 with T gate indices: 70
# Time elapsed: 2s 292ms
#
#
# Rank: 14
# Completed stress experiment #1 of 2 with T gate indices: 29
# Time elapsed: 2s 295ms
#
#
# Rank: 14
# Loading stress experiment #2 of 2 with T gate indices: 30
#
#
# Rank: 28
# Completed stress experiment #1 of 2 with T gate indices: 57
# Time elapsed: 2s 315ms
#
#
# Rank: 28
# Loading stress experiment #2 of 2 with T gate indices: 58
#
#
# Rank: 48
# Completed stress experiment #1 of 1 with T gate indices: 81
# Time elapsed: 2s 349ms
#
#
# Rank: 26
# Completed stress experiment #1 of 2 with T gate indices: 53
# Time elapsed: 2s 357ms
#
#
# Rank: 26
# Loading stress experiment #2 of 2 with T gate indices: 54
#
#
# Rank: 32
# Completed stress experiment #1 of 1 with T gate indices: 65
# Time elapsed: 2s 363ms
#
#
# Rank: 12
# Completed stress experiment #1 of 2 with T gate indices: 25
# Time elapsed: 2s 373ms
#
#
# Rank: 12
# Loading stress experiment #2 of 2 with T gate indices: 26
#
#
# Rank: 23
# Completed stress experiment #1 of 2 with T gate indices: 47
# Time elapsed: 2s 377ms
#
#
# Rank: 23
# Loading stress experiment #2 of 2 with T gate indices: 48
#
#
# Rank: 38
# Completed stress experiment #1 of 1 with T gate indices: 71
# Time elapsed: 2s 379ms
#
#
# Rank: 63
# Completed stress experiment #1 of 1 with T gate indices: 96
# Time elapsed: 2s 430ms
#
#
# Rank: 8
# Completed stress experiment #1 of 2 with T gate indices: 17
# Time elapsed: 2s 447ms
#
#
# Rank: 8
# Loading stress experiment #2 of 2 with T gate indices: 18
#
#
# Rank: 5
# Completed stress experiment #1 of 2 with T gate indices: 11
# Time elapsed: 2s 448ms
#
#
# Rank: 5
# Loading stress experiment #2 of 2 with T gate indices: 12
#
#
# Rank: 27
# Completed stress experiment #1 of 2 with T gate indices: 55
# Time elapsed: 2s 537ms
#
#
# Rank: 27
# Loading stress experiment #2 of 2 with T gate indices: 56
#
#
# Rank: 60
# Completed stress experiment #1 of 1 with T gate indices: 93
# Time elapsed: 2s 548ms
#
#
# Rank: 29
# Completed stress experiment #1 of 2 with T gate indices: 59
# Time elapsed: 3s 2ms
#
#
# Rank: 29
# Loading stress experiment #2 of 2 with T gate indices: 60
#
#
# Rank: 20
# Completed stress experiment #2 of 2 with T gate indices: 42
# Time elapsed: 2s 37ms
#
#
# Rank: 0
# Completed stress experiment #2 of 2 with T gate indices: 2
# Time elapsed: 2s 48ms
#
#
# Rank: 19
# Completed stress experiment #2 of 2 with T gate indices: 40
# Time elapsed: 2s 33ms
#
#
# Rank: 11
# Completed stress experiment #2 of 2 with T gate indices: 24
# Time elapsed: 2s 52ms
#
#
# Rank: 6
# Completed stress experiment #2 of 2 with T gate indices: 14
# Time elapsed: 2s 34ms
#
#
# Rank: 24
# Completed stress experiment #2 of 2 with T gate indices: 50
# Time elapsed: 2s 37ms
#
#
# Rank: 16
# Completed stress experiment #2 of 2 with T gate indices: 34
# Time elapsed: 2s 34ms
#
#
# Rank: 17
# Completed stress experiment #2 of 2 with T gate indices: 36
# Time elapsed: 2s 37ms
#
#
# Rank: 22
# Completed stress experiment #2 of 2 with T gate indices: 46
# Time elapsed: 2s 40ms
#
#
# Rank: 4
# Completed stress experiment #2 of 2 with T gate indices: 10
# Time elapsed: 2s 49ms
#
#
# Rank: 30
# Completed stress experiment #2 of 2 with T gate indices: 62
# Time elapsed: 2s 51ms
#
#
# Rank: 31
# Completed stress experiment #2 of 2 with T gate indices: 64
# Time elapsed: 2s 36ms
#
#
# Rank: 15
# Completed stress experiment #2 of 2 with T gate indices: 32
# Time elapsed: 2s 55ms
#
#
# Rank: 2
# Completed stress experiment #2 of 2 with T gate indices: 6
# Time elapsed: 2s 53ms
#
#
# Rank: 21
# Completed stress experiment #2 of 2 with T gate indices: 44
# Time elapsed: 2s 38ms
#
#
# Rank: 7
# Completed stress experiment #2 of 2 with T gate indices: 16
# Time elapsed: 2s 37ms
#
#
# Rank: 25
# Completed stress experiment #2 of 2 with T gate indices: 52
# Time elapsed: 2s 43ms
#
#
# Rank: 13
# Completed stress experiment #2 of 2 with T gate indices: 28
# Time elapsed: 2s 40ms
#
#
# Rank: 3
# Completed stress experiment #2 of 2 with T gate indices: 8
# Time elapsed: 2s 33ms
#
#
# Rank: 18
# Completed stress experiment #2 of 2 with T gate indices: 38
# Time elapsed: 2s 46ms
#
#
# Rank: 9
# Completed stress experiment #2 of 2 with T gate indices: 20
# Time elapsed: 2s 37ms
#
#
# Rank: 14
# Completed stress experiment #2 of 2 with T gate indices: 30
# Time elapsed: 2s 37ms
#
#
# Rank: 10
# Completed stress experiment #2 of 2 with T gate indices: 22
# Time elapsed: 2s 45ms
#
#
# Rank: 28
# Completed stress experiment #2 of 2 with T gate indices: 58
# Time elapsed: 2s 40ms
#
#
# Rank: 1
# Completed stress experiment #2 of 2 with T gate indices: 4
# Time elapsed: 2s 143ms
#
#
# Rank: 26
# Completed stress experiment #2 of 2 with T gate indices: 54
# Time elapsed: 2s 38ms
#
#
# Rank: 12
# Completed stress experiment #2 of 2 with T gate indices: 26
# Time elapsed: 2s 40ms
#
#
# Rank: 23
# Completed stress experiment #2 of 2 with T gate indices: 48
# Time elapsed: 2s 38ms
#
#
# Rank: 8
# Completed stress experiment #2 of 2 with T gate indices: 18
# Time elapsed: 2s 34ms
#
#
# Rank: 5
# Completed stress experiment #2 of 2 with T gate indices: 12
# Time elapsed: 2s 37ms
#
#
# Rank: 27
# Completed stress experiment #2 of 2 with T gate indices: 56
# Time elapsed: 2s 36ms
#
#
# Rank: 29
# Completed stress experiment #2 of 2 with T gate indices: 60
# Time elapsed: 2s 668ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 2                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 3                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 4                | 0.00              | 100.00            | 0.00              | 100.00            |
# | 5                | 6.25              | 93.75             | 0.00              | 93.75             |
# | 6                | 6.25              | 93.75             | 0.00              | 93.75             |
# | 7                | 0.00              | 100.00            | 3.12              | 96.88             |
# | 8                | 0.00              | 100.00            | 3.12              | 96.88             |
# | 9                | 0.00              | 100.00            | 3.12              | 96.88             |
# | 10               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 11               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 12               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 13               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 14               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 15               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 16               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 17               | 6.25              | 93.75             | 0.00              | 93.75             |
# | 18               | 6.25              | 93.75             | 0.00              | 93.75             |
# | 19               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 20               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 21               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 22               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 23               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 24               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 25               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 26               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 27               | 6.25              | 93.75             | 0.00              | 93.75             |
# | 28               | 6.25              | 93.75             | 0.00              | 93.75             |
# | 29               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 30               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 31               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 32               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 33               | 0.00              | 100.00            | 21.88             | 78.12             |
# | 34               | 0.00              | 100.00            | 15.62             | 84.38             |
# | 35               | 0.00              | 100.00            | 15.62             | 84.38             |
# | 36               | 0.00              | 100.00            | 6.25              | 93.75             |
# | 37               | 0.00              | 100.00            | 12.50             | 87.50             |
# | 38               | 0.00              | 100.00            | 3.12              | 96.88             |
# | 39               | 0.00              | 100.00            | 12.50             | 87.50             |
# | 40               | 0.00              | 100.00            | 12.50             | 87.50             |
# | 41               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 42               | 0.00              | 100.00            | 18.75             | 81.25             |
# | 43               | 0.00              | 100.00            | 18.75             | 81.25             |
# | 44               | 0.00              | 100.00            | 9.38              | 90.62             |
# | 45               | 0.00              | 100.00            | 15.62             | 84.38             |
# | 46               | 0.00              | 100.00            | 6.25              | 93.75             |
# | 47               | 0.00              | 100.00            | 15.62             | 84.38             |
# | 48               | 0.00              | 100.00            | 15.62             | 84.38             |
# | 49               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 50               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 51               | 25.00             | 75.00             | 0.00              | 75.00             |
# | 52               | 25.00             | 75.00             | 0.00              | 75.00             |
# | 53               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 54               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 55               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 56               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 57               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 58               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 59               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 60               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 61               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 62               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 63               | 25.00             | 75.00             | 0.00              | 75.00             |
# | 64               | 25.00             | 75.00             | 0.00              | 75.00             |
# | 65               | 75.00             | 25.00             | 0.00              | 25.00             |
# | 66               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 67               | 75.00             | 25.00             | 0.00              | 25.00             |
# | 68               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 69               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 70               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 71               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 72               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 73               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 74               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 75               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 76               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 77               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 78               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 79               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 80               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 81               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 82               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 83               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 84               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 85               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 86               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 87               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 88               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 89               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 90               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 91               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 92               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 93               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 94               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 95               | 0.00              | 100.00            | 0.00              | 100.00            |
# | 96               | 0.00              | 100.00            | 0.00              | 100.00            |
#
#
# Time elapsed for stress testing 96 unique combinations: 6s 794ms

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 4 qubits

# %%
sys.argv = ['notebook', '--simulate', '--qubit-range=4', f'--t-count={t_count}', '--print-circuit=d', '--print-simulation=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Display
# Start range of qubits: 4
# End range of qubits: 4
# Simulation type: Simulate specific measurement: qram qubits
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time elapsed on displaying the circuit:  61ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)
#
# Time elapsed on simulation and comparison: 364ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  43ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 8 (100.00 %)	( Measurements: 1 (12.50 %) • Output vector: 7 (87.50 %) )
#
# Time elapsed on simulation and comparison: 305ms
#
#
# Simulating the circuit ... Checking the QRAM logic and measure only the target qubit ...
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 82ms
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 149ms
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |       Stop       |       Step       |
# +------------------+------------------+------------------+
# |        0         |   128849215488   |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Memory allocation failed.
# Results of the simulation:
#
# 	• Failed: 0 (0.00 %)
# 	• Succeed: 64 (100.00 %)	( Measurements: 64 (100.00 %) • Output vector: 0 (0.00 %) )
#
# Time elapsed on simulation and comparison: 2s 747ms
#
# ======================================================================================================================================================
# 0

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 4 qubits

# %%
make_slurm("stress", "4", str(t_count), "1", "output")
# Out:
# Rank: 49
# Loading stress experiment #1 of 3 with T gate indices: 164
#
#
# Rank: 7
# Loading stress experiment #1 of 4 with T gate indices: 29
#
#
# Rank: 25
# Loading stress experiment #1 of 3 with T gate indices: 92
#
#
# Rank: 41
# Loading stress experiment #1 of 3 with T gate indices: 140
#
#
# Rank: 0
# Loading stress experiment #1 of 4 with T gate indices: 1
#
#
# Rank: 3
# Loading stress experiment #1 of 4 with T gate indices: 13
#
#
# Rank: 26
# Loading stress experiment #1 of 3 with T gate indices: 95
#
#
# Rank: 35
# Loading stress experiment #1 of 3 with T gate indices: 122
#
#
# Rank: 37
# Loading stress experiment #1 of 3 with T gate indices: 128
#
#
# Rank: 2
# Loading stress experiment #1 of 4 with T gate indices: 9
#
#
# Rank: 44
# Loading stress experiment #1 of 3 with T gate indices: 149
#
#
# Rank: 39
# Loading stress experiment #1 of 3 with T gate indices: 134
#
#
# Rank: 6
# Loading stress experiment #1 of 4 with T gate indices: 25
#
#
# Rank: 1
# Loading stress experiment #1 of 4 with T gate indices: 5
#
#
# Rank: 40
# Loading stress experiment #1 of 3 with T gate indices: 137
#
#
# Rank: 43
# Loading stress experiment #1 of 3 with T gate indices: 146
#
#
# Rank: 14
# Loading stress experiment #1 of 4 with T gate indices: 57
#
#
# Rank: 56
# Loading stress experiment #1 of 3 with T gate indices: 185
#
#
# Rank: 45
# Loading stress experiment #1 of 3 with T gate indices: 152
#
#
# Rank: 32
# Loading stress experiment #1 of 3 with T gate indices: 113
#
#
# Rank: 27
# Loading stress experiment #1 of 3 with T gate indices: 98
#
#
# Rank: 4
# Loading stress experiment #1 of 4 with T gate indices: 17
#
#
# Rank: 57
# Loading stress experiment #1 of 3 with T gate indices: 188
#
#
# Rank: 24
# Loading stress experiment #1 of 3 with T gate indices: 89
#
#
# Rank: 22
# Loading stress experiment #1 of 3 with T gate indices: 83
#
#
# Rank: 12
# Loading stress experiment #1 of 4 with T gate indices: 49
#
#
# Rank: 54
# Loading stress experiment #1 of 3 with T gate indices: 179
#
#
# Rank: 60
# Loading stress experiment #1 of 3 with T gate indices: 197
#
#
# Rank: 58
# Loading stress experiment #1 of 3 with T gate indices: 191
#
#
# Rank: 51
# Loading stress experiment #1 of 3 with T gate indices: 170
#
#
# Rank: 36
# Loading stress experiment #1 of 3 with T gate indices: 125
#
#
# Rank: 16
# Loading stress experiment #1 of 3 with T gate indices: 65
#
#
# Rank: 5
# Loading stress experiment #1 of 4 with T gate indices: 21
#
#
# Rank: 13
# Loading stress experiment #1 of 4 with T gate indices: 53
#
#
# Rank: 41
# Completed stress experiment #1 of 3 with T gate indices: 140
# Time elapsed: 444ms
#
#
# Rank: 41
# Loading stress experiment #2 of 3 with T gate indices: 141
#
#
# Rank: 49
# Completed stress experiment #1 of 3 with T gate indices: 164
# Time elapsed: 450ms
#
#
# Rank: 49
# Loading stress experiment #2 of 3 with T gate indices: 165
#
#
# Rank: 25
# Completed stress experiment #1 of 3 with T gate indices: 92
# Time elapsed: 453ms
#
#
# Rank: 0
# Completed stress experiment #1 of 4 with T gate indices: 1
# Time elapsed: 455ms
#
#
# Rank: 0
# Loading stress experiment #2 of 4 with T gate indices: 2
#
#
# Rank: 23
# Loading stress experiment #1 of 3 with T gate indices: 86
#
#
# Rank: 19
# Loading stress experiment #1 of 3 with T gate indices: 74
#
#
# Rank: 63
# Loading stress experiment #1 of 3 with T gate indices: 206
#
#
# Rank: 26
# Completed stress experiment #1 of 3 with T gate indices: 95
# Time elapsed: 464ms
#
#
# Rank: 3
# Completed stress experiment #1 of 4 with T gate indices: 13
# Time elapsed: 465ms
#
#
# Rank: 26
# Loading stress experiment #2 of 3 with T gate indices: 96
#
#
# Rank: 3
# Loading stress experiment #2 of 4 with T gate indices: 14
#
#
# Rank: 35
# Completed stress experiment #1 of 3 with T gate indices: 122
# Time elapsed: 457ms
#
#
# Rank: 35
# Loading stress experiment #2 of 3 with T gate indices: 123
#
#
# Rank: 39
# Completed stress experiment #1 of 3 with T gate indices: 134
# Time elapsed: 475ms
#
#
# Rank: 39
# Loading stress experiment #2 of 3 with T gate indices: 135
#
#
# Rank: 44
# Completed stress experiment #1 of 3 with T gate indices: 149
# Time elapsed: 480ms
#
#
# Rank: 44
# Loading stress experiment #2 of 3 with T gate indices: 150
#
#
# Rank: 37
# Completed stress experiment #1 of 3 with T gate indices: 128
# Time elapsed: 483ms
#
#
# Rank: 37
# Loading stress experiment #2 of 3 with T gate indices: 129
#
#
# Rank: 25
# Loading stress experiment #2 of 3 with T gate indices: 93
#
#
# Rank: 7
# Completed stress experiment #1 of 4 with T gate indices: 29
# Time elapsed: 457ms
#
#
# Rank: 7
# Loading stress experiment #2 of 4 with T gate indices: 30
#
#
# Rank: 2
# Completed stress experiment #1 of 4 with T gate indices: 9
# Time elapsed: 483ms
#
#
# Rank: 2
# Loading stress experiment #2 of 4 with T gate indices: 10
#
#
# Rank: 6
# Completed stress experiment #1 of 4 with T gate indices: 25
# Time elapsed: 503ms
#
#
# Rank: 6
# Loading stress experiment #2 of 4 with T gate indices: 26
#
#
# Rank: 40
# Completed stress experiment #1 of 3 with T gate indices: 137
# Time elapsed: 506ms
#
#
# Rank: 40
# Loading stress experiment #2 of 3 with T gate indices: 138
#
#
# Rank: 1
# Completed stress experiment #1 of 4 with T gate indices: 5
# Time elapsed: 519ms
#
#
# Rank: 1
# Loading stress experiment #2 of 4 with T gate indices: 6
#
#
# Rank: 56
# Completed stress experiment #1 of 3 with T gate indices: 185
# Time elapsed: 544ms
#
#
# Rank: 56
# Loading stress experiment #2 of 3 with T gate indices: 186
#
#
# Rank: 14
# Completed stress experiment #1 of 4 with T gate indices: 57
# Time elapsed: 549ms
#
#
# Rank: 14
# Loading stress experiment #2 of 4 with T gate indices: 58
#
#
# Rank: 45
# Completed stress experiment #1 of 3 with T gate indices: 152
# Time elapsed: 554ms
#
#
# Rank: 45
# Loading stress experiment #2 of 3 with T gate indices: 153
#
#
# Rank: 28
# Loading stress experiment #1 of 3 with T gate indices: 101
#
#
# Rank: 34
# Loading stress experiment #1 of 3 with T gate indices: 119
#
#
# Rank: 31
# Loading stress experiment #1 of 3 with T gate indices: 110
#
#
# Rank: 43
# Completed stress experiment #1 of 3 with T gate indices: 146
# Time elapsed: 555ms
#
#
# Rank: 43
# Loading stress experiment #2 of 3 with T gate indices: 147
#
#
# Rank: 27
# Completed stress experiment #1 of 3 with T gate indices: 98
# Time elapsed: 599ms
#
#
# Rank: 32
# Completed stress experiment #1 of 3 with T gate indices: 113
# Time elapsed: 600ms
#
#
# Rank: 27
# Loading stress experiment #2 of 3 with T gate indices: 99
#
#
# Rank: 32
# Loading stress experiment #2 of 3 with T gate indices: 114
#
#
# Rank: 4
# Completed stress experiment #1 of 4 with T gate indices: 17
# Time elapsed: 602ms
#
#
# Rank: 4
# Loading stress experiment #2 of 4 with T gate indices: 18
#
#
# Rank: 57
# Completed stress experiment #1 of 3 with T gate indices: 188
# Time elapsed: 599ms
#
#
# Rank: 57
# Loading stress experiment #2 of 3 with T gate indices: 189
#
#
# Rank: 54
# Completed stress experiment #1 of 3 with T gate indices: 179
# Time elapsed: 656ms
#
#
# Rank: 48
# Loading stress experiment #1 of 3 with T gate indices: 161
#
#
# Rank: 10
# Loading stress experiment #1 of 4 with T gate indices: 41
#
#
# Rank: 53
# Loading stress experiment #1 of 3 with T gate indices: 176
#
#
# Rank: 22
# Completed stress experiment #1 of 3 with T gate indices: 83
# Time elapsed: 661ms
#
#
# Rank: 24
# Completed stress experiment #1 of 3 with T gate indices: 89
# Time elapsed: 663ms
#
#
# Rank: 22
# Loading stress experiment #2 of 3 with T gate indices: 84
#
#
# Rank: 24
# Loading stress experiment #2 of 3 with T gate indices: 90
#
#
# Rank: 12
# Completed stress experiment #1 of 4 with T gate indices: 49
# Time elapsed: 666ms
#
#
# Rank: 12
# Loading stress experiment #2 of 4 with T gate indices: 50
#
#
# Rank: 54
# Loading stress experiment #2 of 3 with T gate indices: 180
#
#
# Rank: 58
# Completed stress experiment #1 of 3 with T gate indices: 191
# Time elapsed: 733ms
#
#
# Rank: 58
# Loading stress experiment #2 of 3 with T gate indices: 192
#
#
# Rank: 60
# Completed stress experiment #1 of 3 with T gate indices: 197
# Time elapsed: 736ms
#
#
# Rank: 36
# Completed stress experiment #1 of 3 with T gate indices: 125
# Time elapsed: 737ms
#
#
# Rank: 36
# Loading stress experiment #2 of 3 with T gate indices: 126
#
#
# Rank: 60
# Loading stress experiment #2 of 3 with T gate indices: 198
#
#
# Rank: 52
# Loading stress experiment #1 of 3 with T gate indices: 173
#
#
# Rank: 61
# Loading stress experiment #1 of 3 with T gate indices: 200
#
#
# Rank: 17
# Loading stress experiment #1 of 3 with T gate indices: 68
#
#
# Rank: 51
# Completed stress experiment #1 of 3 with T gate indices: 170
# Time elapsed: 737ms
#
#
# Rank: 51
# Loading stress experiment #2 of 3 with T gate indices: 171
#
#
# Rank: 16
# Completed stress experiment #1 of 3 with T gate indices: 65
# Time elapsed: 810ms
#
#
# Rank: 16
# Loading stress experiment #2 of 3 with T gate indices: 66
#
#
# Rank: 5
# Completed stress experiment #1 of 4 with T gate indices: 21
# Time elapsed: 819ms
#
#
# Rank: 5
# Loading stress experiment #2 of 4 with T gate indices: 22
#
#
# Rank: 13
# Completed stress experiment #1 of 4 with T gate indices: 53
# Time elapsed: 821ms
#
#
# Rank: 13
# Loading stress experiment #2 of 4 with T gate indices: 54
#
#
# Rank: 20
# Loading stress experiment #1 of 3 with T gate indices: 77
#
#
# Rank: 59
# Loading stress experiment #1 of 3 with T gate indices: 194
#
#
# Rank: 38
# Loading stress experiment #1 of 3 with T gate indices: 131
#
#
# Rank: 41
# Completed stress experiment #2 of 3 with T gate indices: 141
# Time elapsed: 429ms
#
#
# Rank: 41
# Loading stress experiment #3 of 3 with T gate indices: 142
#
#
# Rank: 49
# Completed stress experiment #2 of 3 with T gate indices: 165
# Time elapsed: 437ms
#
#
# Rank: 49
# Loading stress experiment #3 of 3 with T gate indices: 166
#
#
# Rank: 26
# Completed stress experiment #2 of 3 with T gate indices: 96
# Time elapsed: 434ms
#
#
# Rank: 0
# Completed stress experiment #2 of 4 with T gate indices: 2
# Time elapsed: 445ms
#
#
# Rank: 0
# Loading stress experiment #3 of 4 with T gate indices: 3
#
#
# Rank: 3
# Completed stress experiment #2 of 4 with T gate indices: 14
# Time elapsed: 439ms
#
#
# Rank: 35
# Completed stress experiment #2 of 3 with T gate indices: 123
# Time elapsed: 437ms
#
#
# Rank: 19
# Completed stress experiment #1 of 3 with T gate indices: 74
# Time elapsed: 908ms
#
#
# Rank: 19
# Loading stress experiment #2 of 3 with T gate indices: 75
#
#
# Rank: 26
# Loading stress experiment #3 of 3 with T gate indices: 97
#
#
# Rank: 23
# Completed stress experiment #1 of 3 with T gate indices: 86
# Time elapsed: 914ms
#
#
# Rank: 23
# Loading stress experiment #2 of 3 with T gate indices: 87
#
#
# Rank: 44
# Completed stress experiment #2 of 3 with T gate indices: 150
# Time elapsed: 435ms
#
#
# Rank: 63
# Completed stress experiment #1 of 3 with T gate indices: 206
# Time elapsed: 907ms
#
#
# Rank: 35
# Loading stress experiment #3 of 3 with T gate indices: 124
#
#
# Rank: 7
# Completed stress experiment #2 of 4 with T gate indices: 30
# Time elapsed: 432ms
#
#
# Rank: 7
# Loading stress experiment #3 of 4 with T gate indices: 31
#
#
# Rank: 25
# Completed stress experiment #2 of 3 with T gate indices: 93
# Time elapsed: 470ms
#
#
# Rank: 37
# Completed stress experiment #2 of 3 with T gate indices: 129
# Time elapsed: 441ms
#
#
# Rank: 37
# Loading stress experiment #3 of 3 with T gate indices: 130
#
#
# Rank: 44
# Loading stress experiment #3 of 3 with T gate indices: 151
#
#
# Rank: 63
# Loading stress experiment #2 of 3 with T gate indices: 207
#
#
# Rank: 2
# Completed stress experiment #2 of 4 with T gate indices: 10
# Time elapsed: 439ms
#
#
# Rank: 2
# Loading stress experiment #3 of 4 with T gate indices: 11
#
#
# Rank: 25
# Loading stress experiment #3 of 3 with T gate indices: 94
#
#
# Rank: 3
# Loading stress experiment #3 of 4 with T gate indices: 15
#
#
# Rank: 6
# Completed stress experiment #2 of 4 with T gate indices: 26
# Time elapsed: 439ms
#
#
# Rank: 39
# Completed stress experiment #2 of 3 with T gate indices: 135
# Time elapsed: 437ms
#
#
# Rank: 6
# Loading stress experiment #3 of 4 with T gate indices: 27
#
#
# Rank: 39
# Loading stress experiment #3 of 3 with T gate indices: 136
#
#
# Rank: 1
# Completed stress experiment #2 of 4 with T gate indices: 6
# Time elapsed: 436ms
#
#
# Rank: 1
# Loading stress experiment #3 of 4 with T gate indices: 7
#
#
# Rank: 9
# Loading stress experiment #1 of 4 with T gate indices: 37
#
#
# Rank: 47
# Loading stress experiment #1 of 3 with T gate indices: 158
#
#
# Rank: 21
# Loading stress experiment #1 of 3 with T gate indices: 80
#
#
# Rank: 40
# Completed stress experiment #2 of 3 with T gate indices: 138
# Time elapsed: 439ms
#
#
# Rank: 40
# Loading stress experiment #3 of 3 with T gate indices: 139
#
#
# Rank: 56
# Completed stress experiment #2 of 3 with T gate indices: 186
# Time elapsed: 437ms
#
#
# Rank: 56
# Loading stress experiment #3 of 3 with T gate indices: 187
#
#
# Rank: 45
# Completed stress experiment #2 of 3 with T gate indices: 153
# Time elapsed: 432ms
#
#
# Rank: 45
# Loading stress experiment #3 of 3 with T gate indices: 154
#
#
# Rank: 14
# Completed stress experiment #2 of 4 with T gate indices: 58
# Time elapsed: 446ms
#
#
# Rank: 14
# Loading stress experiment #3 of 4 with T gate indices: 59
#
#
# Rank: 28
# Completed stress experiment #1 of 3 with T gate indices: 101
# Time elapsed: 1s 2ms
#
#
# Rank: 28
# Loading stress experiment #2 of 3 with T gate indices: 102
#
#
# Rank: 43
# Completed stress experiment #2 of 3 with T gate indices: 147
# Time elapsed: 441ms
#
#
# Rank: 43
# Loading stress experiment #3 of 3 with T gate indices: 148
#
#
# Rank: 31
# Completed stress experiment #1 of 3 with T gate indices: 110
# Time elapsed: 1s 11ms
#
#
# Rank: 31
# Loading stress experiment #2 of 3 with T gate indices: 111
#
#
# Rank: 34
# Completed stress experiment #1 of 3 with T gate indices: 119
# Time elapsed: 1s 14ms
#
#
# Rank: 34
# Loading stress experiment #2 of 3 with T gate indices: 120
#
#
# Rank: 27
# Completed stress experiment #2 of 3 with T gate indices: 99
# Time elapsed: 432ms
#
#
# Rank: 27
# Loading stress experiment #3 of 3 with T gate indices: 100
#
#
# Rank: 32
# Completed stress experiment #2 of 3 with T gate indices: 114
# Time elapsed: 435ms
#
#
# Rank: 32
# Loading stress experiment #3 of 3 with T gate indices: 115
#
#
# Rank: 4
# Completed stress experiment #2 of 4 with T gate indices: 18
# Time elapsed: 437ms
#
#
# Rank: 4
# Loading stress experiment #3 of 4 with T gate indices: 19
#
#
# Rank: 57
# Completed stress experiment #2 of 3 with T gate indices: 189
# Time elapsed: 439ms
#
#
# Rank: 57
# Loading stress experiment #3 of 3 with T gate indices: 190
#
#
# Rank: 33
# Loading stress experiment #1 of 3 with T gate indices: 116
#
#
# Rank: 15
# Loading stress experiment #1 of 4 with T gate indices: 61
#
#
# Rank: 18
# Loading stress experiment #1 of 3 with T gate indices: 71
#
#
# Rank: 48
# Completed stress experiment #1 of 3 with T gate indices: 161
# Time elapsed: 1s 101ms
#
#
# Rank: 48
# Loading stress experiment #2 of 3 with T gate indices: 162
#
#
# Rank: 22
# Completed stress experiment #2 of 3 with T gate indices: 84
# Time elapsed: 440ms
#
#
# Rank: 22
# Loading stress experiment #3 of 3 with T gate indices: 85
#
#
# Rank: 12
# Completed stress experiment #2 of 4 with T gate indices: 50
# Time elapsed: 439ms
#
#
# Rank: 12
# Loading stress experiment #3 of 4 with T gate indices: 51
#
#
# Rank: 10
# Completed stress experiment #1 of 4 with T gate indices: 41
# Time elapsed: 1s 110ms
#
#
# Rank: 10
# Loading stress experiment #2 of 4 with T gate indices: 42
#
#
# Rank: 24
# Completed stress experiment #2 of 3 with T gate indices: 90
# Time elapsed: 437ms
#
#
# Rank: 24
# Loading stress experiment #3 of 3 with T gate indices: 91
#
#
# Rank: 53
# Completed stress experiment #1 of 3 with T gate indices: 176
# Time elapsed: 1s 113ms
#
#
# Rank: 53
# Loading stress experiment #2 of 3 with T gate indices: 177
#
#
# Rank: 54
# Completed stress experiment #2 of 3 with T gate indices: 180
# Time elapsed: 444ms
#
#
# Rank: 54
# Loading stress experiment #3 of 3 with T gate indices: 181
#
#
# Rank: 8
# Loading stress experiment #1 of 4 with T gate indices: 33
#
#
# Rank: 50
# Loading stress experiment #1 of 3 with T gate indices: 167
#
#
# Rank: 29
# Loading stress experiment #1 of 3 with T gate indices: 104
#
#
# Rank: 36
# Completed stress experiment #2 of 3 with T gate indices: 126
# Time elapsed: 433ms
#
#
# Rank: 36
# Loading stress experiment #3 of 3 with T gate indices: 127
#
#
# Rank: 58
# Completed stress experiment #2 of 3 with T gate indices: 192
# Time elapsed: 439ms
#
#
# Rank: 58
# Loading stress experiment #3 of 3 with T gate indices: 193
#
#
# Rank: 60
# Completed stress experiment #2 of 3 with T gate indices: 198
# Time elapsed: 450ms
#
#
# Rank: 60
# Loading stress experiment #3 of 3 with T gate indices: 199
#
#
# Rank: 51
# Completed stress experiment #2 of 3 with T gate indices: 171
# Time elapsed: 437ms
#
#
# Rank: 51
# Loading stress experiment #3 of 3 with T gate indices: 172
#
#
# Rank: 52
# Completed stress experiment #1 of 3 with T gate indices: 173
# Time elapsed: 1s 211ms
#
#
# Rank: 17
# Completed stress experiment #1 of 3 with T gate indices: 68
# Time elapsed: 1s 212ms
#
#
# Rank: 17
# Loading stress experiment #2 of 3 with T gate indices: 69
#
#
# Rank: 61
# Completed stress experiment #1 of 3 with T gate indices: 200
# Time elapsed: 1s 208ms
#
#
# Rank: 61
# Loading stress experiment #2 of 3 with T gate indices: 201
#
#
# Rank: 52
# Loading stress experiment #2 of 3 with T gate indices: 174
#
#
# Rank: 16
# Completed stress experiment #2 of 3 with T gate indices: 66
# Time elapsed: 434ms
#
#
# Rank: 16
# Loading stress experiment #3 of 3 with T gate indices: 67
#
#
# Rank: 13
# Completed stress experiment #2 of 4 with T gate indices: 54
# Time elapsed: 437ms
#
#
# Rank: 62
# Loading stress experiment #1 of 3 with T gate indices: 203
#
#
# Rank: 55
# Loading stress experiment #1 of 3 with T gate indices: 182
#
#
# Rank: 30
# Loading stress experiment #1 of 3 with T gate indices: 107
#
#
# Rank: 5
# Completed stress experiment #2 of 4 with T gate indices: 22
# Time elapsed: 449ms
#
#
# Rank: 5
# Loading stress experiment #3 of 4 with T gate indices: 23
#
#
# Rank: 13
# Loading stress experiment #3 of 4 with T gate indices: 55
#
#
# Rank: 20
# Completed stress experiment #1 of 3 with T gate indices: 77
# Time elapsed: 1s 305ms
#
#
# Rank: 20
# Loading stress experiment #2 of 3 with T gate indices: 78
#
#
# Rank: 41
# Completed stress experiment #3 of 3 with T gate indices: 142
# Time elapsed: 435ms
#
#
# Rank: 59
# Completed stress experiment #1 of 3 with T gate indices: 194
# Time elapsed: 1s 305ms
#
#
# Rank: 59
# Loading stress experiment #2 of 3 with T gate indices: 195
#
#
# Rank: 38
# Completed stress experiment #1 of 3 with T gate indices: 131
# Time elapsed: 1s 312ms
#
#
# Rank: 38
# Loading stress experiment #2 of 3 with T gate indices: 132
#
#
# Rank: 49
# Completed stress experiment #3 of 3 with T gate indices: 166
# Time elapsed: 437ms
#
#
# Rank: 0
# Completed stress experiment #3 of 4 with T gate indices: 3
# Time elapsed: 444ms
#
#
# Rank: 0
# Loading stress experiment #4 of 4 with T gate indices: 4
#
#
# Rank: 35
# Completed stress experiment #3 of 3 with T gate indices: 124
# Time elapsed: 448ms
#
#
# Rank: 26
# Completed stress experiment #3 of 3 with T gate indices: 97
# Time elapsed: 455ms
#
#
# Rank: 19
# Completed stress experiment #2 of 3 with T gate indices: 75
# Time elapsed: 437ms
#
#
# Rank: 19
# Loading stress experiment #3 of 3 with T gate indices: 76
#
#
# Rank: 11
# Loading stress experiment #1 of 4 with T gate indices: 45
#
#
# Rank: 46
# Loading stress experiment #1 of 3 with T gate indices: 155
#
#
# Rank: 63
# Completed stress experiment #2 of 3 with T gate indices: 207
# Time elapsed: 444ms
#
#
# Rank: 63
# Loading stress experiment #3 of 3 with T gate indices: 208
#
#
# Rank: 44
# Completed stress experiment #3 of 3 with T gate indices: 151
# Time elapsed: 450ms
#
#
# Rank: 7
# Completed stress experiment #3 of 4 with T gate indices: 31
# Time elapsed: 438ms
#
#
# Rank: 37
# Completed stress experiment #3 of 3 with T gate indices: 130
# Time elapsed: 436ms
#
#
# Rank: 7
# Loading stress experiment #4 of 4 with T gate indices: 32
#
#
# Rank: 6
# Completed stress experiment #3 of 4 with T gate indices: 27
# Time elapsed: 429ms
#
#
# Rank: 6
# Loading stress experiment #4 of 4 with T gate indices: 28
#
#
# Rank: 39
# Completed stress experiment #3 of 3 with T gate indices: 136
# Time elapsed: 431ms
#
#
# Rank: 23
# Completed stress experiment #2 of 3 with T gate indices: 87
# Time elapsed: 454ms
#
#
# Rank: 23
# Loading stress experiment #3 of 3 with T gate indices: 88
#
#
# Rank: 25
# Completed stress experiment #3 of 3 with T gate indices: 94
# Time elapsed: 448ms
#
#
# Rank: 2
# Completed stress experiment #3 of 4 with T gate indices: 11
# Time elapsed: 441ms
#
#
# Rank: 2
# Loading stress experiment #4 of 4 with T gate indices: 12
#
#
# Rank: 47
# Completed stress experiment #1 of 3 with T gate indices: 158
# Time elapsed: 1s 399ms
#
#
# Rank: 47
# Loading stress experiment #2 of 3 with T gate indices: 159
#
#
# Rank: 9
# Completed stress experiment #1 of 4 with T gate indices: 37
# Time elapsed: 1s 406ms
#
#
# Rank: 9
# Loading stress experiment #2 of 4 with T gate indices: 38
#
#
# Rank: 3
# Completed stress experiment #3 of 4 with T gate indices: 15
# Time elapsed: 470ms
#
#
# Rank: 21
# Completed stress experiment #1 of 3 with T gate indices: 80
# Time elapsed: 1s 410ms
#
#
# Rank: 3
# Loading stress experiment #4 of 4 with T gate indices: 16
#
#
# Rank: 21
# Loading stress experiment #2 of 3 with T gate indices: 81
#
#
# Rank: 40
# Completed stress experiment #3 of 3 with T gate indices: 139
# Time elapsed: 437ms
#
#
# Rank: 1
# Completed stress experiment #3 of 4 with T gate indices: 7
# Time elapsed: 450ms
#
#
# Rank: 56
# Completed stress experiment #3 of 3 with T gate indices: 187
# Time elapsed: 435ms
#
#
# Rank: 1
# Loading stress experiment #4 of 4 with T gate indices: 8
#
#
# Rank: 28
# Completed stress experiment #2 of 3 with T gate indices: 102
# Time elapsed: 433ms
#
#
# Rank: 28
# Loading stress experiment #3 of 3 with T gate indices: 103
#
#
# Rank: 45
# Completed stress experiment #3 of 3 with T gate indices: 154
# Time elapsed: 440ms
#
#
# Rank: 14
# Completed stress experiment #3 of 4 with T gate indices: 59
# Time elapsed: 440ms
#
#
# Rank: 14
# Loading stress experiment #4 of 4 with T gate indices: 60
#
#
# Rank: 43
# Completed stress experiment #3 of 3 with T gate indices: 148
# Time elapsed: 442ms
#
#
# Rank: 34
# Completed stress experiment #2 of 3 with T gate indices: 120
# Time elapsed: 438ms
#
#
# Rank: 34
# Loading stress experiment #3 of 3 with T gate indices: 121
#
#
# Rank: 42
# Loading stress experiment #1 of 3 with T gate indices: 143
#
#
# Rank: 27
# Completed stress experiment #3 of 3 with T gate indices: 100
# Time elapsed: 438ms
#
#
# Rank: 32
# Completed stress experiment #3 of 3 with T gate indices: 115
# Time elapsed: 441ms
#
#
# Rank: 4
# Completed stress experiment #3 of 4 with T gate indices: 19
# Time elapsed: 439ms
#
#
# Rank: 4
# Loading stress experiment #4 of 4 with T gate indices: 20
#
#
# Rank: 31
# Completed stress experiment #2 of 3 with T gate indices: 111
# Time elapsed: 440ms
#
#
# Rank: 31
# Loading stress experiment #3 of 3 with T gate indices: 112
#
#
# Rank: 57
# Completed stress experiment #3 of 3 with T gate indices: 190
# Time elapsed: 439ms
#
#
# Rank: 15
# Completed stress experiment #1 of 4 with T gate indices: 61
# Time elapsed: 1s 510ms
#
#
# Rank: 15
# Loading stress experiment #2 of 4 with T gate indices: 62
#
#
# Rank: 18
# Completed stress experiment #1 of 3 with T gate indices: 71
# Time elapsed: 1s 516ms
#
#
# Rank: 18
# Loading stress experiment #2 of 3 with T gate indices: 72
#
#
# Rank: 33
# Completed stress experiment #1 of 3 with T gate indices: 116
# Time elapsed: 1s 512ms
#
#
# Rank: 33
# Loading stress experiment #2 of 3 with T gate indices: 117
#
#
# Rank: 48
# Completed stress experiment #2 of 3 with T gate indices: 162
# Time elapsed: 436ms
#
#
# Rank: 48
# Loading stress experiment #3 of 3 with T gate indices: 163
#
#
# Rank: 12
# Completed stress experiment #3 of 4 with T gate indices: 51
# Time elapsed: 435ms
#
#
# Rank: 12
# Loading stress experiment #4 of 4 with T gate indices: 52
#
#
# Rank: 24
# Completed stress experiment #3 of 3 with T gate indices: 91
# Time elapsed: 437ms
#
#
# Rank: 22
# Completed stress experiment #3 of 3 with T gate indices: 85
# Time elapsed: 441ms
#
#
# Rank: 10
# Completed stress experiment #2 of 4 with T gate indices: 42
# Time elapsed: 440ms
#
#
# Rank: 53
# Completed stress experiment #2 of 3 with T gate indices: 177
# Time elapsed: 439ms
#
#
# Rank: 53
# Loading stress experiment #3 of 3 with T gate indices: 178
#
#
# Rank: 10
# Loading stress experiment #3 of 4 with T gate indices: 43
#
#
# Rank: 54
# Completed stress experiment #3 of 3 with T gate indices: 181
# Time elapsed: 446ms
#
#
# Rank: 50
# Completed stress experiment #1 of 3 with T gate indices: 167
# Time elapsed: 1s 610ms
#
#
# Rank: 50
# Loading stress experiment #2 of 3 with T gate indices: 168
#
#
# Rank: 58
# Completed stress experiment #3 of 3 with T gate indices: 193
# Time elapsed: 439ms
#
#
# Rank: 8
# Completed stress experiment #1 of 4 with T gate indices: 33
# Time elapsed: 1s 619ms
#
#
# Rank: 8
# Loading stress experiment #2 of 4 with T gate indices: 34
#
#
# Rank: 36
# Completed stress experiment #3 of 3 with T gate indices: 127
# Time elapsed: 437ms
#
#
# Rank: 29
# Completed stress experiment #1 of 3 with T gate indices: 104
# Time elapsed: 1s 622ms
#
#
# Rank: 29
# Loading stress experiment #2 of 3 with T gate indices: 105
#
#
# Rank: 60
# Completed stress experiment #3 of 3 with T gate indices: 199
# Time elapsed: 438ms
#
#
# Rank: 51
# Completed stress experiment #3 of 3 with T gate indices: 172
# Time elapsed: 435ms
#
#
# Rank: 17
# Completed stress experiment #2 of 3 with T gate indices: 69
# Time elapsed: 433ms
#
#
# Rank: 17
# Loading stress experiment #3 of 3 with T gate indices: 70
#
#
# Rank: 61
# Completed stress experiment #2 of 3 with T gate indices: 201
# Time elapsed: 436ms
#
#
# Rank: 61
# Loading stress experiment #3 of 3 with T gate indices: 202
#
#
# Rank: 52
# Completed stress experiment #2 of 3 with T gate indices: 174
# Time elapsed: 449ms
#
#
# Rank: 52
# Loading stress experiment #3 of 3 with T gate indices: 175
#
#
# Rank: 16
# Completed stress experiment #3 of 3 with T gate indices: 67
# Time elapsed: 435ms
#
#
# Rank: 55
# Completed stress experiment #1 of 3 with T gate indices: 182
# Time elapsed: 1s 704ms
#
#
# Rank: 55
# Loading stress experiment #2 of 3 with T gate indices: 183
#
#
# Rank: 62
# Completed stress experiment #1 of 3 with T gate indices: 203
# Time elapsed: 1s 707ms
#
#
# Rank: 62
# Loading stress experiment #2 of 3 with T gate indices: 204
#
#
# Rank: 5
# Completed stress experiment #3 of 4 with T gate indices: 23
# Time elapsed: 443ms
#
#
# Rank: 13
# Completed stress experiment #3 of 4 with T gate indices: 55
# Time elapsed: 453ms
#
#
# Rank: 13
# Loading stress experiment #4 of 4 with T gate indices: 56
#
#
# Rank: 30
# Completed stress experiment #1 of 3 with T gate indices: 107
# Time elapsed: 1s 715ms
#
#
# Rank: 5
# Loading stress experiment #4 of 4 with T gate indices: 24
#
#
# Rank: 30
# Loading stress experiment #2 of 3 with T gate indices: 108
#
#
# Rank: 20
# Completed stress experiment #2 of 3 with T gate indices: 78
# Time elapsed: 430ms
#
#
# Rank: 20
# Loading stress experiment #3 of 3 with T gate indices: 79
#
#
# Rank: 59
# Completed stress experiment #2 of 3 with T gate indices: 195
# Time elapsed: 437ms
#
#
# Rank: 59
# Loading stress experiment #3 of 3 with T gate indices: 196
#
#
# Rank: 38
# Completed stress experiment #2 of 3 with T gate indices: 132
# Time elapsed: 434ms
#
#
# Rank: 38
# Loading stress experiment #3 of 3 with T gate indices: 133
#
#
# Rank: 0
# Completed stress experiment #4 of 4 with T gate indices: 4
# Time elapsed: 442ms
#
#
# Rank: 19
# Completed stress experiment #3 of 3 with T gate indices: 76
# Time elapsed: 439ms
#
#
# Rank: 63
# Completed stress experiment #3 of 3 with T gate indices: 208
# Time elapsed: 437ms
#
#
# Rank: 46
# Completed stress experiment #1 of 3 with T gate indices: 155
# Time elapsed: 1s 808ms
#
#
# Rank: 46
# Loading stress experiment #2 of 3 with T gate indices: 156
#
#
# Rank: 7
# Completed stress experiment #4 of 4 with T gate indices: 32
# Time elapsed: 440ms
#
#
# Rank: 23
# Completed stress experiment #3 of 3 with T gate indices: 88
# Time elapsed: 436ms
#
#
# Rank: 6
# Completed stress experiment #4 of 4 with T gate indices: 28
# Time elapsed: 441ms
#
#
# Rank: 47
# Completed stress experiment #2 of 3 with T gate indices: 159
# Time elapsed: 425ms
#
#
# Rank: 47
# Loading stress experiment #3 of 3 with T gate indices: 160
#
#
# Rank: 2
# Completed stress experiment #4 of 4 with T gate indices: 12
# Time elapsed: 443ms
#
#
# Rank: 11
# Completed stress experiment #1 of 4 with T gate indices: 45
# Time elapsed: 1s 809ms
#
#
# Rank: 11
# Loading stress experiment #2 of 4 with T gate indices: 46
#
#
# Rank: 9
# Completed stress experiment #2 of 4 with T gate indices: 38
# Time elapsed: 438ms
#
#
# Rank: 9
# Loading stress experiment #3 of 4 with T gate indices: 39
#
#
# Rank: 21
# Completed stress experiment #2 of 3 with T gate indices: 81
# Time elapsed: 440ms
#
#
# Rank: 21
# Loading stress experiment #3 of 3 with T gate indices: 82
#
#
# Rank: 3
# Completed stress experiment #4 of 4 with T gate indices: 16
# Time elapsed: 436ms
#
#
# Rank: 28
# Completed stress experiment #3 of 3 with T gate indices: 103
# Time elapsed: 439ms
#
#
# Rank: 1
# Completed stress experiment #4 of 4 with T gate indices: 8
# Time elapsed: 461ms
#
#
# Rank: 14
# Completed stress experiment #4 of 4 with T gate indices: 60
# Time elapsed: 444ms
#
#
# Rank: 34
# Completed stress experiment #3 of 3 with T gate indices: 121
# Time elapsed: 446ms
#
#
# Rank: 42
# Completed stress experiment #1 of 3 with T gate indices: 143
# Time elapsed: 1s 905ms
#
#
# Rank: 42
# Loading stress experiment #2 of 3 with T gate indices: 144
#
#
# Rank: 31
# Completed stress experiment #3 of 3 with T gate indices: 112
# Time elapsed: 438ms
#
#
# Rank: 4
# Completed stress experiment #4 of 4 with T gate indices: 20
# Time elapsed: 444ms
#
#
# Rank: 15
# Completed stress experiment #2 of 4 with T gate indices: 62
# Time elapsed: 436ms
#
#
# Rank: 15
# Loading stress experiment #3 of 4 with T gate indices: 63
#
#
# Rank: 18
# Completed stress experiment #2 of 3 with T gate indices: 72
# Time elapsed: 436ms
#
#
# Rank: 18
# Loading stress experiment #3 of 3 with T gate indices: 73
#
#
# Rank: 33
# Completed stress experiment #2 of 3 with T gate indices: 117
# Time elapsed: 434ms
#
#
# Rank: 33
# Loading stress experiment #3 of 3 with T gate indices: 118
#
#
# Rank: 12
# Completed stress experiment #4 of 4 with T gate indices: 52
# Time elapsed: 435ms
#
#
# Rank: 48
# Completed stress experiment #3 of 3 with T gate indices: 163
# Time elapsed: 442ms
#
#
# Rank: 53
# Completed stress experiment #3 of 3 with T gate indices: 178
# Time elapsed: 441ms
#
#
# Rank: 10
# Completed stress experiment #3 of 4 with T gate indices: 43
# Time elapsed: 450ms
#
#
# Rank: 10
# Loading stress experiment #4 of 4 with T gate indices: 44
#
#
# Rank: 50
# Completed stress experiment #2 of 3 with T gate indices: 168
# Time elapsed: 438ms
#
#
# Rank: 50
# Loading stress experiment #3 of 3 with T gate indices: 169
#
#
# Rank: 8
# Completed stress experiment #2 of 4 with T gate indices: 34
# Time elapsed: 437ms
#
#
# Rank: 8
# Loading stress experiment #3 of 4 with T gate indices: 35
#
#
# Rank: 17
# Completed stress experiment #3 of 3 with T gate indices: 70
# Time elapsed: 438ms
#
#
# Rank: 61
# Completed stress experiment #3 of 3 with T gate indices: 202
# Time elapsed: 432ms
#
#
# Rank: 52
# Completed stress experiment #3 of 3 with T gate indices: 175
# Time elapsed: 442ms
#
#
# Rank: 55
# Completed stress experiment #2 of 3 with T gate indices: 183
# Time elapsed: 431ms
#
#
# Rank: 55
# Loading stress experiment #3 of 3 with T gate indices: 184
#
#
# Rank: 62
# Completed stress experiment #2 of 3 with T gate indices: 204
# Time elapsed: 435ms
#
#
# Rank: 62
# Loading stress experiment #3 of 3 with T gate indices: 205
#
#
# Rank: 30
# Completed stress experiment #2 of 3 with T gate indices: 108
# Time elapsed: 436ms
#
#
# Rank: 30
# Loading stress experiment #3 of 3 with T gate indices: 109
#
#
# Rank: 13
# Completed stress experiment #4 of 4 with T gate indices: 56
# Time elapsed: 449ms
#
#
# Rank: 5
# Completed stress experiment #4 of 4 with T gate indices: 24
# Time elapsed: 453ms
#
#
# Rank: 20
# Completed stress experiment #3 of 3 with T gate indices: 79
# Time elapsed: 436ms
#
#
# Rank: 29
# Completed stress experiment #2 of 3 with T gate indices: 105
# Time elapsed: 564ms
#
#
# Rank: 29
# Loading stress experiment #3 of 3 with T gate indices: 106
#
#
# Rank: 38
# Completed stress experiment #3 of 3 with T gate indices: 133
# Time elapsed: 435ms
#
#
# Rank: 59
# Completed stress experiment #3 of 3 with T gate indices: 196
# Time elapsed: 442ms
#
#
# Rank: 46
# Completed stress experiment #2 of 3 with T gate indices: 156
# Time elapsed: 434ms
#
#
# Rank: 46
# Loading stress experiment #3 of 3 with T gate indices: 157
#
#
# Rank: 47
# Completed stress experiment #3 of 3 with T gate indices: 160
# Time elapsed: 431ms
#
#
# Rank: 11
# Completed stress experiment #2 of 4 with T gate indices: 46
# Time elapsed: 439ms
#
#
# Rank: 11
# Loading stress experiment #3 of 4 with T gate indices: 47
#
#
# Rank: 21
# Completed stress experiment #3 of 3 with T gate indices: 82
# Time elapsed: 438ms
#
#
# Rank: 9
# Completed stress experiment #3 of 4 with T gate indices: 39
# Time elapsed: 454ms
#
#
# Rank: 9
# Loading stress experiment #4 of 4 with T gate indices: 40
#
#
# Rank: 42
# Completed stress experiment #2 of 3 with T gate indices: 144
# Time elapsed: 439ms
#
#
# Rank: 42
# Loading stress experiment #3 of 3 with T gate indices: 145
#
#
# Rank: 15
# Completed stress experiment #3 of 4 with T gate indices: 63
# Time elapsed: 439ms
#
#
# Rank: 15
# Loading stress experiment #4 of 4 with T gate indices: 64
#
#
# Rank: 18
# Completed stress experiment #3 of 3 with T gate indices: 73
# Time elapsed: 442ms
#
#
# Rank: 33
# Completed stress experiment #3 of 3 with T gate indices: 118
# Time elapsed: 438ms
#
#
# Rank: 10
# Completed stress experiment #4 of 4 with T gate indices: 44
# Time elapsed: 442ms
#
#
# Rank: 50
# Completed stress experiment #3 of 3 with T gate indices: 169
# Time elapsed: 436ms
#
#
# Rank: 8
# Completed stress experiment #3 of 4 with T gate indices: 35
# Time elapsed: 442ms
#
#
# Rank: 8
# Loading stress experiment #4 of 4 with T gate indices: 36
#
#
# Rank: 55
# Completed stress experiment #3 of 3 with T gate indices: 184
# Time elapsed: 439ms
#
#
# Rank: 62
# Completed stress experiment #3 of 3 with T gate indices: 205
# Time elapsed: 441ms
#
#
# Rank: 30
# Completed stress experiment #3 of 3 with T gate indices: 109
# Time elapsed: 442ms
#
#
# Rank: 46
# Completed stress experiment #3 of 3 with T gate indices: 157
# Time elapsed: 437ms
#
#
# Rank: 29
# Completed stress experiment #3 of 3 with T gate indices: 106
# Time elapsed: 515ms
#
#
# Rank: 11
# Completed stress experiment #3 of 4 with T gate indices: 47
# Time elapsed: 442ms
#
#
# Rank: 11
# Loading stress experiment #4 of 4 with T gate indices: 48
#
#
# Rank: 9
# Completed stress experiment #4 of 4 with T gate indices: 40
# Time elapsed: 442ms
#
#
# Rank: 42
# Completed stress experiment #3 of 3 with T gate indices: 145
# Time elapsed: 439ms
#
#
# Rank: 15
# Completed stress experiment #4 of 4 with T gate indices: 64
# Time elapsed: 434ms
#
#
# Rank: 8
# Completed stress experiment #4 of 4 with T gate indices: 36
# Time elapsed: 444ms
#
#
# Rank: 11
# Completed stress experiment #4 of 4 with T gate indices: 48
# Time elapsed: 438ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 2                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 3                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 4                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 5                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 6                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 7                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 8                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 9                | 0.00              | 100.00            | 100.00            | 0.00              |
# | 10               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 11               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 12               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 13               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 14               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 15               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 16               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 17               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 18               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 19               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 20               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 21               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 22               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 23               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 24               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 25               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 26               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 27               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 28               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 29               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 30               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 31               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 32               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 33               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 34               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 35               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 36               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 37               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 38               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 39               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 40               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 41               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 42               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 43               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 44               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 45               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 46               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 47               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 48               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 49               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 50               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 51               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 52               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 53               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 54               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 55               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 56               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 57               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 58               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 59               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 60               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 61               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 62               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 63               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 64               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 65               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 66               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 67               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 68               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 69               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 70               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 71               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 72               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 73               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 74               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 75               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 76               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 77               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 78               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 79               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 80               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 81               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 82               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 83               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 84               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 85               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 86               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 87               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 88               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 89               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 90               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 91               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 92               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 93               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 94               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 95               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 96               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 97               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 98               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 99               | 0.00              | 100.00            | 100.00            | 0.00              |
# | 100              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 101              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 102              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 103              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 104              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 105              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 106              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 107              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 108              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 109              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 110              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 111              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 112              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 113              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 114              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 115              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 116              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 117              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 118              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 119              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 120              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 121              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 122              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 123              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 124              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 125              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 126              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 127              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 128              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 129              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 130              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 131              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 132              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 133              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 134              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 135              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 136              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 137              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 138              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 139              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 140              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 141              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 142              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 143              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 144              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 145              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 146              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 147              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 148              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 149              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 150              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 151              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 152              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 153              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 154              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 155              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 156              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 157              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 158              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 159              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 160              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 161              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 162              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 163              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 164              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 165              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 166              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 167              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 168              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 169              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 170              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 171              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 172              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 173              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 174              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 175              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 176              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 177              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 178              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 179              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 180              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 181              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 182              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 183              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 184              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 185              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 186              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 187              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 188              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 189              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 190              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 191              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 192              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 193              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 194              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 195              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 196              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 197              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 198              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 199              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 200              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 201              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 202              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 203              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 204              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 205              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 206              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 207              | 0.00              | 100.00            | 100.00            | 0.00              |
# | 208              | 0.00              | 100.00            | 100.00            | 0.00              |
#
#
# Time elapsed for stress testing 208 unique combinations: 5s 725ms
