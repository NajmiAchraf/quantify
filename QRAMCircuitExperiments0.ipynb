# %%
import sys
from QRAMCircuitExperiments import QRAMCircuitExperiments
from qramcircuits.toffoli_decomposition import ToffoliDecompType
from qramcircuits.bucket_brigade import MirrorMethod

# Simulate command-line arguments
sys.argv = ['notebook', 'y', 'd', 'n', '2', '2', "abmt"]

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CX 3) & (QC10)

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=ToffoliDecompType.NO_DECOMP,
    parallel_toffolis=False,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
    ],
    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: no
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate Specific Measurement: abmt
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 00,430
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 00,703
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 01,540
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 01,991
#
#
# ...

# %% [markdown]
# ## RESULTS AND BILAN OF THE EXPERIMENT
#
# ### Modded circuit results:
#
# - <span style="color:red">Failed: 00.00%</span>
# - <span style="color:green">Succeed: 100.00%</span>
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CX 3) & (QC10) FIRST EXPERIMENT

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
    ],
    parallel_toffolis=True,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: no
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate Specific Measurement: abmt
#
#
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 00,54
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 00,89
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 00,46
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 00,81
#
# ...

# %% [markdown]
# ## RESULTS AND BILAN OF THE EXPERIMENT
#
# ### Reference circuit results:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:green">Succeed: 100.00%</span>
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
#
#
# ### Modded circuit results:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:green">Succeed: 100.00%</span>
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 36               | 10                |
# | 3                | 20               | 45                   | 17               | 88               | 26                |
# | 4                | 37               | 57                   | 21               | 192              | 58                |
# | 5                | 70               | 69                   | 25               | 400              | 122               |
# | 6                | 135              | 81                   | 29               | 816              | 250               |
#
#
#
# ## COMPARING RESULTS
#
# ### Simulation comparison:
#
# - <span style="color:red">Failed: 0.00% vs 0.00%</span>
# - <span style="color:green">Succeed: 100.00% vs 100.00%</span>
#
# ### T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded     | T Count Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 36 (90.00%)        | 4 (-10.00%)            |
# | 3                | 96                 | 88 (91.67%)        | 8 (-8.33%)             |
# | 4                | 208                | 192 (92.31%)       | 16 (-7.69%)            |
# | 5                | 432                | 400 (92.59%)       | 32 (-7.41%)            |
# | 6                | 880                | 816 (92.73%)       | 64 (-7.27%)            |
#
#
# ### T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded     | T Depth Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 13 (100.00%)       | 0 (-0.00%)             |
# | 3                | 17                 | 17 (100.00%)       | 0 (-0.00%)             |
# | 4                | 21                 | 21 (100.00%)       | 0 (-0.00%)             |
# | 5                | 25                 | 25 (100.00%)       | 0 (-0.00%)             |
# | 6                | 29                 | 29 (100.00%)       | 0 (-0.00%)             |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 0 CX 3) & (QC10) SECOND EXPERIMENT

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3,
    ],
    parallel_toffolis=True,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_0_CX_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_0_CX_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: no
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate Specific Measurement: abmt
#
#
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 00,49
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 00,76
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 00,32
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Failed: 0.00%
# Succeed: 100.00%
#
# Time spent on the decomposition simulation: 00,57
#
# ...

# %% [markdown]
# ## RESULTS AND BILAN OF THE EXPERIMENT
#
# ### Reference circuit results:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:green">Succeed: 100.00%</span>
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
#
#
# ### Modded circuit results:
#
# - <span style="color:red">Failed: 18.75%</span>
# - <span style="color:green">Succeed: 81.25%</span>
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 25                   | 5                | 20               | 10                |
# | 3                | 20               | 33                   | 5                | 40               | 26                |
# | 4                | 37               | 41                   | 5                | 80               | 58                |
# | 5                | 70               | 49                   | 5                | 160              | 122               |
# | 6                | 135              | 57                   | 5                | 320              | 250               |
#
#
#
# ## COMPARING RESULTS
#
# ### Simulation comparison:
#
# - <span style="color:red">Failed: 0.00% vs 18.75%</span>
# - <span style="color:green">Succeed: 100.00% vs 81.25%</span>
#
# ### T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded     | T Count Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 20 (50.00%)        | 20 (-50.00%)           |
# | 3                | 96                 | 40 (41.67%)        | 56 (-58.33%)           |
# | 4                | 208                | 80 (38.46%)        | 128 (-61.54%)          |
# | 5                | 432                | 160 (37.04%)       | 272 (-62.96%)          |
# | 6                | 880                | 320 (36.36%)       | 560 (-63.64%)          |
#
#
# ### T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded     | T Depth Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 5 (38.46%)         | 8 (-61.54%)            |
# | 3                | 17                 | 5 (29.41%)         | 12 (-70.59%)           |
# | 4                | 21                 | 5 (23.81%)         | 16 (-76.19%)           |
# | 5                | 25                 | 5 (20.00%)         | 20 (-80.00%)           |
# | 6                | 29                 | 5 (17.24%)         | 24 (-82.76%)           |
