# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD4_TC6_CX6 for Query

# %%
import sys
from make import *
from main_experiments import main

t_count = 6

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 2
# End range of qubits: 2
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 1s 535ms
# 	• RSS (Memory Usage): 221.84 MB
# 	• VMS (Memory Usage): 1.68 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 315ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD4_TC6_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  214ms
#
# Display decomposition ToffoliDecompType.AN0_TD4_TC6_CX6 circuit:
# Time elapsed on displaying the circuit:  318ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 36               | 10                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 513ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
make_slurm("experiments", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD4_TC6_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 218ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 226ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |      2048        |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 46.88% • Output vector: 53.12% )
#
# Time elapsed on simulation and comparison: 1s 269ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# Rank: 31
# Loading stress experiment #1 of 1 with T gate indices: 32
#
#
# Rank: 22
# Loading stress experiment #1 of 1 with T gate indices: 23
#
#
# Rank: 30
# Loading stress experiment #1 of 1 with T gate indices: 31
#
#
# Rank: 20
# Loading stress experiment #1 of 1 with T gate indices: 21
#
#
# Rank: 25
# Loading stress experiment #1 of 1 with T gate indices: 26
#
#
# Rank: 1
# Loading stress experiment #1 of 1 with T gate indices: 2
#
#
# Rank: 2
# Loading stress experiment #1 of 1 with T gate indices: 3
#
#
# Rank: 17
# Loading stress experiment #1 of 1 with T gate indices: 18
#
#
# Rank: 4
# Loading stress experiment #1 of 1 with T gate indices: 5
#
#
# Rank: 14
# Loading stress experiment #1 of 1 with T gate indices: 15
#
#
# Rank: 10
# Loading stress experiment #1 of 1 with T gate indices: 11
#
#
# Rank: 21
# Loading stress experiment #1 of 1 with T gate indices: 22
#
#
# Rank: 8
# Loading stress experiment #1 of 1 with T gate indices: 9
#
#
# Rank: 27
# Loading stress experiment #1 of 1 with T gate indices: 28
#
#
# Rank: 23
# Loading stress experiment #1 of 1 with T gate indices: 24
#
#
# Rank: 19
# Loading stress experiment #1 of 1 with T gate indices: 20
#
#
# Rank: 11
# Loading stress experiment #1 of 1 with T gate indices: 12
#
#
# Rank: 24
# Loading stress experiment #1 of 1 with T gate indices: 25
#
#
# Rank: 13
# Loading stress experiment #1 of 1 with T gate indices: 14
#
#
# Rank: 18
# Loading stress experiment #1 of 1 with T gate indices: 19
#
#
# Rank: 12
# Loading stress experiment #1 of 1 with T gate indices: 13
#
#
# Rank: 7
# Loading stress experiment #1 of 1 with T gate indices: 8
#
#
# Rank: 9
# Loading stress experiment #1 of 1 with T gate indices: 10
#
#
# Rank: 28
# Loading stress experiment #1 of 1 with T gate indices: 29
#
#
# Rank: 32
# Loading stress experiment #1 of 1 with T gate indices: 33
#
#
# Rank: 16
# Loading stress experiment #1 of 1 with T gate indices: 17
#
#
# Rank: 33
# Loading stress experiment #1 of 1 with T gate indices: 34
#
#
# Rank: 26
# Loading stress experiment #1 of 1 with T gate indices: 27
#
#
# Rank: 29
# Loading stress experiment #1 of 1 with T gate indices: 30
#
#
# Rank: 5
# Loading stress experiment #1 of 1 with T gate indices: 6
#
#
# Rank: 34
# Loading stress experiment #1 of 1 with T gate indices: 35
#
#
# Rank: 6
# Loading stress experiment #1 of 1 with T gate indices: 7
#
#
# Rank: 35
# Loading stress experiment #1 of 1 with T gate indices: 36
#
#
# Rank: 15
# Loading stress experiment #1 of 1 with T gate indices: 16
#
#
# Rank: 0
# Loading stress experiment #1 of 1 with T gate indices: 1
#
#
# Rank: 3
# Loading stress experiment #1 of 1 with T gate indices: 4
#
#
# Rank: 22
# Completed stress experiment #1 of 1 with T gate indices: 23
# Time elapsed: 2s 486ms
#
#
# Rank: 1
# Completed stress experiment #1 of 1 with T gate indices: 2
# Time elapsed: 2s 533ms
#
#
# Rank: 25
# Completed stress experiment #1 of 1 with T gate indices: 26
# Time elapsed: 2s 546ms
#
#
# Rank: 20
# Completed stress experiment #1 of 1 with T gate indices: 21
# Time elapsed: 2s 551ms
#
#
# Rank: 30
# Completed stress experiment #1 of 1 with T gate indices: 31
# Time elapsed: 2s 570ms
#
#
# Rank: 2
# Completed stress experiment #1 of 1 with T gate indices: 3
# Time elapsed: 2s 591ms
#
#
# Rank: 17
# Completed stress experiment #1 of 1 with T gate indices: 18
# Time elapsed: 2s 594ms
#
#
# Rank: 4
# Completed stress experiment #1 of 1 with T gate indices: 5
# Time elapsed: 2s 615ms
#
#
# Rank: 31
# Completed stress experiment #1 of 1 with T gate indices: 32
# Time elapsed: 2s 622ms
#
#
# Rank: 14
# Completed stress experiment #1 of 1 with T gate indices: 15
# Time elapsed: 2s 659ms
#
#
# Rank: 10
# Completed stress experiment #1 of 1 with T gate indices: 11
# Time elapsed: 2s 685ms
#
#
# Rank: 21
# Completed stress experiment #1 of 1 with T gate indices: 22
# Time elapsed: 2s 696ms
#
#
# Rank: 27
# Completed stress experiment #1 of 1 with T gate indices: 28
# Time elapsed: 2s 749ms
#
#
# Rank: 8
# Completed stress experiment #1 of 1 with T gate indices: 9
# Time elapsed: 2s 756ms
#
#
# Rank: 23
# Completed stress experiment #1 of 1 with T gate indices: 24
# Time elapsed: 2s 844ms
#
#
# Rank: 19
# Completed stress experiment #1 of 1 with T gate indices: 20
# Time elapsed: 2s 903ms
#
#
# Rank: 24
# Completed stress experiment #1 of 1 with T gate indices: 25
# Time elapsed: 2s 919ms
#
#
# Rank: 11
# Completed stress experiment #1 of 1 with T gate indices: 12
# Time elapsed: 2s 963ms
#
#
# Rank: 13
# Completed stress experiment #1 of 1 with T gate indices: 14
# Time elapsed: 2s 987ms
#
#
# Rank: 18
# Completed stress experiment #1 of 1 with T gate indices: 19
# Time elapsed: 3s 130ms
#
#
# Rank: 12
# Completed stress experiment #1 of 1 with T gate indices: 13
# Time elapsed: 3s 204ms
#
#
# Rank: 7
# Completed stress experiment #1 of 1 with T gate indices: 8
# Time elapsed: 3s 331ms
#
#
# Rank: 9
# Completed stress experiment #1 of 1 with T gate indices: 10
# Time elapsed: 3s 450ms
#
#
# Rank: 28
# Completed stress experiment #1 of 1 with T gate indices: 29
# Time elapsed: 3s 482ms
#
#
# Rank: 32
# Completed stress experiment #1 of 1 with T gate indices: 33
# Time elapsed: 3s 486ms
#
#
# Rank: 16
# Completed stress experiment #1 of 1 with T gate indices: 17
# Time elapsed: 3s 626ms
#
#
# Rank: 33
# Completed stress experiment #1 of 1 with T gate indices: 34
# Time elapsed: 3s 658ms
#
#
# Rank: 26
# Completed stress experiment #1 of 1 with T gate indices: 27
# Time elapsed: 3s 898ms
#
#
# Rank: 29
# Completed stress experiment #1 of 1 with T gate indices: 30
# Time elapsed: 3s 974ms
#
#
# Rank: 34
# Completed stress experiment #1 of 1 with T gate indices: 35
# Time elapsed: 4s 33ms
#
#
# Rank: 5
# Completed stress experiment #1 of 1 with T gate indices: 6
# Time elapsed: 4s 60ms
#
#
# Rank: 6
# Completed stress experiment #1 of 1 with T gate indices: 7
# Time elapsed: 4s 211ms
#
#
# Rank: 35
# Completed stress experiment #1 of 1 with T gate indices: 36
# Time elapsed: 4s 400ms
#
#
# Rank: 15
# Completed stress experiment #1 of 1 with T gate indices: 16
# Time elapsed: 4s 479ms
#
#
# Rank: 0
# Completed stress experiment #1 of 1 with T gate indices: 1
# Time elapsed: 4s 546ms
#
#
# Rank: 3
# Completed stress experiment #1 of 1 with T gate indices: 4
# Time elapsed: 4s 617ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 10.30             | 89.70             | 37.79             | 51.90             |
# | 2                | 8.84              | 91.16             | 38.87             | 52.29             |
# | 3                | 9.23              | 90.77             | 28.17             | 62.60             |
# | 4                | 4.39              | 95.61             | 31.54             | 64.06             |
# | 5                | 7.13              | 92.87             | 40.97             | 51.90             |
# | 6                | 8.98              | 91.02             | 39.16             | 51.86             |
# | 7                | 9.91              | 90.09             | 27.69             | 62.40             |
# | 8                | 7.03              | 92.97             | 29.54             | 63.43             |
# | 9                | 0.00              | 100.00            | 50.00             | 50.00             |
# | 10               | 0.00              | 100.00            | 50.00             | 50.00             |
# | 11               | 0.00              | 100.00            | 50.00             | 50.00             |
# | 12               | 0.00              | 100.00            | 50.00             | 50.00             |
# | 13               | 0.00              | 100.00            | 42.19             | 57.81             |
# | 14               | 0.00              | 100.00            | 42.19             | 57.81             |
# | 15               | 0.00              | 100.00            | 42.19             | 57.81             |
# | 16               | 0.00              | 100.00            | 42.19             | 57.81             |
# | 17               | 11.62             | 88.38             | 41.60             | 46.78             |
# | 18               | 11.77             | 88.23             | 41.31             | 46.92             |
# | 19               | 17.19             | 82.81             | 38.48             | 44.34             |
# | 20               | 11.08             | 88.92             | 40.38             | 48.54             |
# | 21               | 11.33             | 88.67             | 32.96             | 55.71             |
# | 22               | 7.81              | 92.19             | 30.27             | 61.91             |
# | 23               | 9.72              | 90.28             | 33.45             | 56.84             |
# | 24               | 21.24             | 78.76             | 26.95             | 51.81             |
# | 25               | 12.79             | 87.21             | 30.81             | 56.40             |
# | 26               | 18.41             | 81.59             | 29.30             | 52.29             |
# | 27               | 8.20              | 91.80             | 31.74             | 60.06             |
# | 28               | 14.84             | 85.16             | 29.93             | 55.22             |
# | 29               | 9.86              | 90.14             | 38.13             | 52.00             |
# | 30               | 7.91              | 92.09             | 39.75             | 52.34             |
# | 31               | 5.76              | 94.24             | 30.62             | 63.62             |
# | 32               | 6.20              | 93.80             | 30.62             | 63.18             |
# | 33               | 9.23              | 90.77             | 38.67             | 52.10             |
# | 34               | 9.57              | 90.43             | 38.43             | 52.00             |
# | 35               | 7.96              | 92.04             | 29.20             | 62.84             |
# | 36               | 7.18              | 92.82             | 29.59             | 63.23             |
#
#
# Time elapsed for stress testing 36 unique combinations: 5s 295ms

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 3
# End range of qubits: 3
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 3 Qbits
# 	• Time elapsed on creation: 797ms
# 	• RSS (Memory Usage): 224.09 MB
# 	• VMS (Memory Usage): 1.74 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 28                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  2s 970ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD4_TC6_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  219ms
#
# Display decomposition ToffoliDecompType.AN0_TD4_TC6_CX6 circuit:
# Time elapsed on displaying the circuit:  313ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 45                   | 17               | 88               | 26                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  3s 476ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 207ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD4_TC6_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 225ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 49.61% • Output vector: 50.39% )
#
# Time elapsed on simulation and comparison: 14h 14min 54s 887ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")
# Out:
# Rank: 3
# Loading stress experiment #1 of 3 with T gate indices: 10
#
#
# Rank: 6
# Loading stress experiment #1 of 3 with T gate indices: 19
#
#
# Rank: 20
# Loading stress experiment #1 of 3 with T gate indices: 61
#
#
# Rank: 8
# Loading stress experiment #1 of 3 with T gate indices: 25
#
#
# Rank: 28
# Loading stress experiment #1 of 2 with T gate indices: 81
#
#
# Rank: 30
# Loading stress experiment #1 of 2 with T gate indices: 85
#
#
# Rank: 31
# Loading stress experiment #1 of 2 with T gate indices: 87
#
#
# Rank: 4
# Loading stress experiment #1 of 3 with T gate indices: 13
#
#
# Rank: 7
# Loading stress experiment #1 of 3 with T gate indices: 22
#
#
# Rank: 11
# Loading stress experiment #1 of 3 with T gate indices: 34
#
#
# Rank: 10
# Loading stress experiment #1 of 3 with T gate indices: 31
#
#
# Rank: 29
# Loading stress experiment #1 of 2 with T gate indices: 83
#
#
# Rank: 2
# Loading stress experiment #1 of 3 with T gate indices: 7
#
#
# Rank: 13
# Loading stress experiment #1 of 3 with T gate indices: 40
#
#
# Rank: 24
# Loading stress experiment #1 of 2 with T gate indices: 73
#
#
# Rank: 1
# Loading stress experiment #1 of 3 with T gate indices: 4
#
#
# Rank: 18
# Loading stress experiment #1 of 3 with T gate indices: 55
#
#
# Rank: 22
# Loading stress experiment #1 of 3 with T gate indices: 67
#
#
# Rank: 27
# Loading stress experiment #1 of 2 with T gate indices: 79
#
#
# Rank: 23
# Loading stress experiment #1 of 3 with T gate indices: 70
#
#
# Rank: 17
# Loading stress experiment #1 of 3 with T gate indices: 52
#
#
# Rank: 15
# Loading stress experiment #1 of 3 with T gate indices: 46
#
#
# Rank: 9
# Loading stress experiment #1 of 3 with T gate indices: 28
#
#
# Rank: 26
# Loading stress experiment #1 of 2 with T gate indices: 77
#
#
# Rank: 12
# Loading stress experiment #1 of 3 with T gate indices: 37
#
#
# Rank: 0
# Loading stress experiment #1 of 3 with T gate indices: 1
#
#
# Rank: 19
# Loading stress experiment #1 of 3 with T gate indices: 58
#
#
# Rank: 25
# Loading stress experiment #1 of 2 with T gate indices: 75
#
#
# Rank: 16
# Loading stress experiment #1 of 3 with T gate indices: 49
#
#
# Rank: 14
# Loading stress experiment #1 of 3 with T gate indices: 43
#
#
# Rank: 5
# Loading stress experiment #1 of 3 with T gate indices: 16
#
#
# Rank: 21
# Loading stress experiment #1 of 3 with T gate indices: 64
#
#
# Rank: 17
# Completed stress experiment #1 of 3 with T gate indices: 52
# Time elapsed: 23h 33min 46s 184ms
#
#
# Rank: 17
# Loading stress experiment #2 of 3 with T gate indices: 53
#
#
# Rank: 16
# Completed stress experiment #1 of 3 with T gate indices: 49
# Time elapsed: 23h 34min 32s 392ms
#
#
# Rank: 16
# Loading stress experiment #2 of 3 with T gate indices: 50
#
#
# Rank: 18
# Completed stress experiment #1 of 3 with T gate indices: 55
# Time elapsed: 23h 35min 3s 315ms
#
#
# Rank: 18
# Loading stress experiment #2 of 3 with T gate indices: 56
#
#
# Rank: 25
# Completed stress experiment #1 of 2 with T gate indices: 75
# Time elapsed: 23h 35min 14s 224ms
#
#
# Rank: 25
# Loading stress experiment #2 of 2 with T gate indices: 76
#
#
# Rank: 4
# Completed stress experiment #1 of 3 with T gate indices: 13
# Time elapsed: 23h 35min 55s 102ms
#
#
# Rank: 4
# Loading stress experiment #2 of 3 with T gate indices: 14
#
#
# Rank: 6
# Completed stress experiment #1 of 3 with T gate indices: 19
# Time elapsed: 23h 35min 57s 153ms
#
#
# Rank: 6
# Loading stress experiment #2 of 3 with T gate indices: 20
#
#
# Rank: 23
# Completed stress experiment #1 of 3 with T gate indices: 70
# Time elapsed: 23h 36min 3s 90ms
#
#
# Rank: 23
# Loading stress experiment #2 of 3 with T gate indices: 71
#
#
# Rank: 20
# Completed stress experiment #1 of 3 with T gate indices: 61
# Time elapsed: 23h 36min 14s 611ms
#
#
# Rank: 20
# Loading stress experiment #2 of 3 with T gate indices: 62
#
#
# Rank: 8
# Completed stress experiment #1 of 3 with T gate indices: 25
# Time elapsed: 23h 36min 32s 705ms
#
#
# Rank: 8
# Loading stress experiment #2 of 3 with T gate indices: 26
#
#
# Rank: 21
# Completed stress experiment #1 of 3 with T gate indices: 64
# Time elapsed: 23h 37min 1s 183ms
#
#
# Rank: 21
# Loading stress experiment #2 of 3 with T gate indices: 65
#
#
# Rank: 1
# Completed stress experiment #1 of 3 with T gate indices: 4
# Time elapsed: 23h 37min 23s 138ms
#
#
# Rank: 1
# Loading stress experiment #2 of 3 with T gate indices: 5
#
#
# Rank: 0
# Completed stress experiment #1 of 3 with T gate indices: 1
# Time elapsed: 23h 37min 43s 956ms
#
#
# Rank: 0
# Loading stress experiment #2 of 3 with T gate indices: 2
#
#
# Rank: 22
# Completed stress experiment #1 of 3 with T gate indices: 67
# Time elapsed: 23h 37min 48s 525ms
#
#
# Rank: 22
# Loading stress experiment #2 of 3 with T gate indices: 68
#
#
# Rank: 7
# Completed stress experiment #1 of 3 with T gate indices: 22
# Time elapsed: 23h 38min 15s 935ms
#
#
# Rank: 7
# Loading stress experiment #2 of 3 with T gate indices: 23
#
#
# Rank: 13
# Completed stress experiment #1 of 3 with T gate indices: 40
# Time elapsed: 23h 38min 22s 302ms
#
#
# Rank: 13
# Loading stress experiment #2 of 3 with T gate indices: 41
#
#
# Rank: 19
# Completed stress experiment #1 of 3 with T gate indices: 58
# Time elapsed: 23h 39min 38s 213ms
#
#
# Rank: 19
# Loading stress experiment #2 of 3 with T gate indices: 59
#
#
# Rank: 26
# Completed stress experiment #1 of 2 with T gate indices: 77
# Time elapsed: 23h 39min 55s 411ms
#
#
# Rank: 26
# Loading stress experiment #2 of 2 with T gate indices: 78
#
#
# Rank: 27
# Completed stress experiment #1 of 2 with T gate indices: 79
# Time elapsed: 23h 39min 57s 345ms
#
#
# Rank: 27
# Loading stress experiment #2 of 2 with T gate indices: 80
#
#
# Rank: 24
# Completed stress experiment #1 of 2 with T gate indices: 73
# Time elapsed: 23h 40min 4s 314ms
#
#
# Rank: 24
# Loading stress experiment #2 of 2 with T gate indices: 74
#
#
# Rank: 11
# Completed stress experiment #1 of 3 with T gate indices: 34
# Time elapsed: 23h 40min 8s 683ms
#
#
# Rank: 11
# Loading stress experiment #2 of 3 with T gate indices: 35
#
#
# Rank: 9
# Completed stress experiment #1 of 3 with T gate indices: 28
# Time elapsed: 23h 40min 44s 348ms
#
#
# Rank: 9
# Loading stress experiment #2 of 3 with T gate indices: 29
#
#
# Rank: 12
# Completed stress experiment #1 of 3 with T gate indices: 37
# Time elapsed: 23h 40min 47s 639ms
#
#
# Rank: 12
# Loading stress experiment #2 of 3 with T gate indices: 38
#
#
# Rank: 3
# Completed stress experiment #1 of 3 with T gate indices: 10
# Time elapsed: 23h 40min 51s 109ms
#
#
# Rank: 3
# Loading stress experiment #2 of 3 with T gate indices: 11
#
#
# Rank: 29
# Completed stress experiment #1 of[0
#
#
# Rank: 3
# Loading stress experiment #1 of 3 with T gate indices: 10
#
# [9
# Rank: 19
# Completed stress experiment #2 of 3 with T gate indices: 59
# Time elapsed: 23h 25min 26s 643ms
#
#
# Rank: 19
# Loading stress experiment #3 of 3 with T gate indices: 60
#
#
# Rank: 17
# Completed stress experiment #2 of 3 with T gate indices: 53
# Time elapsed: 23h 34min 47s 423ms
#
#
# Rank: 17
# Loading stress experiment #3 of 3 with T gate indices: 54
#
#
# Rank: 25
# Completed stress experiment #2 of 2 with T gate indices: 76
# Time elapsed: 23h 35min 5s 601ms
#
#
# Rank: 18
# Completed stress experiment #2 of 3 with T gate indices: 56
# Time elapsed: 23h 35min 24s 434ms
#
#
# Rank: 18
# Loading stress experiment #3 of 3 with T gate indices: 57
#
#
# Rank: 16
# Completed stress experiment #2 of 3 with T gate indices: 50
# Time elapsed: 23h 36min 10s 601ms
#
#
# Rank: 16
# Loading stress experiment #3 of 3 with T gate indices: 51
#
#
# Rank: 4
# Completed stress experiment #2 of 3 with T gate indices: 14
# Time elapsed: 23h 36min 16s 998ms
#
#
# Rank: 4
# Loading stress experiment #3 of 3 with T gate indices: 15
#
#
# Rank: 23
# Completed stress experiment #2 of 3 with T gate indices: 71
# Time elapsed: 23h 36min 24s 672ms
#
#
# Rank: 23
# Loading stress experiment #3 of 3 with T gate indices: 72
#
#
# Rank: 20
# Completed stress experiment #2 of 3 with T gate indices: 62
# Time elapsed: 23h 36min 32s 640ms
#
#
# Rank: 20
# Loading stress experiment #3 of 3 with T gate indices: 63
#
#
# Rank: 6
# Completed stress experiment #2 of 3 with T gate indices: 20
# Time elapsed: 23h 38min 5s 819ms
#
#
# Rank: 6
# Loading stress experiment #3 of 3 with T gate indices: 21
#
#
# Rank: 8
# Completed stress experiment #2 of 3 with T gate indices: 26
# Time elapsed: 23h 37min 31s 263ms
#
#
# Rank: 8
# Loading stress experiment #3 of 3 with T gate indices: 27
#
#
# Rank: 0
# Completed stress experiment #2 of 3 with T gate indices: 2
# Time elapsed: 23h 36min 30s 587ms
#
#
# Rank: 0
# Loading stress experiment #3 of 3 with T gate indices: 3
#
#
# Rank: 22
# Completed stress experiment #2 of 3 with T gate indices: 68
# Time elapsed: 23h 36min 32s 534ms
#
#
# Rank: 22
# Loading stress experiment #3 of 3 with T gate indices: 69
#
#
# Rank: 21
# Completed stress experiment #2 of 3 with T gate indices: 65
# Time elapsed: 23h 37min 25s 397ms
#
#
# Rank: 21
# Loading stress experiment #3 of 3 with T gate indices: 66
#
#
# Rank: 1
# Completed stress experiment #2 of 3 with T gate indices: 5
# Time elapsed: 23h 37min 29s 281ms
#
#
# Rank: 1
# Loading stress experiment #3 of 3 with T gate indices: 6
#
#
# Rank: 7
# Completed stress experiment #2 of 3 with T gate indices: 23
# Time elapsed: 23h 37min 57s 887ms
#
#
# Rank: 7
# Loading stress experiment #3 of 3 with T gate indices: 24
#
#
# Rank: 13
# Completed stress experiment #2 of 3 with T gate indices: 41
# Time elapsed: 23h 38min 33s 253ms
#
#
# Rank: 13
# Loading stress experiment #3 of 3 with T gate indices: 42
#
#
# Rank: 26
# Completed stress experiment #2 of 2 with T gate indices: 78
# Time elapsed: 23h 37min 32s 887ms
#
#
# Rank: 24
# Completed stress experiment #2 of 2 with T gate indices: 74
# Time elapsed: 23h 39min 22s 937ms
#
#
# Rank: 11
# Completed stress experiment #2 of 3 with T gate indices: 35
# Time elapsed: 23h 39min 54s 920ms
#
#
# Rank: 11
# Loading stress experiment #3 of 3 with T gate indices: 36
#
#
# Rank: 27
# Completed stress experiment #2 of 2 with T gate indices: 80
# Time elapsed: 23h 40min 25s 780ms
#
#
# Rank: 12
# Completed stress experiment #2 of 3 with T gate indices: 38
# Time elapsed: 23h 40min 7s 411ms
#
#
# Rank: 12
# Loading stress experiment #3 of 3 with T gate indices: 39
#
#
# Rank: 9
# Completed stress experiment #2 of 3 with T gate indices: 29
# Time elapsed: 23h 40min 47s 128ms
#
#
# Rank: 9
# Loading stress experiment #3 of 3 with T gate indices: 30
#
#
# Rank: 3
# Completed stress experiment #2 of 3 with T gate indices: 11
# Time elapsed: 23h 40min 44s 559ms
#
#
# Rank: 3
# Loading stress experiment #3 of 3 with T gate indices: 12
#
#
# Rank: 29
# Completed stress experiment #2 of 2 with T gate indices: 84
# Time elapsed: 23h 41min 12s 279ms
#
#
# Rank: 30
# Completed stress experiment #2 of 2 with T gate indices: 86
# Time elapsed: 23h 46min 1s 415ms
#
#
# Rank: 2
# Completed stress experiment #2 of 3 with T gate indices: 8
# Time elapsed: 23h 44min 34s 598ms
#
#
# Rank: 2
# Loading stress experiment #3 of 3 with T gate indices: 9
#
#
# Rank: 10
# Completed stress experiment #2 of 3 with T gate indices: 32
# Time elapsed: 23h 44min 48s 702ms
#
#
# Rank: 10
# Loading stress experiment #3 of 3 with T gate indices: 33
#
#
# Rank: 15
# Completed stress experiment #2 of 3 with T gate indices: 47
# Time elapsed: 23h 44min 17s 219ms
#
#
# Rank: 15
# Loading stress experiment #3 of 3 with T gate indices: 48
#
#
# Rank: 5
# Completed stress experiment #2 of 3 with T gate indices: 17
# Time elapsed: 23h 45min 38s 754ms
#
#
# Rank: 5
# Loading stress experiment #3 of 3 with T gate indices: 18
#
#
# Rank: 31
# Completed stress experiment #2 of 2 with T gate indices: 88
# Time elapsed: 23h 36min 9s 451ms
#
#
# Rank: 14
# Completed stress experiment #2 of 3 with T gate indices: 44
# Time elapsed: 23h 48min 28s 741ms
#
#
# Rank: 14
# Loading stress experiment #3 of 3 with T gate indices: 45
#
#
# Rank: 28
# Completed stress experiment #2 of 2 with T gate indices: 82
# Time elapsed: 23h 49min 21s 907ms
#
#
# Rank: 19
# Completed stress experiment #3 of 3 with T gate indices: 60
# Time elapsed: 23h 25min 59s 622ms
#
#
# Rank: 17
# Completed stress experiment #3 of 3 with T gate indices: 54
# Time elapsed: 23h 36min 4s 202ms
#
#
# Rank: 16
# Completed stress experiment #3 of 3 with T gate indices: 51
# Time elapsed: 23h 34min 40s 227ms
#
#
# Rank: 18
# Completed stress experiment #3 of 3 with T gate indices: 57
# Time elapsed: 23h 36min 15s 276ms
#
#
# Rank: 23
# Completed stress experiment #3 of 3 with T gate indices: 72
# Time elapsed: 23h 36min 33s 201ms
#
#
# Rank: 20
# Completed stress experiment #3 of 3 with T gate indices: 63
# Time elapsed: 23h 36min 15s 551ms
#
#
# Rank: 4
# Completed stress experiment #3 of 3 with T gate indices: 15
# Time elapsed: 23h 36min 54s 43ms
#
#
# Rank: 22
# Completed stress experiment #3 of 3 with T gate indices: 69
# Time elapsed: 23h 36min 19s 62ms
#
#
# Rank: 8
# Completed stress experiment #3 of 3 with T gate indices: 27
# Time elapsed: 23h 37min 1s 515ms
#
#
# Rank: 21
# Completed stress experiment #3 of 3 with T gate indices: 66
# Time elapsed: 23h 36min 51s 485ms
#
#
# Rank: 0
# Completed stress experiment #3 of 3 with T gate indices: 3
# Time elapsed: 23h 37min 42s 686ms
#
#
# Rank: 6
# Completed stress experiment #3 of 3 with T gate indices: 21
# Time elapsed: 23h 38min 1s 326ms
#
#
# Rank: 1
# Completed stress experiment #3 of 3 with T gate indices: 6
# Time elapsed: 23h 38min 3s 655ms
#
#
# Rank: 7
# Completed stress experiment #3 of 3 with T gate indices: 24
# Time elapsed: 23h 38min 25s 433ms
#
#
# Rank: 13
# Completed stress experiment #3 of 3 with T gate indices: 42
# Time elapsed: 23h 38min 43s 880ms
#
#
# Rank: 11
# Completed stress experiment #3 of 3 with T gate indices: 36
# Time elapsed: 23h 40min 43s 704ms
#
#
# Rank: 12
# Completed stress experiment #3 of 3 with T gate indices: 39
# Time elapsed: 23h 40min 19s 550ms
#
#
# Rank: 3
# Completed stress experiment #3 of 3 with T gate indices: 12
# Time elapsed: 23h 39min 50s 676ms
#
#
# Rank: 9
# Completed stress experiment #3 of 3 with T gate indices: 30
# Time elapsed: 23h 42min 5s 342ms
#
#
# Rank: 5
# Completed stress experiment #3 of 3 with T gate indices: 18
# Time elapsed: 23h 42min 21s 467ms
#
#
# Rank: 2
# Completed stress experiment #3 of 3 with T gate indices: 9
# Time elapsed: 23h 45min 49s 266ms
#
#
# Rank: 15
# Completed stress experiment #3 of 3 with T gate indices: 48
# Time elapsed: 23h 45min 24s 256ms
#
#
# Rank: 10
# Completed stress experiment #3 of 3 with T gate indices: 33
# Time elapsed: 23h 45min 51s 224ms
#
#
# Rank: 14
# Completed stress experiment #3 of 3 with T gate indices: 45
# Time elapsed: 23h 50min 27s 560ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 7.26              | 92.74             | 41.10             | 51.64             |
# | 2                | 7.24              | 92.76             | 41.11             | 51.65             |
# | 3                | 7.47              | 92.53             | 40.91             | 51.62             |
# | 4                | 7.31              | 92.69             | 41.05             | 51.63             |
# | 5                | 7.39              | 92.61             | 40.98             | 51.63             |
# | 6                | 7.25              | 92.75             | 41.11             | 51.64             |
# | 7                | 7.26              | 92.74             | 41.10             | 51.64             |
# | 8                | 7.31              | 92.69             | 41.05             | 51.64             |
# | 9                | 7.23              | 92.77             | 41.13             | 51.64             |
# | 10               | 7.26              | 92.74             | 41.11             | 51.63             |
# | 11               | 7.26              | 92.74             | 41.10             | 51.64             |
# | 12               | 7.29              | 92.71             | 41.07             | 51.64             |
# | 13               | 7.35              | 92.65             | 41.01             | 51.63             |
# | 14               | 7.22              | 92.78             | 41.14             | 51.64             |
# | 15               | 7.35              | 92.65             | 41.01             | 51.64             |
# | 16               | 7.49              | 92.51             | 40.88             | 51.64             |
# | 17               | 7.38              | 92.62             | 40.99             | 51.63             |
# | 18               | 7.51              | 92.49             | 40.85             | 51.64             |
# | 19               | 7.21              | 92.79             | 41.16             | 51.64             |
# | 20               | 7.45              | 92.55             | 40.92             | 51.63             |
# | 21               | 7.29              | 92.71             | 41.07             | 51.64             |
# | 22               | 7.47              | 92.53             | 40.89             | 51.64             |
# | 23               | 7.39              | 92.61             | 40.97             | 51.64             |
# | 24               | 7.46              | 92.54             | 40.91             | 51.64             |
# | 25               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 26               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 27               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 28               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 29               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 30               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 31               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 32               | 0.00              | 100.00            | 49.12             | 50.88             |
# | 33               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 34               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 35               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 36               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 37               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 38               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 39               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 40               | 0.00              | 100.00            | 49.02             | 50.98             |
# | 41               | 14.78             | 85.22             | 40.94             | 44.28             |
# | 42               | 14.78             | 85.22             | 40.94             | 44.28             |
# | 43               | 14.71             | 85.29             | 40.97             | 44.33             |
# | 44               | 14.71             | 85.29             | 40.97             | 44.33             |
# | 45               | 14.71             | 85.29             | 40.97             | 44.33             |
# | 46               | 14.61             | 85.39             | 41.07             | 44.32             |
# | 47               | 14.61             | 85.39             | 41.07             | 44.32             |
# | 48               | 14.61             | 85.39             | 41.07             | 44.32             |
# | 49               | 14.79             | 85.21             | 40.95             | 44.26             |
# | 50               | 14.79             | 85.21             | 40.95             | 44.26             |
# | 51               | 14.79             | 85.21             | 40.95             | 44.26             |
# | 52               | 14.79             | 85.21             | 41.10             | 44.11             |
# | 53               | 14.79             | 85.21             | 41.10             | 44.11             |
# | 54               | 14.79             | 85.21             | 41.10             | 44.11             |
# | 55               | 14.51             | 85.49             | 41.24             | 44.26             |
# | 56               | 14.51             | 85.49             | 41.24             | 44.26             |
# | 57               | 14.51             | 85.49             | 41.24             | 44.26             |
# | 58               | 14.73             | 85.27             | 41.04             | 44.24             |
# | 59               | 14.73             | 85.27             | 41.04             | 44.24             |
# | 60               | 14.73             | 85.27             | 41.04             | 44.24             |
# | 61               | 14.60             | 85.40             | 41.12             | 44.28             |
# | 62               | 14.60             | 85.40             | 41.12             | 44.28             |
# | 63               | 14.60             | 85.40             | 41.12             | 44.28             |
# | 64               | 14.51             | 85.49             | 41.11             | 44.38             |
# | 65               | 7.25              | 92.75             | 41.11             | 51.64             |
# | 66               | 7.49              | 92.51             | 40.88             | 51.63             |
# | 67               | 7.39              | 92.61             | 40.97             | 51.64             |
# | 68               | 7.46              | 92.54             | 40.91             | 51.63             |
# | 69               | 7.49              | 92.51             | 40.88             | 51.64             |
# | 70               | 7.30              | 92.70             | 41.06             | 51.64             |
# | 71               | 7.28              | 92.72             | 41.08             | 51.64             |
# | 72               | 7.49              | 92.51             | 40.87             | 51.64             |
# | 73               | 7.47              | 92.53             | 40.90             | 51.63             |
# | 74               | 7.31              | 92.69             | 41.05             | 51.64             |
# | 75               | 7.32              | 92.68             | 41.05             | 51.64             |
# | 76               | 7.31              | 92.69             | 41.04             | 51.64             |
# | 77               | 7.42              | 92.58             | 40.95             | 51.63             |
# | 78               | 7.32              | 92.68             | 41.04             | 51.64             |
# | 79               | 7.37              | 92.63             | 41.00             | 51.63             |
# | 80               | 7.35              | 92.65             | 41.03             | 51.63             |
# | 81               | 7.36              | 92.64             | 41.00             | 51.64             |
# | 82               | 7.38              | 92.62             | 40.98             | 51.64             |
# | 83               | 7.28              | 92.72             | 41.07             | 51.65             |
# | 84               | 7.41              | 92.59             | 40.95             | 51.63             |
# | 85               | 7.28              | 92.72             | 41.08             | 51.64             |
# | 86               | 7.31              | 92.69             | 41.04             | 51.64             |
# | 87               | 7.40              | 92.60             | 40.96             | 51.64             |
# | 88               | 7.45              | 92.55             | 40.92             | 51.63             |
#
#
# Time elapsed for stress testing 88 unique combinations: 2d 23h 27min 39s 80ms

# %% [markdown]
# ## Bilan comparing the QRAM circuit Query AN0_TD4_TC6_CX6 WITH the QRAM circuit Query AN0_TD4_TC7_CX6

# %%
make_slurm("bilan", "2-10", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 10
#
# ================================================
#
#
# Loading bilan done
#
#
# Bilan of the experiment:
#
# Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 210ms                      | 207.23 MB              | 1.13 GB                |
# | 3                | 462ms                      | 207.75 MB              | 1.13 GB                |
# | 4                | 1s 223ms                   | 208.51 MB              | 1.13 GB                |
# | 5                | 3s 676ms                   | 209.70 MB              | 1.13 GB                |
# | 6                | 13s 149ms                  | 211.81 MB              | 1.13 GB                |
# | 7                | 52s 176ms                  | 216.34 MB              | 1.13 GB                |
# | 8                | 4min 3s 391ms              | 224.83 MB              | 1.14 GB                |
# | 9                | 22min 0s 544ms             | 242.67 MB              | 1.15 GB                |
# | 10               | 2h 14min 52s 957ms         | 276.00 MB              | 1.17 GB                |
#
#
# Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
# | 7                | 264              | 93                   | 33               | 1776             | 506               |
# | 8                | 521              | 105                  | 37               | 3568             | 1018              |
# | 9                | 1034             | 117                  | 41               | 7152             | 2042              |
# | 10               | 2059             | 129                  | 45               | 14320            | 4090              |
#
#
# Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 36               | 10                |
# | 3                | 20               | 45                   | 17               | 88               | 26                |
# | 4                | 37               | 57                   | 21               | 192              | 58                |
# | 5                | 70               | 69                   | 25               | 400              | 122               |
# | 6                | 135              | 81                   | 29               | 816              | 250               |
# | 7                | 264              | 93                   | 33               | 1648             | 506               |
# | 8                | 521              | 105                  | 37               | 3312             | 1018              |
# | 9                | 1034             | 117                  | 41               | 6640             | 2042              |
# | 10               | 2059             | 129                  | 45               | 13296            | 4090              |
#
#
# Comparing bilans
#
# T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded (%) | T Count Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 36  ( 90.00 )      | 4  ( 10.00 )           |
# | 3                | 96                 | 88  ( 91.67 )      | 8  ( 8.33 )            |
# | 4                | 208                | 192  ( 92.31 )     | 16  ( 7.69 )           |
# | 5                | 432                | 400  ( 92.59 )     | 32  ( 7.41 )           |
# | 6                | 880                | 816  ( 92.73 )     | 64  ( 7.27 )           |
# | 7                | 1776               | 1648  ( 92.79 )    | 128  ( 7.21 )          |
# | 8                | 3568               | 3312  ( 92.83 )    | 256  ( 7.17 )          |
# | 9                | 7152               | 6640  ( 92.84 )    | 512  ( 7.16 )          |
# | 10               | 14320              | 13296  ( 92.85 )   | 1024  ( 7.15 )         |
#
#
# T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded (%) | T Depth Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 13  ( 100.00 )     | 0  ( 0.00 )            |
# | 3                | 17                 | 17  ( 100.00 )     | 0  ( 0.00 )            |
# | 4                | 21                 | 21  ( 100.00 )     | 0  ( 0.00 )            |
# | 5                | 25                 | 25  ( 100.00 )     | 0  ( 0.00 )            |
# | 6                | 29                 | 29  ( 100.00 )     | 0  ( 0.00 )            |
# | 7                | 33                 | 33  ( 100.00 )     | 0  ( 0.00 )            |
# | 8                | 37                 | 37  ( 100.00 )     | 0  ( 0.00 )            |
# | 9                | 41                 | 41  ( 100.00 )     | 0  ( 0.00 )            |
# | 10               | 45                 | 45  ( 100.00 )     | 0  ( 0.00 )            |
#
#
# Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded (%)   | Depth Cancelled (%)    |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 33  ( 100.00 )     | 0  ( 0.00 )            |
# | 3                | 45                 | 45  ( 100.00 )     | 0  ( 0.00 )            |
# | 4                | 57                 | 57  ( 100.00 )     | 0  ( 0.00 )            |
# | 5                | 69                 | 69  ( 100.00 )     | 0  ( 0.00 )            |
# | 6                | 81                 | 81  ( 100.00 )     | 0  ( 0.00 )            |
# | 7                | 93                 | 93  ( 100.00 )     | 0  ( 0.00 )            |
# | 8                | 105                | 105  ( 100.00 )    | 0  ( 0.00 )            |
# | 9                | 117                | 117  ( 100.00 )    | 0  ( 0.00 )            |
# | 10               | 129                | 129  ( 100.00 )    | 0  ( 0.00 )            |
