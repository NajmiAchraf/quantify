# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD3_TC4_CX6 for Query

# %%
import sys
from make import *
from main_experiments import main

t_count = 4

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 2
# End range of qubits: 2
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 937ms
# 	• RSS (Memory Usage): 222.40 MB
# 	• VMS (Memory Usage): 1.68 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# Time elapsed on displaying the circuit:  1s 305ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.AN0_TD3_TC4_CX6 circuit:
# Time elapsed on displaying the circuit:  324ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  200ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# Display modded circuit:
# Time elapsed on displaying the circuit:  1s 543ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
make_slurm("experiments", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 212ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD3_TC4_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 37.50% • Output vector: 62.50% )
#
# Time elapsed on simulation and comparison: 216ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |      2048        |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 21.09% • Output vector: 78.91% )
#
# Time elapsed on simulation and comparison: 1s 227ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 121ms
# 	• RSS (Memory Usage): 206.90 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 206.79 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 123ms
# 	• RSS (Memory Usage): 207.51 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 123ms
# 	• RSS (Memory Usage): 206.98 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 123ms
# 	• RSS (Memory Usage): 207.27 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 122ms
# 	• RSS (Memory Usage): 207.16 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 207.07 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 127ms
# 	• RSS (Memory Usage): 207.24 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# ======================================================================================================================================================
#
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 121ms
# 	• RSS (Memory Usage): 207.21 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 207.34 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 206.83 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 123ms
# 	• RSS (Memory Usage): 206.89 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Verifying the depth and count of the bucket brigade circuit:
#
# Decomposition scenario of bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
# Decomposition scenario of modded circuit:
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 206.95 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 121ms
# 	• RSS (Memory Usage): 207.19 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 207.02 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 123ms
# 	• RSS (Memory Usage): 207.33 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 122ms
# 	• RSS (Memory Usage): 207.18 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 125ms
# 	• RSS (Memory Usage): 207.26 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 122ms
# 	• RSS (Memory Usage): 207.21 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Decomposition scenario of bucket brigade circuit:
#
# Verifying the depth and count of the bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Decomposition scenario of modded circuit:
#
# Verifying the depth and count of the bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 125ms
# 	• RSS (Memory Usage): 207.25 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 206.68 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 122ms
# 	• RSS (Memory Usage): 206.88 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# ...
#
#
# Optimization methods of bucket brigade circuit:
#
#
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Decomposition scenario of bucket brigade circuit:
#
# Verifying the depth and count of the bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Decomposition scenario of modded circuit:
#
# Verifying the depth and count of the bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 122ms
# 	• RSS (Memory Usage): 207.14 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# Verifying the depth and count of the bucket brigade circuit:
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 124ms
# 	• RSS (Memory Usage): 207.22 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	Decomposition scenario of bucket brigade circuit:
#
# ======================================================================================================================================================
#
#
# ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
# Hello QRAM circuit!
#
# Simulate Toffoli decompositions and circuit: yes
# Hide circuits
# Hide simulation results
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 128ms
# 	• RSS (Memory Usage): 206.49 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
#
# ======================================================================================================================================================
#
#
#
# Loading stress experiment with T gate indices: 1
#
#
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices: 5
#
#
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices: 19
#
#
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices: 14
#
#  4
#
# 9
#
#
# Loading stress experiment with T gate indices:12
#
# 24
#
#
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:  8
#
# 26
#
#
# Loading stress experiment with T gate indices: 22
#
#  7
#
#   23
#
#
# Loading stress experiment with T gate indices: 15
#
#
# Loading stress experiment with T gate indices: 20
#
#  16
#
# 3
#
#  6
#
#  27
#
# 17
#
# 13
#
# 28
#
# 10
#
#  21
#
#
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:
# Loading stress experiment with T gate indices:25
#
# 18
#
# 11
#
#  2
#
#
# Completed stress experiment with T gate indices: 24
# Time elapsed:
# Completed stress experiment with T gate indices: 23
# Time elapsed: 2s 393ms
#
# 2s 393ms
#
#
# Completed stress experiment with T gate indices: 1
# Time elapsed: 2s 397ms
#
#
# Completed stress experiment with T gate indices: 16
# Time elapsed: 2s 405ms
#
#
# Completed stress experiment with T gate indices: 6
# Time elapsed: 2s 408ms
#
#
# Completed stress experiment with T gate indices: 19
# Time elapsed: 2s 411ms
#
#
# Completed stress experiment with T gate indices: 7
# Time elapsed: 2s 415ms
#
#
# Completed stress experiment with T gate indices: 27
# Time elapsed: 2s 417ms
#
#
# Completed stress experiment with T gate indices: 3
# Time elapsed: 2s 418ms
#
#
# Completed stress experiment with T gate indices: 28
# Time elapsed: 2s 423ms
#
#
# Completed stress experiment with T gate indices: 13
# Time elapsed:
# Completed stress experiment with T gate indices: 10
# Time elapsed: 2s 432ms
#
# 2s 432ms
#
#
# Completed stress experiment with T gate indices: 12
# Time elapsed: 2s 432ms
#
#
# Completed stress experiment with T gate indices: 17
# Time elapsed: 2s 433ms
#
#
# Completed stress experiment with T gate indices: 2
# Time elapsed: 2s 433ms
#
#
# Completed stress experiment with T gate indices: 20
# Time elapsed: 2s 435ms
#
#
# Completed stress experiment with T gate indices: 9
# Time elapsed: 2s 436ms
#
#
# Completed stress experiment with T gate indices: 11
# Time elapsed: 2s 439ms
#
#
# Completed stress experiment with T gate indices: 8
# Time elapsed: 2s 443ms
#
#
# Completed stress experiment with T gate indices: 4
# Time elapsed: 2s 445ms
#
#
# Completed stress experiment with T gate indices: 26
# Time elapsed: 2s 462ms
#
#
# Completed stress experiment with T gate indices: 21
# Time elapsed: 2s 462ms
#
#
# Completed stress experiment with T gate indices: 5
# Time elapsed: 2s 463ms
#
#
# Completed stress experiment with T gate indices: 15
# Time elapsed: 2s 467ms
#
#
# Completed stress experiment with T gate indices: 25
# Time elapsed: 2s 467ms
#
#
# Completed stress experiment with T gate indices: 14
# Time elapsed: 2s 496ms
#
#
# Completed stress experiment with T gate indices: 18
# Time elapsed: 2s 506ms
#
#
# Completed stress experiment with T gate indices: 22
# Time elapsed: 2s 514ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 10.21             | 89.79             | 16.80             | 73.00             |
# | 2                | 6.01              | 93.99             | 18.21             | 75.78             |
# | 3                | 10.99             | 89.01             | 16.89             | 72.12             |
# | 4                | 5.47              | 94.53             | 18.95             | 75.59             |
# | 5                | 5.57              | 94.43             | 18.75             | 75.68             |
# | 6                | 5.66              | 94.34             | 19.19             | 75.15             |
# | 7                | 9.33              | 90.67             | 17.29             | 73.39             |
# | 8                | 8.40              | 91.60             | 18.21             | 73.39             |
# | 9                | 10.69             | 89.31             | 18.99             | 70.31             |
# | 10               | 13.43             | 86.57             | 18.55             | 68.02             |
# | 11               | 13.72             | 86.28             | 17.04             | 69.24             |
# | 12               | 19.09             | 80.91             | 16.16             | 64.75             |
# | 13               | 15.62             | 84.38             | 19.19             | 65.19             |
# | 14               | 15.43             | 84.57             | 19.63             | 64.94             |
# | 15               | 11.33             | 88.67             | 18.46             | 70.21             |
# | 16               | 17.29             | 82.71             | 16.36             | 66.36             |
# | 17               | 21.92             | 78.08             | 16.85             | 61.23             |
# | 18               | 15.38             | 84.62             | 18.90             | 65.72             |
# | 19               | 14.40             | 85.60             | 18.12             | 67.48             |
# | 20               | 17.38             | 82.62             | 17.43             | 65.19             |
# | 21               | 7.91              | 92.09             | 18.16             | 73.93             |
# | 22               | 7.23              | 92.77             | 18.16             | 74.61             |
# | 23               | 8.98              | 91.02             | 17.77             | 73.24             |
# | 24               | 7.81              | 92.19             | 17.38             | 74.80             |
# | 25               | 7.76              | 92.24             | 17.82             | 74.41             |
# | 26               | 8.15              | 91.85             | 18.12             | 73.73             |
# | 27               | 8.11              | 91.89             | 17.53             | 74.37             |
# | 28               | 10.45             | 89.55             | 16.55             | 73.00             |
#
#
# Time elapsed for stress testing 28 unique combinations: 3s 852ms

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 3
# End range of qubits: 3
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 3 Qbits
# 	• Time elapsed on creation: 615ms
# 	• RSS (Memory Usage): 224.03 MB
# 	• VMS (Memory Usage): 1.74 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 28                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# Time elapsed on displaying the circuit:  3s 115ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.AN0_TD3_TC4_CX6 circuit:
# Time elapsed on displaying the circuit:  534ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  303ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 45                   | 15               | 72               | 26                |
#
# Display modded circuit:
# Time elapsed on displaying the circuit:  3s 906ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 210ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD3_TC4_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 37.50% • Output vector: 62.50% )
#
# Time elapsed on simulation and comparison: 225ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 31.53% • Output vector: 68.47% )
#
# Time elapsed on simulation and comparison: 12h 56min 48s 982ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")

# %% [markdown]
# ## Bilan comparing the QRAM circuit Query AN0_TD3_TC4_CX6 WITH the QRAM circuit Query AN0_TD4_TC7_CX6

# %%
make_slurm("bilan", "2-10", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 10
#
# ================================================
#
# Loading bilan done
#
#
# Bilan of the experiment:
#
# Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 161ms                      | 207.32 MB              | 1.13 GB                |
# | 3                | 319ms                      | 207.50 MB              | 1.13 GB                |
# | 4                | 852ms                      | 208.17 MB              | 1.13 GB                |
# | 5                | 2s 692ms                   | 209.37 MB              | 1.13 GB                |
# | 6                | 10s 475ms                  | 211.39 MB              | 1.13 GB                |
# | 7                | 45s 680ms                  | 215.66 MB              | 1.13 GB                |
# | 8                | 3min 50s 997ms             | 222.24 MB              | 1.14 GB                |
# | 9                | 25min 55s 580ms            | 238.48 MB              | 1.14 GB                |
# | 10               | 3h 8min 16s 511ms          | 269.55 MB              | 1.16 GB                |
#
#
# Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
# | 3                | 20               | 47                   | 17               | 96               | 26                |
# | 4                | 37               | 59                   | 21               | 208              | 58                |
# | 5                | 70               | 71                   | 25               | 432              | 122               |
# | 6                | 135              | 83                   | 29               | 880              | 250               |
# | 7                | 264              | 95                   | 33               | 1776             | 506               |
# | 8                | 521              | 107                  | 37               | 3568             | 1018              |
# | 9                | 1034             | 119                  | 41               | 7152             | 2042              |
# | 10               | 2059             | 131                  | 45               | 14320            | 4090              |
#
#
# Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 11               | 28               | 10                |
# | 3                | 20               | 45                   | 15               | 72               | 26                |
# | 4                | 37               | 57                   | 19               | 160              | 58                |
# | 5                | 70               | 69                   | 23               | 336              | 122               |
# | 6                | 135              | 81                   | 27               | 688              | 250               |
# | 7                | 264              | 93                   | 31               | 1392             | 506               |
# | 8                | 521              | 105                  | 35               | 2800             | 1018              |
# | 9                | 1034             | 117                  | 39               | 5616             | 2042              |
# | 10               | 2059             | 129                  | 43               | 11248            | 4090              |
#
#
# Comparing bilans
#
# T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded (%) | T Count Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 28  ( 70.00 )      | 12  ( 30.00 )          |
# | 3                | 96                 | 72  ( 75.00 )      | 24  ( 25.00 )          |
# | 4                | 208                | 160  ( 76.92 )     | 48  ( 23.08 )          |
# | 5                | 432                | 336  ( 77.78 )     | 96  ( 22.22 )          |
# | 6                | 880                | 688  ( 78.18 )     | 192  ( 21.82 )         |
# | 7                | 1776               | 1392  ( 78.38 )    | 384  ( 21.62 )         |
# | 8                | 3568               | 2800  ( 78.48 )    | 768  ( 21.52 )         |
# | 9                | 7152               | 5616  ( 78.52 )    | 1536  ( 21.48 )        |
# | 10               | 14320              | 11248  ( 78.55 )   | 3072  ( 21.45 )        |
#
#
# T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded (%) | T Depth Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 11  ( 84.62 )      | 2  ( 15.38 )           |
# | 3                | 17                 | 15  ( 88.24 )      | 2  ( 11.76 )           |
# | 4                | 21                 | 19  ( 90.48 )      | 2  ( 9.52 )            |
# | 5                | 25                 | 23  ( 92.00 )      | 2  ( 8.00 )            |
# | 6                | 29                 | 27  ( 93.10 )      | 2  ( 6.90 )            |
# | 7                | 33                 | 31  ( 93.94 )      | 2  ( 6.06 )            |
# | 8                | 37                 | 35  ( 94.59 )      | 2  ( 5.41 )            |
# | 9                | 41                 | 39  ( 95.12 )      | 2  ( 4.88 )            |
# | 10               | 45                 | 43  ( 95.56 )      | 2  ( 4.44 )            |
#
#
# Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded (%)   | Depth Cancelled (%)    |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 35                 | 33  ( 94.29 )      | 2  ( 5.71 )            |
# | 3                | 47                 | 45  ( 95.74 )      | 2  ( 4.26 )            |
# | 4                | 59                 | 57  ( 96.61 )      | 2  ( 3.39 )            |
# | 5                | 71                 | 69  ( 97.18 )      | 2  ( 2.82 )            |
# | 6                | 83                 | 81  ( 97.59 )      | 2  ( 2.41 )            |
# | 7                | 95                 | 93  ( 97.89 )      | 2  ( 2.11 )            |
# | 8                | 107                | 105  ( 98.13 )     | 2  ( 1.87 )            |
# | 9                | 119                | 117  ( 98.32 )     | 2  ( 1.68 )            |
# | 10               | 131                | 129  ( 98.47 )     | 2  ( 1.53 )            |
