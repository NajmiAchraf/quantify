# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD3_TC4_CX6 for Query

# %%
import sys
from make import *
from main_experiments import main

t_count = 4

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 2
# End range of qubits: 2
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 1s 540ms
# 	• RSS (Memory Usage): 221.71 MB
# 	• VMS (Memory Usage): 1.68 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  1s 464ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.AN0_TD3_TC4_CX6 circuit:
# Time elapsed on displaying the circuit:  337ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  236ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 31                   | 11               | 28               | 10                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  2s 173ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
make_slurm("experiments", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 212ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD3_TC4_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 37.50% • Output vector: 62.50% )
#
# Time elapsed on simulation and comparison: 216ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |      2048        |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 21.09% • Output vector: 78.91% )
#
# Time elapsed on simulation and comparison: 1s 227ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# Rank: 21
# Loading stress experiment #1 of 1 with T gate indices: 22
#
#
# Rank: 9
# Loading stress experiment #1 of 1 with T gate indices: 10
#
#
# Rank: 7
# Loading stress experiment #1 of 1 with T gate indices: 8
#
#
# Rank: 4
# Loading stress experiment #1 of 1 with T gate indices: 5
#
#
# Rank: 11
# Loading stress experiment #1 of 1 with T gate indices: 12
#
#
# Rank: 16
# Loading stress experiment #1 of 1 with T gate indices: 17
#
#
# Rank: 23
# Loading stress experiment #1 of 1 with T gate indices: 24
#
#
# Rank: 20
# Loading stress experiment #1 of 1 with T gate indices: 21
#
#
# Rank: 8
# Loading stress experiment #1 of 1 with T gate indices: 9
#
#
# Rank: 22
# Loading stress experiment #1 of 1 with T gate indices: 23
#
#
# Rank: 2
# Loading stress experiment #1 of 1 with T gate indices: 3
#
#
# Rank: 19
# Loading stress experiment #1 of 1 with T gate indices: 20
#
#
# Rank: 25
# Loading stress experiment #1 of 1 with T gate indices: 26
#
#
# Rank: 1
# Loading stress experiment #1 of 1 with T gate indices: 2
#
#
# Rank: 14
# Loading stress experiment #1 of 1 with T gate indices: 15
#
#
# Rank: 26
# Loading stress experiment #1 of 1 with T gate indices: 27
#
#
# Rank: 10
# Loading stress experiment #1 of 1 with T gate indices: 11
#
#
# Rank: 6
# Loading stress experiment #1 of 1 with T gate indices: 7
#
#
# Rank: 27
# Loading stress experiment #1 of 1 with T gate indices: 28
#
#
# Rank: 5
# Loading stress experiment #1 of 1 with T gate indices: 6
#
#
# Rank: 15
# Loading stress experiment #1 of 1 with T gate indices: 16
#
#
# Rank: 24
# Loading stress experiment #1 of 1 with T gate indices: 25
#
#
# Rank: 18
# Loading stress experiment #1 of 1 with T gate indices: 19
#
#
# Rank: 12
# Loading stress experiment #1 of 1 with T gate indices: 13
#
#
# Rank: 13
# Loading stress experiment #1 of 1 with T gate indices: 14
#
#
# Rank: 17
# Loading stress experiment #1 of 1 with T gate indices: 18
#
#
# Rank: 0
# Loading stress experiment #1 of 1 with T gate indices: 1
#
#
# Rank: 3
# Loading stress experiment #1 of 1 with T gate indices: 4
#
#
# Rank: 21
# Completed stress experiment #1 of 1 with T gate indices: 22
# Time elapsed: 2s 419ms
#
#
# Rank: 7
# Completed stress experiment #1 of 1 with T gate indices: 8
# Time elapsed: 2s 425ms
#
#
# Rank: 4
# Completed stress experiment #1 of 1 with T gate indices: 5
# Time elapsed: 2s 450ms
#
#
# Rank: 9
# Completed stress experiment #1 of 1 with T gate indices: 10
# Time elapsed: 2s 469ms
#
#
# Rank: 11
# Completed stress experiment #1 of 1 with T gate indices: 12
# Time elapsed: 2s 485ms
#
#
# Rank: 16
# Completed stress experiment #1 of 1 with T gate indices: 17
# Time elapsed: 2s 511ms
#
#
# Rank: 23
# Completed stress experiment #1 of 1 with T gate indices: 24
# Time elapsed: 2s 556ms
#
#
# Rank: 22
# Completed stress experiment #1 of 1 with T gate indices: 23
# Time elapsed: 2s 562ms
#
#
# Rank: 20
# Completed stress experiment #1 of 1 with T gate indices: 21
# Time elapsed: 2s 565ms
#
#
# Rank: 8
# Completed stress experiment #1 of 1 with T gate indices: 9
# Time elapsed: 2s 589ms
#
#
# Rank: 19
# Completed stress experiment #1 of 1 with T gate indices: 20
# Time elapsed: 2s 649ms
#
#
# Rank: 2
# Completed stress experiment #1 of 1 with T gate indices: 3
# Time elapsed: 2s 672ms
#
#
# Rank: 25
# Completed stress experiment #1 of 1 with T gate indices: 26
# Time elapsed: 2s 754ms
#
#
# Rank: 26
# Completed stress experiment #1 of 1 with T gate indices: 27
# Time elapsed: 2s 760ms
#
#
# Rank: 1
# Completed stress experiment #1 of 1 with T gate indices: 2
# Time elapsed: 2s 798ms
#
#
# Rank: 14
# Completed stress experiment #1 of 1 with T gate indices: 15
# Time elapsed: 2s 857ms
#
#
# Rank: 6
# Completed stress experiment #1 of 1 with T gate indices: 7
# Time elapsed: 2s 892ms
#
#
# Rank: 10
# Completed stress experiment #1 of 1 with T gate indices: 11
# Time elapsed: 2s 907ms
#
#
# Rank: 27
# Completed stress experiment #1 of 1 with T gate indices: 28
# Time elapsed: 3s 3ms
#
#
# Rank: 5
# Completed stress experiment #1 of 1 with T gate indices: 6
# Time elapsed: 3s 59ms
#
#
# Rank: 15
# Completed stress experiment #1 of 1 with T gate indices: 16
# Time elapsed: 3s 195ms
#
#
# Rank: 24
# Completed stress experiment #1 of 1 with T gate indices: 25
# Time elapsed: 3s 324ms
#
#
# Rank: 18
# Completed stress experiment #1 of 1 with T gate indices: 19
# Time elapsed: 3s 424ms
#
#
# Rank: 12
# Completed stress experiment #1 of 1 with T gate indices: 13
# Time elapsed: 3s 521ms
#
#
# Rank: 13
# Completed stress experiment #1 of 1 with T gate indices: 14
# Time elapsed: 3s 613ms
#
#
# Rank: 17
# Completed stress experiment #1 of 1 with T gate indices: 18
# Time elapsed: 3s 703ms
#
#
# Rank: 0
# Completed stress experiment #1 of 1 with T gate indices: 1
# Time elapsed: 3s 837ms
#
#
# Rank: 3
# Completed stress experiment #1 of 1 with T gate indices: 4
# Time elapsed: 3s 942ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 7.67              | 92.33             | 17.92             | 74.41             |
# | 2                | 8.74              | 91.26             | 17.24             | 74.02             |
# | 3                | 10.06             | 89.94             | 16.85             | 73.10             |
# | 4                | 10.94             | 89.06             | 16.21             | 72.85             |
# | 5                | 7.62              | 92.38             | 18.21             | 74.17             |
# | 6                | 6.30              | 93.70             | 18.51             | 75.20             |
# | 7                | 6.79              | 93.21             | 18.60             | 74.61             |
# | 8                | 5.08              | 94.92             | 19.09             | 75.83             |
# | 9                | 14.60             | 85.40             | 19.24             | 66.16             |
# | 10               | 18.26             | 81.74             | 18.65             | 63.09             |
# | 11               | 14.11             | 85.89             | 17.58             | 68.31             |
# | 12               | 14.01             | 85.99             | 17.43             | 68.55             |
# | 13               | 8.79              | 91.21             | 20.36             | 70.85             |
# | 14               | 17.43             | 82.57             | 16.89             | 65.67             |
# | 15               | 18.85             | 81.15             | 16.06             | 65.09             |
# | 16               | 16.89             | 83.11             | 16.75             | 66.36             |
# | 17               | 10.79             | 89.21             | 18.95             | 70.26             |
# | 18               | 18.60             | 81.40             | 16.89             | 64.50             |
# | 19               | 11.57             | 88.43             | 18.12             | 70.31             |
# | 20               | 14.50             | 85.50             | 19.09             | 66.41             |
# | 21               | 10.06             | 89.94             | 16.55             | 73.39             |
# | 22               | 7.52              | 92.48             | 18.51             | 73.97             |
# | 23               | 6.59              | 93.41             | 18.95             | 74.46             |
# | 24               | 7.81              | 92.19             | 17.82             | 74.37             |
# | 25               | 7.67              | 92.33             | 17.92             | 74.41             |
# | 26               | 5.62              | 94.38             | 18.80             | 75.59             |
# | 27               | 6.79              | 93.21             | 18.65             | 74.56             |
# | 28               | 6.69              | 93.31             | 17.97             | 75.34             |
#
#
# Time elapsed for stress testing 28 unique combinations: 4s 287ms

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d']

main()
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Display
# Start range of qubits: 3
# End range of qubits: 3
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 3 Qbits
# 	• Time elapsed on creation: 865ms
# 	• RSS (Memory Usage): 223.84 MB
# 	• VMS (Memory Usage): 1.74 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 28                   | -                | -                | -                 |
#
# Display bucket brigade circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  2s 895ms
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.AN0_TD3_TC4_CX6
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Display decomposition ToffoliDecompType.AN0_TD3_TC4_CX6 circuit:
# Time elapsed on displaying the circuit:  334ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3 circuit:
# Time elapsed on displaying the circuit:  275ms
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 3                | 20               | 43                   | 15               | 72               | 26                |
#
# Display modded circuit:
# <img width="100%" style="background-color:white;" src="data:image/svg+xml;base64,..." >
# Time elapsed on displaying the circuit:  3s 313ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 210ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.AN0_TD3_TC4_CX6
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 37.50% • Output vector: 62.50% )
#
# Time elapsed on simulation and comparison: 225ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 31.53% • Output vector: 68.47% )
#
# Time elapsed on simulation and comparison: 12h 56min 48s 982ms
#
# ======================================================================================================================================================

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ======================================================================================================================================================
#
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
#
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 31.53% • Output vector: 68.47% )
#
# Time elapsed on simulation and comparison: 22min 20s 30ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")
# Out:
# Rank: 1
# Loading stress experiment #1 of 3 with T gate indices: 4
#
#
# Rank: 16
# Loading stress experiment #1 of 2 with T gate indices: 41
#
#
# Rank: 7
# Loading stress experiment #1 of 3 with T gate indices: 22
#
#
# Rank: 17
# Loading stress experiment #1 of 2 with T gate indices: 43
#
#
# Rank: 21
# Loading stress experiment #1 of 2 with T gate indices: 51
#
#
# Rank: 26
# Loading stress experiment #1 of 2 with T gate indices: 61
#
#
# Rank: 2
# Loading stress experiment #1 of 3 with T gate indices: 7
#
#
# Rank: 15
# Loading stress experiment #1 of 2 with T gate indices: 39
#
#
# Rank: 27
# Loading stress experiment #1 of 2 with T gate indices: 63
#
#
# Rank: 14
# Loading stress experiment #1 of 2 with T gate indices: 37
#
#
# Rank: 23
# Loading stress experiment #1 of 2 with T gate indices: 55
#
#
# Rank: 28
# Loading stress experiment #1 of 2 with T gate indices: 65
#
#
# Rank: 6
# Loading stress experiment #1 of 3 with T gate indices: 19
#
#
# Rank: 0
# Loading stress experiment #1 of 3 with T gate indices: 1
#
#
# Rank: 5
# Loading stress experiment #1 of 3 with T gate indices: 16
#
#
# Rank: 11
# Loading stress experiment #1 of 2 with T gate indices: 31
#
#
# Rank: 20
# Loading stress experiment #1 of 2 with T gate indices: 49
#
#
# Rank: 12
# Loading stress experiment #1 of 2 with T gate indices: 33
#
#
# Rank: 30
# Loading stress experiment #1 of 2 with T gate indices: 69
#
#
# Rank: 19
# Loading stress experiment #1 of 2 with T gate indices: 47
#
#
# Rank: 18
# Loading stress experiment #1 of 2 with T gate indices: 45
#
#
# Rank: 3
# Loading stress experiment #1 of 3 with T gate indices: 10
#
#
# Rank: 31
# Loading stress experiment #1 of 2 with T gate indices: 71
#
#
# Rank: 24
# Loading stress experiment #1 of 2 with T gate indices: 57
#
#
# Rank: 10
# Loading stress experiment #1 of 2 with T gate indices: 29
#
#
# Rank: 9
# Loading stress experiment #1 of 2 with T gate indices: 27
#
#
# Rank: 22
# Loading stress experiment #1 of 2 with T gate indices: 53
#
#
# Rank: 25
# Loading stress experiment #1 of 2 with T gate indices: 59
#
#
# Rank: 4
# Loading stress experiment #1 of 3 with T gate indices: 13
#
#
# Rank: 29
# Loading stress experiment #1 of 2 with T gate indices: 67
#
#
# Rank: 13
# Loading stress experiment #1 of 2 with T gate indices: 35
#
#
# Rank: 8
# Loading stress experiment #1 of 2 with T gate indices: 25
#
#
# Rank: 12
# Completed stress experiment #1 of 2 with T gate indices: 33
# Time elapsed: 23h 0min 22s 524ms
#
#
# Rank: 12
# Loading stress experiment #2 of 2 with T gate indices: 34
#
#
# Rank: 8
# Completed stress experiment #1 of 2 with T gate indices: 25
# Time elapsed: 23h 0min 47s 357ms
#
#
# Rank: 8
# Loading stress experiment #2 of 2 with T gate indices: 26
#
#
# Rank: 14
# Completed stress experiment #1 of 2 with T gate indices: 37
# Time elapsed: 23h 0min 51s 318ms
#
#
# Rank: 14
# Loading stress experiment #2 of 2 with T gate indices: 38
#
#
# Rank: 13
# Completed stress experiment #1 of 2 with T gate indices: 35
# Time elapsed: 23h 2min 5s 373ms
#
#
# Rank: 13
# Loading stress experiment #2 of 2 with T gate indices: 36
#
#
# Rank: 4
# Completed stress experiment #1 of 3 with T gate indices: 13
# Time elapsed: 23h 2min 54s 198ms
#
#
# Rank: 4
# Loading stress experiment #2 of 3 with T gate indices: 14
#
#
# Rank: 25
# Completed stress experiment #1 of 2 with T gate indices: 59
# Time elapsed: 23h 3min 8s 772ms
#
#
# Rank: 25
# Loading stress experiment #2 of 2 with T gate indices: 60
#
#
# Rank: 0
# Completed stress experiment #1 of 3 with T gate indices: 1
# Time elapsed: 23h 4min 17s 922ms
#
#
# Rank: 0
# Loading stress experiment #2 of 3 with T gate indices: 2
#
#
# Rank: 7
# Completed stress experiment #1 of 3 with T gate indices: 22
# Time elapsed: 23h 4min 23s 28ms
#
#
# Rank: 7
# Loading stress experiment #2 of 3 with T gate indices: 23
#
#
# Rank: 23
# Completed stress experiment #1 of 2 with T gate indices: 55
# Time elapsed: 23h 4min 42s 646ms
#
#
# Rank: 23
# Loading stress experiment #2 of 2 with T gate indices: 56
#
#
# Rank: 1
# Completed stress experiment #1 of 3 with T gate indices: 4
# Time elapsed: 23h 4min 52s 482ms
#
#
# Rank: 1
# Loading stress experiment #2 of 3 with T gate indices: 5
#
#
# Rank: 29
# Completed stress experiment #1 of 2 with T gate indices: 67
# Time elapsed: 23h 4min 52s 711ms
#
#
# Rank: 29
# Loading stress experiment #2 of 2 with T gate indices: 68
#
#
# Rank: 9
# Completed stress experiment #1 of 2 with T gate indices: 27
# Time elapsed: 23h 5min 8s 280ms
#
#
# Rank: 9
# Loading stress experiment #2 of 2 with T gate indices: 28
#
#
# Rank: 17
# Completed stress experiment #1 of 2 with T gate indices: 43
# Time elapsed: 23h 5min 20s 875ms
#
#
# Rank: 17
# Loading stress experiment #2 of 2 with T gate indices: 44
#
#
# Rank: 6
# Completed stress experiment #1 of 3 with T gate indices: 19
# Time elapsed: 23h 5min 35s 621ms
#
#
# Rank: 6
# Loading stress experiment #2 of 3 with T gate indices: 20
#
#
# Rank: 15
# Completed stress experiment #1 of 2 with T gate indices: 39
# Time elapsed: 23h 5min 58s 121ms
#
#
# Rank: 15
# Loading stress experiment #2 of 2 with T gate indices: 40
#
#
# Rank: 24
# Completed stress experiment #1 of 2 with T gate indices: 57
# Time elapsed: 23h 6min 36s 577ms
#
#
# Rank: 24
# Loading stress experiment #2 of 2 with T gate indices: 58
#
#
# Rank: 26
# Completed stress experiment #1 of 2 with T gate indices: 61
# Time elapsed: 23h 7min 15s 925ms
#
#
# Rank: 26
# Loading stress experiment #2 of 2 with T gate indices: 62
#
#
# Rank: 5
# Completed stress experiment #1 of 3 with T gate indices: 16
# Time elapsed: 23h 7min 19s 913ms
#
#
# Rank: 5
# Loading stress experiment #2 of 3 with T gate indices: 17
#
#
# Rank: 10
# Completed stress experiment #1 of 2 with T gate indices: 29
# Time elapsed: 23h 8min 15s 195ms
#
#
# Rank: 10
# Loading stress experiment #2 of 2 with T gate indices: 30
#
#
# Rank: 30
# Completed stress experiment #1 of 2 with T gate indices: 69
# Time elapsed: 23h 8min 31s 724ms
#
#
# Rank: 30
# Loading stress experiment #2 of 2 with T gate indices: 70
#
#
# Rank: 3
# Completed stress experiment #1 of 3 with T gate indices: 10
# Time elapsed: 23h 8min 47s 408ms
#
#
# Rank: 3
# Loading stress experiment #2 of 3 with T gate indices: 11
#
#
# Rank: 11
# Completed stress experiment #1 of 2 with T gate indices: 31
# Time elapsed: 23h 8min 53s 278ms
#
#
# Rank: 11
# Loading stress experiment #2 of 2 with T gate indices: 32
#
#
# Rank: 21
# Completed stress experiment #1 of 2 with T gate indices: 51
# Time elapsed: 23h 9min 48s 110ms
#
#
# Rank: 21
# Loading stress experiment #2 of 2 with T gate indices: 52
#
#
# Rank: 16
# Completed stress experiment #1 of 2 with T gate indices: 41
# Time elapsed: 23h 10min 11s 718ms
#
#
# Rank: 16
# Loading stress experiment #2 of 2 with T gate indices: 42
#
#
# Rank: 18
# Completed stress experiment #1 of 2 with T gate indices: 45
# Time elapsed: 23h 10min 21s 539ms
#
#
# Rank: 18
# Loading stress experiment #2 of 2 with T gate indices: 46
#
#
# Rank: 31
# Completed stress experiment #1 of 2 with T gate indices: 71
# Time elapsed: 23h 10min 46s 891ms
#
#
# Rank: 31
# Loading stress experiment #2 of 2 with T gate indices: 72
#
#
# Rank: 19
# Completed stress experiment #1 of 2 with T gate indices: 47
# Time elapsed: 23h 11min 35s 974ms
#
#
# Rank: 19
# Loading stress experiment #2 of 2 with T gate indices: 48
#
#
# Rank: 2
# Completed stress experiment #1 of 3 with T gate indices: 7
# Time elapsed: 23h 11min 48s 212ms
#
#
# Rank: 2
# Loading stress experiment #2 of 3 with T gate indices: 8
#
#
# Rank: 20
# Completed stress experiment #1 of 2 with T gate indices: 49
# Time elapsed: 23h 11min 52s 680ms
#
#
# Rank: 20
# Loading stress experiment #2 of 2 with T gate indices: 50
#
#
# Rank: 28
# Completed stress experiment #1 of 2 with T gate indices: 65
# Time elapsed: 23h 12min 0s 535ms
#
#
# Rank: 28
# Loading stress experiment #2 of 2 with T gate indices: 66
#
#
# Rank: 27
# Completed stress experiment #1 of 2 with T gate indices: 63
# Time elapsed: 23h 18min 24s 263ms
#
#
# Rank: 27
# Loading stress experiment #2 of 2 with T gate indices: 64
#
#
# Rank: 22
# Completed stress experiment #1 of 2 with T gate indices: 53
# Time elapsed: 23h 23min 31s 544ms
#
#
# Rank: 22
# Loading stress experiment #2 of 2 with T gate indices: 54
#
#
# Rank: 8
# Completed stress experiment #2 of 2 with T gate indices: 26
# Time elapsed: 22h 52min 42s 390ms
#
#
# Rank: 12
# Completed stress experiment #2 of 2 with T gate indices: 34
# Time elapsed: 22h 59min 34s 497ms
#
#
# Rank: 14
# Completed stress experiment #2 of 2 with T gate indices: 38
# Time elapsed: 23h 2min 5s 549ms
#
#
# Rank: 13
# Completed stress experiment #2 of 2 with T gate indices: 36
# Time elapsed: 23h 1min 9s 907ms
#
#
# Rank: 25
# Completed stress experiment #2 of 2 with T gate indices: 60
# Time elapsed: 23h 1min 55s 914ms
#
#
# Rank: 4
# Completed stress experiment #2 of 3 with T gate indices: 14
# Time elapsed: 23h 2min 14s 348ms
#
#
# Rank: 4
# Loading stress experiment #3 of 3 with T gate indices: 15
#
#
# Rank: 0
# Completed stress experiment #2 of 3 with T gate indices: 2
# Time elapsed: 23h 2min 52s 197ms
#
#
# Rank: 0
# Loading stress experiment #3 of 3 with T gate indices: 3
#
#
# Rank: 7
# Completed stress experiment #2 of 3 with T gate indices: 23
# Time elapsed: 23h 3min 29s 766ms
#
#
# Rank: 7
# Loading stress experiment #3 of 3 with T gate indices: 24
#
#
# Rank: 1
# Completed stress experiment #2 of 3 with T gate indices: 5
# Time elapsed: 23h 3min 57s 829ms
#
#
# Rank: 1
# Loading stress experiment #3 of 3 with T gate indices: 6
#
#
# Rank: 23
# Completed stress experiment #2 of 2 with T gate indices: 56
# Time elapsed: 23h 4min 11s 828ms
#
#
# Rank: 29
# Completed stress experiment #2 of 2 with T gate indices: 68
# Time elapsed: 23h 4min 5s 264ms
#
#
# Rank: 6
# Completed stress experiment #2 of 3 with T gate indices: 20
# Time elapsed: 23h 3min 53s 127ms
#
#
# Rank: 6
# Loading stress experiment #3 of 3 with T gate indices: 21
#
#
# Rank: 15
# Completed stress experiment #2 of 2 with T gate indices: 40
# Time elapsed: 23h 3min 42s 486ms
#
#
# Rank: 9
# Completed stress experiment #2 of 2 with T gate indices: 28
# Time elapsed: 23h 5min 48s 307ms
#
#
# Rank: 24
# Completed stress experiment #2 of 2 with T gate indices: 58
# Time elapsed: 23h 5min 34s 891ms
#
#
# Rank: 17
# Completed stress experiment #2 of 2 with T gate indices: 44
# Time elapsed: 23h 7min 25s 343ms
#
#
# Rank: 5
# Completed stress experiment #2 of 3 with T gate indices: 17
# Time elapsed: 23h 6min 20s 714ms
#
#
# Rank: 5
# Loading stress experiment #3 of 3 with T gate indices: 18
#
#
# Rank: 26
# Completed stress experiment #2 of 2 with T gate indices: 62
# Time elapsed: 23h 7min 27s 88ms
#
#
# Rank: 3
# Completed stress experiment #2 of 3 with T gate indices: 11
# Time elapsed: 23h 6min 19s 827ms
#
#
# Rank: 3
# Loading stress experiment #3 of 3 with T gate indices: 12
#
#
# Rank: 10
# Completed stress experiment #2 of 2 with T gate indices: 30
# Time elapsed: 23h 8min 1s 905ms
#
#
# Rank: 11
# Completed stress experiment #2 of 2 with T gate indices: 32
# Time elapsed: 23h 8min 31s 233ms
#
#
# Rank: 16
# Completed stress experiment #2 of 2 with T gate indices: 42
# Time elapsed: 23h 8min 4s 283ms
#
#
# Rank: 21
# Completed stress experiment #2 of 2 with T gate indices: 52
# Time elapsed: 23h 8min 33s 209ms
#
#
# Rank: 30
# Completed stress experiment #2 of 2 with T gate indices: 70
# Time elapsed: 23h 9min 49s 917ms
#
#
# Rank: 18
# Completed stress experiment #2 of 2 with T gate indices: 46
# Time elapsed: 23h 8min 54s 254ms
#
#
# Rank: 31
# Completed stress experiment #2 of 2 with T gate indices: 72
# Time elapsed: 23h 10min 29s 297ms
#
#
# Rank: 28
# Completed stress experiment #2 of 2 with T gate indices: 66
# Time elapsed: 23h 10min 22s 554ms
#
#
# Rank: 19
# Completed stress experiment #2 of 2 with T gate indices: 48
# Time elapsed: 23h 11min 41s 812ms
#
#
# Rank: 2
# Completed stress experiment #2 of 3 with T gate indices: 8
# Time elapsed: 23h 12min 10s 630ms
#
#
# Rank: 2
# Loading stress experiment #3 of 3 with T gate indices: 9
#
#
# Rank: 20
# Completed stress experiment #2 of 2 with T gate indices: 50
# Time elapsed: 23h 12min 26s 133ms
#
#
# Rank: 27
# Completed stress experiment #2 of 2 with T gate indices: 64
# Time elapsed: 23h 15min 39s 856ms
#
#
# Rank: 22
# Completed stress experiment #2 of 2 with T gate indices: 54
# Time elapsed: 23h 22min 49s 596ms
#
#
# Rank: 4
# Completed stress experiment #3 of 3 with T gate indices: 15
# Time elapsed: 23h 2min 39s 257ms
#
#
# Rank: 0
# Completed stress experiment #3 of 3 with T gate indices: 3
# Time elapsed: 23h 3min 2s 457ms
#
#
# Rank: 7
# Completed stress experiment #3 of 3 with T gate indices: 24
# Time elapsed: 23h 3min 41s 218ms
#
#
# Rank: 6
# Completed stress experiment #3 of 3 with T gate indices: 21
# Time elapsed: 23h 2min 57s 747ms
#
#
# Rank: 1
# Completed stress experiment #3 of 3 with T gate indices: 6
# Time elapsed: 23h 4min 1s 771ms
#
#
# Rank: 5
# Completed stress experiment #3 of 3 with T gate indices: 18
# Time elapsed: 23h 7min 11s 257ms
#
#
# Rank: 3
# Completed stress experiment #3 of 3 with T gate indices: 12
# Time elapsed: 23h 6min 51s 917ms
#
#
# Rank: 2
# Completed stress experiment #3 of 3 with T gate indices: 9
# Time elapsed: 23h 14min 38s 412ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 7.32              | 92.68             | 26.93             | 65.75             |
# | 2                | 7.26              | 92.74             | 26.97             | 65.77             |
# | 3                | 7.33              | 92.67             | 26.95             | 65.72             |
# | 4                | 7.49              | 92.51             | 26.84             | 65.67             |
# | 5                | 7.31              | 92.69             | 26.94             | 65.74             |
# | 6                | 7.36              | 92.64             | 26.91             | 65.73             |
# | 7                | 7.40              | 92.60             | 26.89             | 65.71             |
# | 8                | 7.50              | 92.50             | 26.83             | 65.68             |
# | 9                | 7.40              | 92.60             | 26.88             | 65.72             |
# | 10               | 7.38              | 92.62             | 26.88             | 65.73             |
# | 11               | 7.31              | 92.69             | 26.95             | 65.73             |
# | 12               | 7.32              | 92.68             | 26.93             | 65.75             |
# | 13               | 7.50              | 92.50             | 26.81             | 65.69             |
# | 14               | 7.48              | 92.52             | 26.83             | 65.68             |
# | 15               | 7.50              | 92.50             | 26.81             | 65.69             |
# | 16               | 7.40              | 92.60             | 26.88             | 65.72             |
# | 17               | 7.41              | 92.59             | 26.85             | 65.74             |
# | 18               | 7.35              | 92.65             | 26.88             | 65.77             |
# | 19               | 7.40              | 92.60             | 26.87             | 65.72             |
# | 20               | 7.38              | 92.62             | 26.89             | 65.73             |
# | 21               | 7.29              | 92.71             | 26.95             | 65.76             |
# | 22               | 7.49              | 92.51             | 26.82             | 65.70             |
# | 23               | 7.38              | 92.62             | 26.90             | 65.72             |
# | 24               | 7.52              | 92.48             | 26.80             | 65.68             |
# | 25               | 14.83             | 85.17             | 26.88             | 58.30             |
# | 26               | 14.83             | 85.17             | 26.88             | 58.30             |
# | 27               | 14.69             | 85.31             | 26.90             | 58.42             |
# | 28               | 14.69             | 85.31             | 26.90             | 58.42             |
# | 29               | 14.73             | 85.27             | 26.87             | 58.40             |
# | 30               | 14.73             | 85.27             | 26.87             | 58.40             |
# | 31               | 14.57             | 85.43             | 27.03             | 58.39             |
# | 32               | 14.57             | 85.43             | 27.03             | 58.39             |
# | 33               | 14.57             | 85.43             | 27.04             | 58.39             |
# | 34               | 14.57             | 85.43             | 27.04             | 58.39             |
# | 35               | 14.86             | 85.14             | 26.76             | 58.38             |
# | 36               | 14.86             | 85.14             | 26.76             | 58.38             |
# | 37               | 14.73             | 85.27             | 26.92             | 58.35             |
# | 38               | 14.73             | 85.27             | 26.92             | 58.35             |
# | 39               | 14.52             | 85.48             | 27.02             | 58.46             |
# | 40               | 14.52             | 85.48             | 27.02             | 58.46             |
# | 41               | 14.65             | 85.35             | 26.86             | 58.49             |
# | 42               | 14.65             | 85.35             | 26.86             | 58.49             |
# | 43               | 14.91             | 85.09             | 26.81             | 58.28             |
# | 44               | 14.91             | 85.09             | 26.81             | 58.28             |
# | 45               | 14.79             | 85.21             | 26.84             | 58.38             |
# | 46               | 14.79             | 85.21             | 26.84             | 58.38             |
# | 47               | 14.61             | 85.39             | 26.91             | 58.48             |
# | 48               | 14.61             | 85.39             | 26.91             | 58.48             |
# | 49               | 7.38              | 92.62             | 26.91             | 65.71             |
# | 50               | 7.30              | 92.70             | 26.93             | 65.77             |
# | 51               | 7.30              | 92.70             | 26.96             | 65.74             |
# | 52               | 7.33              | 92.67             | 26.95             | 65.72             |
# | 53               | 7.21              | 92.79             | 26.99             | 65.79             |
# | 54               | 7.31              | 92.69             | 26.94             | 65.75             |
# | 55               | 7.44              | 92.56             | 26.88             | 65.68             |
# | 56               | 7.36              | 92.64             | 26.93             | 65.72             |
# | 57               | 7.19              | 92.81             | 27.02             | 65.79             |
# | 58               | 7.27              | 92.73             | 26.97             | 65.76             |
# | 59               | 7.29              | 92.71             | 26.96             | 65.76             |
# | 60               | 7.10              | 92.90             | 27.08             | 65.82             |
# | 61               | 7.42              | 92.58             | 26.86             | 65.72             |
# | 62               | 7.41              | 92.59             | 26.87             | 65.72             |
# | 63               | 7.27              | 92.73             | 26.93             | 65.79             |
# | 64               | 7.46              | 92.54             | 26.85             | 65.69             |
# | 65               | 7.39              | 92.61             | 26.88             | 65.73             |
# | 66               | 7.16              | 92.84             | 27.04             | 65.80             |
# | 67               | 7.31              | 92.69             | 26.97             | 65.73             |
# | 68               | 7.22              | 92.78             | 27.00             | 65.78             |
# | 69               | 7.26              | 92.74             | 26.97             | 65.76             |
# | 70               | 7.48              | 92.52             | 26.85             | 65.66             |
# | 71               | 7.34              | 92.66             | 26.91             | 65.75             |
# | 72               | 7.52              | 92.48             | 26.78             | 65.70             |
#
#
# Time elapsed for stress testing 72 unique combinations: 2d 21h 38min 40s 27ms

# %% [markdown]
# ## Bilan comparing the QRAM circuit Query AN0_TD3_TC4_CX6 WITH the QRAM circuit Query AN0_TD4_TC7_CX6

# %%
make_slurm("bilan", "2-10", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: No
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 10
#
# ================================================
#
#
# Loading bilan done
#
#
# Bilan of the experiment:
#
# Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 189ms                      | 207.17 MB              | 1.13 GB                |
# | 3                | 412ms                      | 207.64 MB              | 1.13 GB                |
# | 4                | 1s 110ms                   | 208.45 MB              | 1.13 GB                |
# | 5                | 3s 412ms                   | 209.58 MB              | 1.13 GB                |
# | 6                | 12s 749ms                  | 211.75 MB              | 1.13 GB                |
# | 7                | 53s 342ms                  | 216.02 MB              | 1.13 GB                |
# | 8                | 4min 7s 63ms               | 226.21 MB              | 1.14 GB                |
# | 9                | 26min 46s 43ms             | 240.21 MB              | 1.14 GB                |
# | 10               | 3h 11min 52s 261ms         | 270.66 MB              | 1.16 GB                |
#
#
# Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
# | 7                | 264              | 93                   | 33               | 1776             | 506               |
# | 8                | 521              | 105                  | 37               | 3568             | 1018              |
# | 9                | 1034             | 117                  | 41               | 7152             | 2042              |
# | 10               | 2059             | 129                  | 45               | 14320            | 4090              |
#
#
# Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 31                   | 11               | 28               | 10                |
# | 3                | 20               | 43                   | 15               | 72               | 26                |
# | 4                | 37               | 55                   | 19               | 160              | 58                |
# | 5                | 70               | 67                   | 23               | 336              | 122               |
# | 6                | 135              | 79                   | 27               | 688              | 250               |
# | 7                | 264              | 91                   | 31               | 1392             | 506               |
# | 8                | 521              | 103                  | 35               | 2800             | 1018              |
# | 9                | 1034             | 115                  | 39               | 5616             | 2042              |
# | 10               | 2059             | 127                  | 43               | 11248            | 4090              |
#
#
# Comparing bilans
#
# T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded (%) | T Count Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 28  ( 70.00 )      | 12  ( 30.00 )          |
# | 3                | 96                 | 72  ( 75.00 )      | 24  ( 25.00 )          |
# | 4                | 208                | 160  ( 76.92 )     | 48  ( 23.08 )          |
# | 5                | 432                | 336  ( 77.78 )     | 96  ( 22.22 )          |
# | 6                | 880                | 688  ( 78.18 )     | 192  ( 21.82 )         |
# | 7                | 1776               | 1392  ( 78.38 )    | 384  ( 21.62 )         |
# | 8                | 3568               | 2800  ( 78.48 )    | 768  ( 21.52 )         |
# | 9                | 7152               | 5616  ( 78.52 )    | 1536  ( 21.48 )        |
# | 10               | 14320              | 11248  ( 78.55 )   | 3072  ( 21.45 )        |
#
#
# T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded (%) | T Depth Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 11  ( 84.62 )      | 2  ( 15.38 )           |
# | 3                | 17                 | 15  ( 88.24 )      | 2  ( 11.76 )           |
# | 4                | 21                 | 19  ( 90.48 )      | 2  ( 9.52 )            |
# | 5                | 25                 | 23  ( 92.00 )      | 2  ( 8.00 )            |
# | 6                | 29                 | 27  ( 93.10 )      | 2  ( 6.90 )            |
# | 7                | 33                 | 31  ( 93.94 )      | 2  ( 6.06 )            |
# | 8                | 37                 | 35  ( 94.59 )      | 2  ( 5.41 )            |
# | 9                | 41                 | 39  ( 95.12 )      | 2  ( 4.88 )            |
# | 10               | 45                 | 43  ( 95.56 )      | 2  ( 4.44 )            |
#
#
# Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded (%)   | Depth Cancelled (%)    |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 31  ( 93.94 )      | 2  ( 6.06 )            |
# | 3                | 45                 | 43  ( 95.56 )      | 2  ( 4.44 )            |
# | 4                | 57                 | 55  ( 96.49 )      | 2  ( 3.51 )            |
# | 5                | 69                 | 67  ( 97.10 )      | 2  ( 2.90 )            |
# | 6                | 81                 | 79  ( 97.53 )      | 2  ( 2.47 )            |
# | 7                | 93                 | 91  ( 97.85 )      | 2  ( 2.15 )            |
# | 8                | 105                | 103  ( 98.10 )     | 2  ( 1.90 )            |
# | 9                | 117                | 115  ( 98.29 )     | 2  ( 1.71 )            |
# | 10               | 129                | 127  ( 98.45 )     | 2  ( 1.55 )            |
