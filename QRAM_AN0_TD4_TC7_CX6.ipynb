# %% [markdown]
# # Toffoli Decomposition Relative Phase TD_4_CXD_3 for Fanin and Fanout
# # Toffoli Decomposition AN0_TD4_TC7_CX6 for Query

# %%
import sys
from make import *
from main_experiments import main

t_count = 7

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
sys.argv = ['notebook', '--qubit-range=2', f'--t-count={t_count}', '--print-circuit=d']

main()

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 2 qubits

# %%
make_slurm("experiments", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 208ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 224ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |      2048        |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# ••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 1s 252ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 2 qubits

# %%
make_slurm("stress", "2", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.10 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 148ms
# 	• RSS (Memory Usage): 205.14 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 149ms
# 	• RSS (Memory Usage): 207.04 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 150ms
# 	• RSS (Memory Usage): 207.51 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 147ms
# 	• RSS (Memory Usage): 207.38 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 149ms
# 	• RSS (Memory Usage): 207.30 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 149ms
# 	• RSS (Memory Usage): 207.25 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 147ms
# 	• RSS (Memory Usage): 207.37 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 147ms
# 	• RSS (Memory Usage): 207.54 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# ======================================================================================================================================================
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 150ms
# 	• RSS (Memory Usage): 207.46 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 150ms
# 	• RSS (Memory Usage): 207.36 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 151ms
# 	• RSS (Memory Usage): 207.18 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.01 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.36 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 149ms
# 	• RSS (Memory Usage): 207.27 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: Yes
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 2
# End range of qubits: 2
# Simulation type: Simulate full circuit
# Simulation display option: Hide
#
# ================================================
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 147ms
# 	• RSS (Memory Usage): 207.64 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.19 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 150ms
# 	• RSS (Memory Usage): 207.14 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.48 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 146ms
# 	• RSS (Memory Usage): 207.26 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ...
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 149ms
# 	• RSS (Memory Usage): 207.33 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
#
#
# Bucket Brigade circuit creation:
# 	• 2 Qbits
# 	• Time elapsed on creation: 150ms
# 	• RSS (Memory Usage): 207.18 MB
# 	• VMS (Memory Usage): 1.06 GB
#
# Decomposition scenario of bucket brigade circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.NO_DECOMP
# 	• mem_decomp:    	ToffoliDecompType.NO_DECOMP
# 	• fan_out_decomp:	ToffoliDecompType.NO_DECOMP
#
#
# Optimization methods of bucket brigade circuit:
#
# 	• parallel_toffolis:	NO !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the bucket brigade circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 14                   | -                | -                | -                 |
#
# Decomposition scenario of modded circuit:
#
# 	• fan_in_decomp: 	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
# 	• mem_decomp:    	ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
# 	• fan_out_decomp:	ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
#
# Optimization methods of modded circuit:
#
# 	• parallel_toffolis:	YES !!
# 	• reverse_moments:  	ReverseMoments.OUT_TO_IN
#
#
# Verifying the depth and count of the modded circuit:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 35                   | 13               | 40               | 10                |
#
# ======================================================================================================================================================
#
#
#
# Rank: 0
# Loading stress experiment #1 of 1
# Rank: with T gate indices: 1
#
# 15
# Loading stress experiment #1 of 1 with T gate indices:
# Rank: 16
#
# 37
# Loading stress experiment #1 of 1 with T gate indices:
# Rank: 38
#
#
# Rank: 18
# Loading stress experiment #1
# Rank:
# Rank:
# Rank:
# Rank:
# Rank: of 1 with T gate indices: 5
# Loading stress experiment #1 of 1
# Rank: 28
# Loading stress experiment #1 of 1 35
# Loading stress experiment #1 of 1 with T gate indices: 9
# Loading stress experiment #1 of 1 with T gate indices:
# Rank:
# Rank: with T gate indices: 36
#
#
# Rank: 10
#
# 7
# Loading stress experiment #1 of
# Rank:
# Rank:
# Rank:
# Rank:
# Rank:
# Rank: 34
# Loading stress experiment #1 of 1 with T gate indices: 19
#
# 16
# Loading stress experiment #1 of 1 with T gate indices: with T gate indices: 6
#
#
# Rank: 29
# Loading stress experiment #1 of 1 with T gate indices:
# Rank:
# Rank:
# Rank:
# Rank:
# Rank:
# Rank: 35
#
# 17
#
# 10
# Loading stress experiment #1 of 1 with T gate indices: 30
#
# 1
# Loading stress experiment #1 of 1 with T gate indices: 25
# Loading stress experiment #1 of 1 29
#
# 3
# Loading stress experiment #1
# Rank: 1 with T gate indices: 12
# Loading stress experiment #1 of 1 with T gate indices: 19
# Loading stress experiment #1 of 1
# Rank: 26
# Loading stress experiment #1 of 1 with T gate indices:
# Rank: 17
# Loading stress experiment #1 of 1 33
# Loading stress experiment #1 of
# Rank: 22
# Loading stress experiment #1
# Rank:
# Rank:
# Rank
# Rank: 27
#
# Rank:
# Rank:
# Rank: 2
# Loading stress experiment #1
# Rank: 6
# Loading stress experiment #1 32
# Loading stress experiment #1 21
# Loading stress experiment #1
# Rank: 20
# Loading stress experiment #1 of 1 with T gate indices: 11
#
# 2
#
# with T gate indices: 26
#
# of 1 with T gate indices: 4
#
# 23
# Loading stress experiment #1 8
#
# 13
#
# with T gate indices: 31
# Loading stress experiment #1 of 1 with T gate indices: 27
#
# 4
# Loading stress experiment #1 of with T gate indices: 1 with T gate indices: 34
#
# 38
# Loading stress experiment #1 of 1 of 1 with T gate indices: 23
#
# 39
# Loading stress experiment #1 of 1 with T gate indices: 30
# Loading stress experiment #1 of 1 : 14
# Loading stress experiment #1 of 1 Loading stress experiment #1 of 1 with T gate indices: 11
# Loading stress experiment #1 36
# Loading stress experiment #1 of 1 with T gate indices: 8
# Loading stress experiment #1 of 1 with T gate indices: of 1 with T gate indices: 24
#
# 20
#
# 32
#
# 1 with T gate indices: 18
#
# with T gate indices: 40
#
# with T gate indices: with T gate indices: 28
#
# of 1 with T gate indices: 37
#
# 9
#
# of 1 with T gate indices: 24
# Loading stress experiment #1 of 1 with T gate indices: of 1 with T gate indices: of 1 with T gate indices: 33
#
# of 1 with T gate indices: 22
#
# 13
# Loading stress experiment #1 of 1 with T gate indices: 21
#
# 5
#
# 39
#
# 31
#
# 15
#
# 12
#
# 3
#
# 25
#
# 7
#
# 14
#
#
# Rank: 14
# Completed stress experiment #1 of 1 with T gate indices: 15
# Time elapsed: 2s 532ms
#
#
# Rank: 30
# Completed stress experiment #1 of 1 with T gate indices: 31
# Time elapsed: 2s 533ms
#
#
# Rank: 33
# Completed stress experiment #1 of 1 with T gate indices: 34
# Time elapsed: 2s 537ms
#
#
# Rank: 22
# Completed stress experiment #1 of 1 with T gate indices: 23
# Time elapsed: 2s 545ms
#
#
# Rank: 27
# Completed stress experiment #1 of 1 with T gate indices: 28
# Time elapsed: 2s 546ms
#
#
# Rank: 8
# Completed stress experiment #1 of 1 with T gate indices: 9
# Time elapsed: 2s 549ms
#
#
# Rank: 29
# Completed stress experiment #1 of 1 with T gate indices: 30
# Time elapsed: 2s 552ms
#
#
# Rank: 18
# Completed stress experiment #1 of 1 with T gate indices: 19
# Time elapsed: 2s 560ms
#
#
# Rank: 31
# Completed stress experiment #1 of 1 with T gate indices: 32
# Time elapsed: 2s 568ms
#
#
# Rank: 36
# Completed stress experiment #1 of 1 with T gate indices: 37
# Time elapsed: 2s 572ms
#
#
# Rank: 26
# Completed stress experiment #1 of 1 with T gate indices: 27
# Time elapsed: 2s 575ms
#
#
# Rank: 11
# Completed stress experiment #1 of 1 with T gate indices: 12
# Time elapsed: 2s 576ms
#
#
# Rank: 37
# Completed stress experiment #1 of 1 with T gate indices: 38
# Time elapsed: 2s 577ms
#
#
# Rank: 19
# Completed stress experiment #1 of 1 with T gate indices: 20
# Time elapsed: 2s 579ms
#
#
# Rank: 1
# Completed stress experiment #1 of 1 with T gate indices: 2
# Time elapsed: 2s 579ms
#
#
# Rank: 39
# Completed stress experiment #1 of 1 with T gate indices: 40
# Time elapsed: 2s 580ms
#
#
# Rank: 38
# Completed stress experiment #1 of 1 with T gate indices: 39
# Time elapsed: 2s 580ms
#
#
# Rank: 4
# Completed stress experiment #1 of 1 with T gate indices: 5
# Time elapsed: 2s 581ms
#
#
# Rank: 15
# Completed stress experiment #1 of 1 with T gate indices: 16
# Time elapsed: 2s 583ms
#
#
# Rank: 32
# Completed stress experiment #1 of 1 with T gate indices: 33
# Time elapsed: 2s 586ms
#
#
# Rank: 6
# Completed stress experiment #1 of 1 with T gate indices: 7
# Time elapsed: 2s 586ms
#
#
# Rank: 35
# Completed stress experiment #1 of 1 with T gate indices: 36
# Time elapsed: 2s 589ms
#
#
# Rank: 10
# Completed stress experiment #1 of 1 with T gate indices: 11
# Time elapsed: 2s 597ms
#
#
# Rank: 12
# Completed stress experiment #1 of 1 with T gate indices: 13
# Time elapsed: 2s 598ms
#
#
# Rank: 16
# Completed stress experiment #1 of 1 with T gate indices: 17
# Time elapsed: 2s 598ms
#
#
# Rank: 5
# Completed stress experiment #1 of 1 with T gate indices: 6
# Time elapsed: 2s 600ms
#
#
# Rank: 34
# Completed stress experiment #1 of 1 with T gate indices: 35
# Time elapsed: 2s 600ms
#
#
# Rank: 24
# Completed stress experiment #1 of 1 with T gate indices: 25
# Time elapsed: 2s 601ms
#
#
# Rank: 2
# Completed stress experiment #1 of 1 with T gate indices: 3
# Time elapsed: 2s 605ms
#
#
# Rank: 23
# Completed stress experiment #1 of 1 with T gate indices: 24
# Time elapsed: 2s 607ms
#
#
# Rank: 7
# Completed stress experiment #1 of 1 with T gate indices: 8
# Time elapsed: 2s 608ms
#
#
# Rank: 17
# Completed stress experiment #1 of 1 with T gate indices: 18
# Time elapsed: 2s 610ms
#
#
# Rank: 13
# Completed stress experiment #1 of 1 with T gate indices: 14
# Time elapsed: 2s 612ms
#
#
# Rank: 25
# Completed stress experiment #1 of 1 with T gate indices: 26
# Time elapsed: 2s 624ms
#
#
# Rank: 28
# Completed stress experiment #1 of 1 with T gate indices: 29
# Time elapsed: 2s 629ms
#
#
# Rank: 9
# Completed stress experiment #1 of 1 with T gate indices: 10
# Time elapsed: 2s 633ms
#
#
# Rank: 3
# Completed stress experiment #1 of 1 with T gate indices: 4
# Time elapsed: 2s 635ms
#
#
# Rank: 20
# Completed stress experiment #1 of 1 with T gate indices: 21
# Time elapsed: 2s 639ms
#
#
# Rank: 0
# Completed stress experiment #1 of 1 with T gate indices: 1
# Time elapsed: 2s 672ms
#
#
# Rank: 21
# Completed stress experiment #1 of 1 with T gate indices: 22
# Time elapsed: 2s 680ms
#
#
#
# Bilan of the stress experiment:
#
# Stress experiment bilan:
#
# | T Gate Index     | Failed (%)        | Succeed (%)       | Measurements (%)  | Output Vector (%) |
# |------------------|-------------------|-------------------|-------------------|-------------------|
# | 1                | 9.03              | 90.97             | 0.00              | 90.97             |
# | 2                | 9.33              | 90.67             | 0.00              | 90.67             |
# | 3                | 0.00              | 100.00            | 25.00             | 75.00             |
# | 4                | 0.00              | 100.00            | 25.00             | 75.00             |
# | 5                | 0.00              | 100.00            | 25.00             | 75.00             |
# | 6                | 0.00              | 100.00            | 25.00             | 75.00             |
# | 7                | 7.57              | 92.43             | 0.00              | 92.43             |
# | 8                | 9.42              | 90.58             | 0.00              | 90.58             |
# | 9                | 9.67              | 90.33             | 0.00              | 90.33             |
# | 10               | 10.89             | 89.11             | 0.00              | 89.11             |
# | 11               | 7.81              | 92.19             | 0.00              | 92.19             |
# | 12               | 11.96             | 88.04             | 0.00              | 88.04             |
# | 13               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 14               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 15               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 16               | 0.00              | 100.00            | 25.00             | 75.00             |
# | 17               | 0.00              | 100.00            | 28.12             | 71.88             |
# | 18               | 0.00              | 100.00            | 28.12             | 71.88             |
# | 19               | 0.00              | 100.00            | 28.12             | 71.88             |
# | 20               | 0.00              | 100.00            | 28.12             | 71.88             |
# | 21               | 13.48             | 86.52             | 0.00              | 86.52             |
# | 22               | 14.55             | 85.45             | 0.00              | 85.45             |
# | 23               | 17.33             | 82.67             | 0.00              | 82.67             |
# | 24               | 6.59              | 93.41             | 0.00              | 93.41             |
# | 25               | 10.06             | 89.94             | 0.00              | 89.94             |
# | 26               | 13.72             | 86.28             | 0.00              | 86.28             |
# | 27               | 18.99             | 81.01             | 0.00              | 81.01             |
# | 28               | 17.48             | 82.52             | 0.00              | 82.52             |
# | 29               | 17.29             | 82.71             | 0.00              | 82.71             |
# | 30               | 22.31             | 77.69             | 0.00              | 77.69             |
# | 31               | 9.57              | 90.43             | 0.00              | 90.43             |
# | 32               | 17.14             | 82.86             | 0.00              | 82.86             |
# | 33               | 7.86              | 92.14             | 0.00              | 92.14             |
# | 34               | 8.59              | 91.41             | 0.00              | 91.41             |
# | 35               | 8.59              | 91.41             | 0.00              | 91.41             |
# | 36               | 6.79              | 93.21             | 0.00              | 93.21             |
# | 37               | 10.21             | 89.79             | 0.00              | 89.79             |
# | 38               | 7.23              | 92.77             | 0.00              | 92.77             |
# | 39               | 7.08              | 92.92             | 0.00              | 92.92             |
# | 40               | 6.49              | 93.51             | 0.00              | 93.51             |
#
#
# Time elapsed for stress testing 40 unique combinations: 4s 461ms

# %% [markdown]
# ## Introduction of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
sys.argv = ['notebook', '--qubit-range=3', f'--t-count={t_count}', '--print-circuit=d']

main()

# %% [markdown]
# ## Simulation of Toffoli decompositions and the QRAM circuit in 3 qubits

# %%
make_slurm("experiments", "3", str(t_count), "1", "output")
# Out:
# ========== QRAM Circuit Configuration ==========
#
# Simulate circuit on HPC: No
# Simulate Toffoli decompositions and circuit: Yes
# Circuit display option: Hide
# Start range of qubits: 3
# End range of qubits: 3
# Simulation type: Simulate full circuit
# Simulation display option: Dot
#
# ================================================
#
# ======================================================================================================================================================
#
#
#
# <==================== Simulating the circuit ... Comparing the results of the decompositions to the Toffoli gate ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 203ms
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |        8         |        1         |
# +------------------+------------------+------------------+
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulation and comparison: 224ms
#
#
# <==================== Simulating the circuit ... Checking the all qubits ====================>
#
#
# Simulation Range:
#
# +------------------+------------------+------------------+
# |      Start       |      Stop        |      Step        |
# +------------------+------------------+------------------+
# |        0         |     1048576      |        1         |
# +------------------+------------------+------------------+
#
# Simulating both the modded and bucket brigade circuits and comparing their output vector and measurements ...
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulation and comparison: 13h 51min 23s 941ms
#
# ======================================================================================================================================================

# %% [markdown]
# ## Stress test canceling 1 T gate in QRAM circuit with 3 qubits

# %%
make_slurm("stress", "3", str(t_count), "1", "output")
