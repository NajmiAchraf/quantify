# %%
import sys
from qramcircuits.bucket_brigade import MirrorMethod
from qramcircuits.qram_circuit_experiments import QRAMCircuitExperiments
from qramcircuits.qram_circuit_stress import QRAMCircuitStress
from qramcircuits.toffoli_decomposition import ToffoliDecompType

# Simulate command-line arguments
sys.argv = ['notebook', 'y', 'd', 'd', '2', '2']

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CXD 3) & (QC10) FIRST STRESS TESTING ELIMINATE ONE T GATE

# %%
QRAMCircuitStress(1).bb_decompose_test(
    dec=ToffoliDecompType.NO_DECOMP,
    parallel_toffolis=False,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)

# %% [markdown]
# # Bilan of the stress experiment:
#
# ### Stress experiment bilan:
#
# | T Gate Index     | Failed                                | Succeed (Measurements + Output Vector)    | Measurements                           | Output Vector                           |
# |------------------|---------------------------------------|-------------------------------------------|----------------------------------------|-----------------------------------------|
# | 3                | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 4                | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 5                | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 6                | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 13               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 14               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 15               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 16               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">25.00%        | <span style="color:green">75.00%        |
# | 17               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">28.12%        | <span style="color:green">71.88%        |
# | 18               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">28.12%        | <span style="color:green">71.88%        |
# | 19               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">28.12%        | <span style="color:green">71.88%        |
# | 20               | <span style="color:red">0.00%         | <span style="color:yellow">100.00%        | <span style="color:blue">28.12%        | <span style="color:green">71.88%        |
# | 37               | <span style="color:red">7.03%         | <span style="color:green">92.97%          | <span style="color:blue">0.00%         | <span style="color:green">92.97%        |
# | 33               | <span style="color:red">7.08%         | <span style="color:green">92.92%          | <span style="color:blue">0.00%         | <span style="color:green">92.92%        |
# | 35               | <span style="color:red">7.13%         | <span style="color:green">92.87%          | <span style="color:blue">0.00%         | <span style="color:green">92.87%        |
# | 39               | <span style="color:red">7.13%         | <span style="color:green">92.87%          | <span style="color:blue">0.00%         | <span style="color:green">92.87%        |
# | 11               | <span style="color:red">8.40%         | <span style="color:green">91.60%          | <span style="color:blue">0.00%         | <span style="color:green">91.60%        |
# | 38               | <span style="color:red">8.50%         | <span style="color:green">91.50%          | <span style="color:blue">0.00%         | <span style="color:green">91.50%        |
# | 7                | <span style="color:red">8.54%         | <span style="color:green">91.46%          | <span style="color:blue">0.00%         | <span style="color:green">91.46%        |
# | 1                | <span style="color:red">8.59%         | <span style="color:green">91.41%          | <span style="color:blue">0.00%         | <span style="color:green">91.41%        |
# | 9                | <span style="color:red">8.59%         | <span style="color:green">91.41%          | <span style="color:blue">0.00%         | <span style="color:green">91.41%        |
# | 36               | <span style="color:red">8.64%         | <span style="color:green">91.36%          | <span style="color:blue">0.00%         | <span style="color:green">91.36%        |
# | 34               | <span style="color:red">8.69%         | <span style="color:green">91.31%          | <span style="color:blue">0.00%         | <span style="color:green">91.31%        |
# | 40               | <span style="color:red">8.79%         | <span style="color:green">91.21%          | <span style="color:blue">0.00%         | <span style="color:green">91.21%        |
# | 12               | <span style="color:red">9.13%         | <span style="color:green">90.87%          | <span style="color:blue">0.00%         | <span style="color:green">90.87%        |
# | 2                | <span style="color:red">9.18%         | <span style="color:green">90.82%          | <span style="color:blue">0.00%         | <span style="color:green">90.82%        |
# | 10               | <span style="color:red">9.23%         | <span style="color:green">90.77%          | <span style="color:blue">0.00%         | <span style="color:green">90.77%        |
# | 8                | <span style="color:red">9.28%         | <span style="color:green">90.72%          | <span style="color:blue">0.00%         | <span style="color:green">90.72%        |
# | 21               | <span style="color:red">16.06%        | <span style="color:green">83.94%          | <span style="color:blue">0.00%         | <span style="color:green">83.94%        |
# | 29               | <span style="color:red">16.11%        | <span style="color:green">83.89%          | <span style="color:blue">0.00%         | <span style="color:green">83.89%        |
# | 22               | <span style="color:red">16.16%        | <span style="color:green">83.84%          | <span style="color:blue">0.00%         | <span style="color:green">83.84%        |
# | 30               | <span style="color:red">16.36%        | <span style="color:green">83.64%          | <span style="color:blue">0.00%         | <span style="color:green">83.64%        |
# | 28               | <span style="color:red">16.46%        | <span style="color:green">83.54%          | <span style="color:blue">0.00%         | <span style="color:green">83.54%        |
# | 24               | <span style="color:red">16.55%        | <span style="color:green">83.45%          | <span style="color:blue">0.00%         | <span style="color:green">83.45%        |
# | 32               | <span style="color:red">16.55%        | <span style="color:green">83.45%          | <span style="color:blue">0.00%         | <span style="color:green">83.45%        |
# | 25               | <span style="color:red">16.70%        | <span style="color:green">83.30%          | <span style="color:blue">0.00%         | <span style="color:green">83.30%        |
# | 27               | <span style="color:red">16.70%        | <span style="color:green">83.30%          | <span style="color:blue">0.00%         | <span style="color:green">83.30%        |
# | 23               | <span style="color:red">16.80%        | <span style="color:green">83.20%          | <span style="color:blue">0.00%         | <span style="color:green">83.20%        |
# | 31               | <span style="color:red">16.89%        | <span style="color:green">83.11%          | <span style="color:blue">0.00%         | <span style="color:green">83.11%        |
# | 26               | <span style="color:red">16.99%        | <span style="color:green">83.01%          | <span style="color:blue">0.00%         | <span style="color:green">83.01%        |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CX 3) & (QC10 MOD) FIRST EXPERIMENT

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],
    parallel_toffolis=True,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: no
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 49ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulate the decomposition: 209ms
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 70ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# ...

# %% [markdown]
# ## Bilan of the experiment:
#
# ### Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 169ms                      | 182.38 MB              | 2.11 GB                |
# | 3                | 459ms                      | 182.59 MB              | 2.11 GB                |
# | 4                | 1s 94ms                    | 182.97 MB              | 2.11 GB                |
# | 5                | 3s 206ms                   | 183.59 MB              | 2.12 GB                |
# | 6                | 9s 395ms                   | 184.47 MB              | 2.12 GB                |
#
#
# ### Simulation circuit result:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:yellow">Succeed: 100.00%</span>	( <span style="color:blue">Measurements: 46.88%</span> • <span style="color:green">Output vector: 53.12%</span> )
#
# ### Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
#
#
# ### Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 36               | 10                |
# | 3                | 20               | 45                   | 17               | 88               | 26                |
# | 4                | 37               | 57                   | 21               | 192              | 58                |
# | 5                | 70               | 69                   | 25               | 400              | 122               |
# | 6                | 135              | 81                   | 29               | 816              | 250               |
#
#
# ## Comparing bilans
#
# ### T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded     | T Count Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 36 (90.00%)        | 4 (10.00%)             |
# | 3                | 96                 | 88 (91.67%)        | 8 (8.33%)              |
# | 4                | 208                | 192 (92.31%)       | 16 (7.69%)             |
# | 5                | 432                | 400 (92.59%)       | 32 (7.41%)             |
# | 6                | 880                | 816 (92.73%)       | 64 (7.27%)             |
#
#
# ### T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded     | T Depth Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 13 (100.00%)       | 0 (0.00%)              |
# | 3                | 17                 | 17 (100.00%)       | 0 (0.00%)              |
# | 4                | 21                 | 21 (100.00%)       | 0 (0.00%)              |
# | 5                | 25                 | 25 (100.00%)       | 0 (0.00%)              |
# | 6                | 29                 | 29 (100.00%)       | 0 (0.00%)              |
#
#
# ### Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded       | Depth Cancelled        |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 33 (100.00%)       | 0 (0.00%)              |
# | 3                | 45                 | 45 (100.00%)       | 0 (0.00%)              |
# | 4                | 57                 | 57 (100.00%)       | 0 (0.00%)              |
# | 5                | 69                 | 69 (100.00%)       | 0 (0.00%)              |
# | 6                | 81                 | 81 (100.00%)       | 0 (0.00%)              |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CXD 3) & (QC10 MOD) SECOND EXPERIMENT

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],
    parallel_toffolis=True,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: no
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 48ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%	( Measurements: 12.50% • Output vector: 87.50% )
#
# Time elapsed on simulate the decomposition: 306ms
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 75ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# ...

# %% [markdown]
# ## Bilan of the experiment:
#
# ### Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 201ms                      | 182.09 MB              | 2.11 GB                |
# | 3                | 447ms                      | 182.23 MB              | 2.11 GB                |
# | 4                | 1s 147ms                   | 182.74 MB              | 2.11 GB                |
# | 5                | 3s 74ms                    | 183.36 MB              | 2.12 GB                |
# | 6                | 9s 217ms                   | 184.49 MB              | 2.12 GB                |
#
#
# ### Simulation circuit result:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:yellow">Succeed: 100.00%</span>	( <span style="color:blue">Measurements: 52.34%</span> • <span style="color:green">Output vector: 47.66%</span> )
#
# ### Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
#
#
# ### Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 32                   | 12               | 32               | 10                |
# | 3                | 20               | 44                   | 16               | 80               | 26                |
# | 4                | 37               | 56                   | 20               | 176              | 58                |
# | 5                | 70               | 68                   | 24               | 368              | 122               |
# | 6                | 135              | 80                   | 28               | 752              | 250               |
#
#
# ## Comparing bilans
#
# ### T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded     | T Count Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 32 (80.00%)        | 8 (20.00%)             |
# | 3                | 96                 | 80 (83.33%)        | 16 (16.67%)            |
# | 4                | 208                | 176 (84.62%)       | 32 (15.38%)            |
# | 5                | 432                | 368 (85.19%)       | 64 (14.81%)            |
# | 6                | 880                | 752 (85.45%)       | 128 (14.55%)           |
#
#
# ### T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded     | T Depth Cancelled      |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 12 (92.31%)        | 1 (7.69%)              |
# | 3                | 17                 | 16 (94.12%)        | 1 (5.88%)              |
# | 4                | 21                 | 20 (95.24%)        | 1 (4.76%)              |
# | 5                | 25                 | 24 (96.00%)        | 1 (4.00%)              |
# | 6                | 29                 | 28 (96.55%)        | 1 (3.45%)              |
#
#
# ### Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded       | Depth Cancelled        |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 32 (96.97%)        | 1 (3.03%)              |
# | 3                | 45                 | 44 (97.78%)        | 1 (2.22%)              |
# | 4                | 57                 | 56 (98.25%)        | 1 (1.75%)              |
# | 5                | 69                 | 68 (98.55%)        | 1 (1.45%)              |
# | 6                | 81                 | 80 (98.77%)        | 1 (1.23%)              |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CXD 3) & (QC10 MOD) THIRD EXPERIMENT

# %%
QRAMCircuitExperiments().bb_decompose_test(
    dec=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],
    parallel_toffolis=True,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)
# Out:
# Hello QRAM circuit experiments!
#
# Simulate Toffoli decompositions and circuit: yes
# Display circuits
# Print the full simulation result: yes
# Start Range of Qubits: 2
# End Range of Qubits: 2
# Simulate full circuit
#
#
# ...
#
#
#
# Simulating the decompositions ... comparing the results of the decompositions to the Toffoli gate.
#
# Display decomposition ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4 circuit:
# Time of displaying the circuit: 191ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.ZERO_ANCILLA_TDEPTH_4
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# 	• Succeed: 100.00%
#
# Time elapsed on simulate the decomposition: 389ms
#
# Display decomposition ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3 circuit:
# Time of displaying the circuit: 46ms
#
# start = 0 	stop = 8 	step = 1
#
# Simulating the decomposition ... ToffoliDecompType.RELATIVE_PHASE_TD_4_CX_3
#
# ••••••••
#
# Results of the simulation:
#
# 	• Failed: 0.00%
# ...

# %% [markdown]
# ## Bilan of the experiment:
#
# ### Creation of the Bucket Brigade Circuits:
#
# | Qubits Range     | Elapsed Time               | RSS (Memory Usage)     | VMS (Memory Usage)     |
# |------------------|----------------------------|------------------------|------------------------|
# | 2                | 82ms                       | 207.17 MB              | 1.80 GB                |
# | 3                | 165ms                      | 207.32 MB              | 1.80 GB                |
# | 4                | 415ms                      | 207.64 MB              | 1.80 GB                |
# | 5                | 1s 192ms                   | 208.26 MB              | 1.80 GB                |
# | 6                | 4s 86ms                    | 209.67 MB              | 1.80 GB                |
# | 7                | 15s 780ms                  | 212.32 MB              | 1.80 GB                |
# | 8                | 1min 10s 901ms             | 217.64 MB              | 1.80 GB                |
# | 9                | 6min 14s 639ms             | 222.77 MB              | 1.81 GB                |
# | 10               | 40min 39s 459ms            | 237.76 MB              | 1.82 GB                |
#
#
# ### Simulation circuit result:
#
# - <span style="color:red">Failed: 0.00%</span>
# - <span style="color:yellow">Succeed: 100.00%</span>	( <span style="color:blue">Measurements: 21.09%</span> • <span style="color:green">Output vector: 78.91%</span> )
#
#
# ### Reference circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 33                   | 13               | 40               | 10                |
# | 3                | 20               | 45                   | 17               | 96               | 26                |
# | 4                | 37               | 57                   | 21               | 208              | 58                |
# | 5                | 70               | 69                   | 25               | 432              | 122               |
# | 6                | 135              | 81                   | 29               | 880              | 250               |
# | 7                | 264              | 93                   | 33               | 1776             | 506               |
# | 8                | 521              | 105                  | 37               | 3568             | 1018              |
# | 9                | 1034             | 117                  | 41               | 7152             | 2042              |
# | 10               | 2059             | 129                  | 45               | 14320            | 4090              |
#
#
# ### Modded circuit bilan:
#
# | Qubits Range     | Number of Qubits | Depth of the Circuit | T Depth          | T Count          | Hadamard Count    |
# |------------------|------------------|----------------------|------------------|------------------|-------------------|
# | 2                | 11               | 31                   | 11               | 28               | 10                |
# | 3                | 20               | 43                   | 15               | 72               | 26                |
# | 4                | 37               | 55                   | 19               | 160              | 58                |
# | 5                | 70               | 67                   | 23               | 336              | 122               |
# | 6                | 135              | 79                   | 27               | 688              | 250               |
# | 7                | 264              | 91                   | 31               | 1392             | 506               |
# | 8                | 521              | 103                  | 35               | 2800             | 1018              |
# | 9                | 1034             | 115                  | 39               | 5616             | 2042              |
# | 10               | 2059             | 127                  | 43               | 11248            | 4090              |
#
#
# ## Comparing bilans
#
# ### T count comparison:
#
# | Qubits Range     | T Count Reference  | T Count Modded (%) | T Count Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 40                 | 28  ( 70.00 )      | 12  ( 30.00 )          |
# | 3                | 96                 | 72  ( 75.00 )      | 24  ( 25.00 )          |
# | 4                | 208                | 160  ( 76.92 )     | 48  ( 23.08 )          |
# | 5                | 432                | 336  ( 77.78 )     | 96  ( 22.22 )          |
# | 6                | 880                | 688  ( 78.18 )     | 192  ( 21.82 )         |
# | 7                | 1776               | 1392  ( 78.38 )    | 384  ( 21.62 )         |
# | 8                | 3568               | 2800  ( 78.48 )    | 768  ( 21.52 )         |
# | 9                | 7152               | 5616  ( 78.52 )    | 1536  ( 21.48 )        |
# | 10               | 14320              | 11248  ( 78.55 )   | 3072  ( 21.45 )        |
#
#
# ### T depth comparison:
#
# | Qubits Range     | T Depth Reference  | T Depth Modded (%) | T Depth Cancelled (%)  |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 13                 | 11  ( 84.62 )      | 2  ( 15.38 )           |
# | 3                | 17                 | 15  ( 88.24 )      | 2  ( 11.76 )           |
# | 4                | 21                 | 19  ( 90.48 )      | 2  ( 9.52 )            |
# | 5                | 25                 | 23  ( 92.00 )      | 2  ( 8.00 )            |
# | 6                | 29                 | 27  ( 93.10 )      | 2  ( 6.90 )            |
# | 7                | 33                 | 31  ( 93.94 )      | 2  ( 6.06 )            |
# | 8                | 37                 | 35  ( 94.59 )      | 2  ( 5.41 )            |
# | 9                | 41                 | 39  ( 95.12 )      | 2  ( 4.88 )            |
# | 10               | 45                 | 43  ( 95.56 )      | 2  ( 4.44 )            |
#
#
# ### Depth of the circuit comparison:
#
# | Qubits Range     | Depth Reference    | Depth Modded (%)   | Depth Cancelled (%)    |
# |------------------|--------------------|--------------------|------------------------|
# | 2                | 33                 | 31  ( 93.94 )      | 2  ( 6.06 )            |
# | 3                | 45                 | 43  ( 95.56 )      | 2  ( 4.44 )            |
# | 4                | 57                 | 55  ( 96.49 )      | 2  ( 3.51 )            |
# | 5                | 69                 | 67  ( 97.10 )      | 2  ( 2.90 )            |
# | 6                | 81                 | 79  ( 97.53 )      | 2  ( 2.47 )            |
# | 7                | 93                 | 91  ( 97.85 )      | 2  ( 2.15 )            |
# | 8                | 105                | 103  ( 98.10 )     | 2  ( 1.90 )            |
# | 9                | 117                | 115  ( 98.29 )     | 2  ( 1.71 )            |
# | 10               | 129                | 127  ( 98.45 )     | 2  ( 1.55 )            |

# %% [markdown]
# # COMPARING BILANS OF THE THREE EXPERIMENTS

# %% [markdown]
# ## Simulation circuit result of the three experiments:
#
# | Experiment | <span style="color:red">Failed (%)</span> | <span style="color:yellow">Succeed (%)</span> | <span style="color:blue">Measurements (%)</span> | <span style="color:green">Output Vector (%)</span> |
# |------------|------------------------------------------|-----------------------------------------------|--------------------------------------------------|---------------------------------------------------|
# | First      | <span style="color:red">0.00</span>      | <span style="color:yellow">100.00</span>      | <span style="color:blue">46.88</span>            | <span style="color:green">53.12</span>            |
# | Second     | <span style="color:red">0.00</span>      | <span style="color:yellow">100.00</span>      | <span style="color:blue">52.34</span>            | <span style="color:green">47.66</span>            |
# | Third      | <span style="color:red">0.00</span>      | <span style="color:yellow">100.00</span>      | <span style="color:blue">21.09</span>            | <span style="color:green">78.91</span>            |
#
# ## T count comparison of the three experiments (Modded):
#
# | Qubits Range | T Count Reference | T Count Modded (Exp 1) | T Count Modded (Exp 2) | T Count Modded (Exp 3) |
# |--------------|-------------------|------------------------|------------------------|------------------------|
# | 2            | 40                | <span style="color:green">36 (90.00%)</span>            | <span style="color:green">32 (80.00%)</span>            | <span style="color:green">28 (70.00%)</span>            |
# | 3            | 96                | <span style="color:green">88 (91.67%)</span>            | <span style="color:green">80 (83.33%)</span>            | <span style="color:green">72 (75.00%)</span>            |
# | 4            | 208               | <span style="color:green">192 (92.31%)</span>           | <span style="color:green">176 (84.62%)</span>           | <span style="color:green">160 (76.92%)</span>           |
# | 5            | 432               | <span style="color:green">400 (92.59%)</span>           | <span style="color:green">368 (85.19%)</span>           | <span style="color:green">336 (77.78%)</span>           |
# | 6            | 880               | <span style="color:green">816 (92.73%)</span>           | <span style="color:green">752 (85.45%)</span>           | <span style="color:green">688 (78.18%)</span>           |
#
# ## T count comparison of the three experiments (Cancelled):
#
# | Qubits Range | T Count Reference | T Count Cancelled (Exp 1) | T Count Cancelled (Exp 2) | T Count Cancelled (Exp 3) |
# |--------------|-------------------|---------------------------|---------------------------|---------------------------|
# | 2            | 40                | <span style="color:orange">4 (10.00%)</span>                | <span style="color:orange">8 (20.00%)</span>                | <span style="color:orange">12 (30.00%)</span>               |
# | 3            | 96                | <span style="color:orange">8 (8.33%)</span>                 | <span style="color:orange">16 (16.67%)</span>               | <span style="color:orange">24 (25.00%)</span>               |
# | 4            | 208               | <span style="color:orange">16 (7.69%)</span>                | <span style="color:orange">32 (15.38%)</span>               | <span style="color:orange">48 (23.08%)</span>               |
# | 5            | 432               | <span style="color:orange">32 (7.41%)</span>                | <span style="color:orange">64 (14.81%)</span>               | <span style="color:orange">96 (22.22%)</span>               |
# | 6            | 880               | <span style="color:orange">64 (7.27%)</span>                | <span style="color:orange">128 (14.55%)</span>              | <span style="color:orange">192 (21.82%)</span>              |

# %% [markdown]
# # THE BUCKET BRIGADE DECOMPOSITION (TD 4 CXD 3) & (QC10 MOD) SECOND STRESS TESTING ELIMINATE ONE T GATE

# %%
QRAMCircuitStress(1).bb_decompose_test(
    dec=ToffoliDecompType.NO_DECOMP,
    parallel_toffolis=False,

    dec_mod=[
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
        ToffoliDecompType.ANCILLA_0_TD4_MOD,
        ToffoliDecompType.RELATIVE_PHASE_TD_4_CXD_3,
    ],

    parallel_toffolis_mod=True,
    mirror_method=MirrorMethod.OUT_TO_IN
)

# %% [markdown]
# | T Gate Index     | Failed                                | Succeed (Measurements + Output Vector)    | Measurements                           | Output Vector                           |
# |------------------|---------------------------------------|-------------------------------------------|----------------------------------------|-----------------------------------------|
# | 1                | <span style="color:red">7.71%         | <span style="color:yellow">92.29%         | <span style="color:blue">18.36%        | <span style="color:green">73.93%        |
# | 7                | <span style="color:red">7.71%         | <span style="color:yellow">92.29%         | <span style="color:blue">18.26%        | <span style="color:green">74.02%        |
# | 5                | <span style="color:red">7.76%         | <span style="color:yellow">92.24%         | <span style="color:blue">18.12%        | <span style="color:green">74.12%        |
# | 23               | <span style="color:red">7.81%         | <span style="color:yellow">92.19%         | <span style="color:blue">18.26%        | <span style="color:green">73.93%        |
# | 25               | <span style="color:red">7.81%         | <span style="color:yellow">92.19%         | <span style="color:blue">18.31%        | <span style="color:green">73.88%        |
# | 27               | <span style="color:red">7.81%         | <span style="color:yellow">92.19%         | <span style="color:blue">18.16%        | <span style="color:green">74.02%        |
# | 21               | <span style="color:red">7.86%         | <span style="color:yellow">92.14%         | <span style="color:blue">18.21%        | <span style="color:green">73.93%        |
# | 3                | <span style="color:red">8.01%         | <span style="color:yellow">91.99%         | <span style="color:blue">18.12%        | <span style="color:green">73.88%        |
# | 4                | <span style="color:red">8.15%         | <span style="color:yellow">91.85%         | <span style="color:blue">17.82%        | <span style="color:green">74.02%        |
# | 6                | <span style="color:red">8.20%         | <span style="color:yellow">91.80%         | <span style="color:blue">17.87%        | <span style="color:green">73.93%        |
# | 2                | <span style="color:red">8.25%         | <span style="color:yellow">91.75%         | <span style="color:blue">17.87%        | <span style="color:green">73.88%        |
# | 8                | <span style="color:red">8.30%         | <span style="color:yellow">91.70%         | <span style="color:blue">17.87%        | <span style="color:green">73.83%        |
# | 22               | <span style="color:red">8.35%         | <span style="color:yellow">91.65%         | <span style="color:blue">17.82%        | <span style="color:green">73.83%        |
# | 28               | <span style="color:red">8.35%         | <span style="color:yellow">91.65%         | <span style="color:blue">17.82%        | <span style="color:green">73.83%        |
# | 24               | <span style="color:red">8.45%         | <span style="color:yellow">91.55%         | <span style="color:blue">17.82%        | <span style="color:green">73.73%        |
# | 26               | <span style="color:red">8.59%         | <span style="color:yellow">91.41%         | <span style="color:blue">17.72%        | <span style="color:green">73.68%        |
# | 12               | <span style="color:red">13.04%        | <span style="color:yellow">86.96%         | <span style="color:blue">18.55%        | <span style="color:green">68.41%        |
# | 13               | <span style="color:red">13.09%        | <span style="color:yellow">86.91%         | <span style="color:blue">18.70%        | <span style="color:green">68.21%        |
# | 17               | <span style="color:red">13.23%        | <span style="color:yellow">86.77%         | <span style="color:blue">18.65%        | <span style="color:green">68.12%        |
# | 9                | <span style="color:red">13.28%        | <span style="color:yellow">86.72%         | <span style="color:blue">18.46%        | <span style="color:green">68.26%        |
# | 10               | <span style="color:red">13.28%        | <span style="color:yellow">86.72%         | <span style="color:blue">18.60%        | <span style="color:green">68.12%        |
# | 11               | <span style="color:red">13.28%        | <span style="color:yellow">86.72%         | <span style="color:blue">18.70%        | <span style="color:green">68.02%        |
# | 15               | <span style="color:red">13.28%        | <span style="color:yellow">86.72%         | <span style="color:blue">18.65%        | <span style="color:green">68.07%        |
# | 18               | <span style="color:red">13.33%        | <span style="color:yellow">86.67%         | <span style="color:blue">18.60%        | <span style="color:green">68.07%        |
# | 20               | <span style="color:red">13.33%        | <span style="color:yellow">86.67%         | <span style="color:blue">18.60%        | <span style="color:green">68.07%        |
# | 16               | <span style="color:red">13.43%        | <span style="color:yellow">86.57%         | <span style="color:blue">18.46%        | <span style="color:green">68.12%        |
# | 14               | <span style="color:red">13.72%        | <span style="color:yellow">86.28%         | <span style="color:blue">18.55%        | <span style="color:green">67.72%        |
# | 19               | <span style="color:red">13.72%        | <span style="color:yellow">86.28%         | <span style="color:blue">18.55%        | <span style="color:green">67.72%        |
